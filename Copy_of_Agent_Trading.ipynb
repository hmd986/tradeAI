# %%
## Further  recommendation, test multiple frameworks, see what works better on average. 
## Open source RL: https://docs.google.com/spreadsheets/d/1EeFPd-XIQ3mq_9snTlAZSsFY7Hbnmd7P5bbT8LPuMn0/edit#gid=0

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import time
sns.set()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ## Trading Strategies

# %% [markdown]
# This notebook is part of a series on machine learning asset managment. https://ssrn.com/abstract=3420952
#
# I have had some enquiries about future releases, I will post future content on the [FirmAI](https://www.linkedin.com/company/18004273/admin/) Linkedin page.

# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# Requirement already up-to-date: yfinance in /usr/local/lib/python3.6/dist-packages (0.1.54)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.17.4)
# Requirement already satisfied, skipping upgrade: pandas>=0.24 in /usr/local/lib/python3.6/dist-packages (from yfinance) (0.25.3)
# Requirement already satisfied, skipping upgrade: requests>=2.20 in /usr/local/lib/python3.6/dist-packages (from yfinance) (2.21.0)
# Requirement already satisfied, skipping upgrade: multitasking>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from yfinance) (0.0.9)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2.6.1)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2019.11.28)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2.8)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.12.0)

# %%
## Save future files to your drive
## In this notebook control for multiple testing
import numpy as np
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# %cd "/content/drive/My Drive/FirmAI/FinML/Data/Agent Trading/output"
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/FirmAI/FinML/Data/Agent Trading/output

# %%
from pandas_datareader import data as pdr
import fix_yahoo_finance as yf
yf.pdr_override()
df_full = pdr.get_data_yahoo("CTSH", start="2018-01-01").reset_index()
df_full.to_csv('CTSH.csv',index=False)
df_full.head()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#         Date       Open       High        Low      Close  Adj Close   Volume
# 0 2018-01-02  71.160004  71.330002  70.540001  70.949997  69.146751  3068600
# 1 2018-01-03  71.180000  71.769997  70.900002  71.550003  69.731499  4317100
# 2 2018-01-04  71.949997  72.970001  71.860001  72.680000  70.832794  3444300
# 3 2018-01-05  73.110001  73.589996  72.760002  73.300003  71.437042  2913200
# 4 2018-01-08  73.160004  73.660004  73.010002  73.370003  71.505241  3305400

# %%
df_full = pd.read_csv('CTSH.csv')

# %% [markdown]
# #  Agents
#
# * Turtle Trading agent
# * Moving Average agent
# * Signal Rolling agent
# * Policy Gradient agent
# * Q-learning agent
# * Evolution Strategy agent
# * Double Q-learning agent
# * Recurrent Q-learning agent
# * Double Recurrent Q-learning agent
# * Duel Q-learning agent
# * Double Duel Q-learning agent
# * Duel Recurrent Q-learning agent
# * Double Duel Recurrent Q-learning agent
# * Actor-critic agent
# * Actor-critic Duel agent
# * Actor-critic Recurrent agent
# * Actor-critic Duel Recurrent agent
# * Curiosity Q-learning agent
# * Recurrent Curiosity Q-learning agent
# * Duel Curiosity Q-learning agent
# * Neuro-evolution agent
# * Neuro-evolution with Novelty search agent
# * ABCD strategy agent
# * Deep Evolution Strategy

# %% [markdown]
# ## Turtle Trading Agent

# %%
df= df_full.copy()
name = 'Turtle Trading Agent'
count = int(np.ceil(len(df) * 0.1))
signals = pd.DataFrame(index=df.index)
signals['signal'] = 0.0
signals['trend'] = df['Close']
signals['RollingMax'] = (signals.trend.shift(1).rolling(count).max())
signals['RollingMin'] = (signals.trend.shift(1).rolling(count).min())
signals.loc[signals['RollingMax'] < signals.trend, 'signal'] = -1
signals.loc[signals['RollingMin'] > signals.trend, 'signal'] = 1
signals
# Out:
#      signal      trend  RollingMax  RollingMin
# 0       0.0  70.949997         NaN         NaN
# 1       0.0  71.550003         NaN         NaN
# 2       0.0  72.680000         NaN         NaN
# 3       0.0  73.300003         NaN         NaN
# 4       0.0  73.370003         NaN         NaN
# ..      ...        ...         ...         ...
# 499     0.0  62.119999   64.150002   59.889999
# 500     0.0  62.160000   64.150002   59.889999
# 501     0.0  61.650002   64.150002   59.889999
# 502     0.0  62.020000   64.150002   59.889999
# 503     0.0  61.820000   64.150002   59.889999
#
# [504 rows x 4 columns]

# %%
def buy_stock(
    real_movement,
    signal,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    for i in range(real_movement.shape[0] - int(0.025 * len(df))):
        state = signal[i]
        if state == 1:
            initial_money, current_inventory = buy(
                i, initial_money, current_inventory
            )
            states_buy.append(i)
        elif state == -1:
            if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
            else:
                if current_inventory > max_sell:
                    sell_units = max_sell
                else:
                    sell_units = current_inventory
                current_inventory -= sell_units
                total_sell = sell_units * real_movement[i]
                initial_money += total_sell
                try:
                    invest = (
                        (real_movement[i] - real_movement[states_buy[-1]])
                        / real_movement[states_buy[-1]]
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (i, sell_units, total_sell, invest, initial_money)
                )
            states_sell.append(i)
            
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, signals['signal'])
# Out:
# day 86: buy 1 units at price 77.860001, total balance 9922.139999
# day 87: buy 1 units at price 75.550003, total balance 9846.589996
# day 88: buy 1 units at price 75.029999, total balance 9771.559997
# day 101: buy 1 units at price 74.410004, total balance 9697.149993
# day 132, sell 1 units at price 83.320000, investment 11.974191 %, total balance 9780.469993,
# day 155: buy 1 units at price 75.220001, total balance 9705.249992
# day 156: buy 1 units at price 74.540001, total balance 9630.709991
# day 193: buy 1 units at price 74.110001, total balance 9556.599990
# day 194: buy 1 units at price 73.970001, total balance 9482.629989
# day 195: buy 1 units at price 71.440002, total balance 9411.189987
# day 196: buy 1 units at price 70.290001, total balance 9340.899986
# day 205: buy 1 units at price 70.150002, total balance 9270.749984
# day 208: buy 1 units at price 69.220001, total balance 9201.529983
# day 209: buy 1 units at price 66.519997, total balance 9135.009986
# day 241: buy 1 units at price 64.669998, total balance 9070.339988
# day 242: buy 1 units at price 64.620003, total balance 9005.719985
# day 243: buy 1 units at price 64.230003, total balance 8941.489982
# day 244: buy 1 units at price 62.779999, total balance 8878.709983
# day 245: buy 1 units at price 60.090000, total balance 8818.619983
# day 246: buy 1 units at price 60.020000, total balance 8758.599983
# day 275, sell 1 units at price 74.500000, investment 24.125292 %, total balance 8833.099983,
# day 319, sell 1 units at price 74.599998, investment 24.291899 %, total balance 8907.699981,
# day 334: buy 1 units at price 66.610001, total balance 8841.089980
# day 335: buy 1 units at price 59.250000, total balance 8781.839980
# day 337: buy 1 units at price 58.509998, total balance 8723.329982
# day 341: buy 1 units at price 56.880001, total balance 8666.449981
# day 393, sell 1 units at price 66.400002, investment 16.736992 %, total balance 8732.849983,
# day 397, sell 1 units at price 66.410004, investment 16.754576 %, total balance 8799.259987,
# day 407: buy 1 units at price 60.580002, total balance 8738.679985
# day 413: buy 1 units at price 60.000000, total balance 8678.679985
# day 414: buy 1 units at price 59.869999, total balance 8618.809986
# day 415: buy 1 units at price 59.700001, total balance 8559.109985
# day 436: buy 1 units at price 59.660000, total balance 8499.449985
# day 437: buy 1 units at price 58.750000, total balance 8440.699985
# day 480, sell 1 units at price 64.150002, investment 9.191493 %, total balance 8504.849987,

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Moving Average agent

# %%
df= df_full.copy()
name = 'Moving Average agent'

short_window = int(0.025 * len(df))
long_window = int(0.05 * len(df))

signals = pd.DataFrame(index=df.index)
signals['signal'] = 0.0

signals['short_ma'] = df['Close'].rolling(window=short_window, min_periods=1, center=False).mean()
signals['long_ma'] = df['Close'].rolling(window=long_window, min_periods=1, center=False).mean()

signals['signal'][short_window:] = np.where(signals['short_ma'][short_window:] 
                                            > signals['long_ma'][short_window:], 1.0, 0.0)   
signals['positions'] = signals['signal'].diff()

signals
# Out:
#      signal   short_ma    long_ma  positions
# 0       0.0  70.949997  70.949997        NaN
# 1       0.0  71.250000  71.250000        0.0
# 2       0.0  71.726667  71.726667        0.0
# 3       0.0  72.120001  72.120001        0.0
# 4       0.0  72.370001  72.370001        0.0
# ..      ...        ...        ...        ...
# 499     0.0  62.000833  62.596000        0.0
# 500     0.0  62.089167  62.542000        0.0
# 501     0.0  62.170000  62.472000        0.0
# 502     0.0  62.190833  62.425200        0.0
# 503     0.0  62.205833  62.363600        0.0
#
# [504 rows x 4 columns]

# %%
def buy_stock(
    real_movement,
    signal,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    for i in range(real_movement.shape[0] - int(0.025 * len(df))):
        state = signal[i]
        if state == 1:
            initial_money, current_inventory = buy(
                i, initial_money, current_inventory
            )
            states_buy.append(i)
        elif state == -1:
            if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
            else:
                if current_inventory > max_sell:
                    sell_units = max_sell
                else:
                    sell_units = current_inventory
                current_inventory -= sell_units
                total_sell = sell_units * real_movement[i]
                initial_money += total_sell
                try:
                    invest = (
                        (real_movement[i] - real_movement[states_buy[-1]])
                        / real_movement[states_buy[-1]]
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (i, sell_units, total_sell, invest, initial_money)
                )
            states_sell.append(i)
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, signals['positions'])
# Out:
# day 12: buy 1 units at price 77.290001, total balance 9922.709999
# day 30, sell 1 units at price 79.820000, investment 3.273385 %, total balance 10002.529999,
# day 33: buy 1 units at price 81.540001, total balance 9920.989998
# day 59, sell 1 units at price 79.669998, investment -2.293357 %, total balance 10000.659996,
# day 77: buy 1 units at price 80.800003, total balance 9919.859993
# day 87, sell 1 units at price 75.550003, investment -6.497525 %, total balance 9995.409996,
# day 110: buy 1 units at price 76.970001, total balance 9918.439995
# day 149, sell 1 units at price 78.489998, investment 1.974791 %, total balance 9996.929993,
# day 172: buy 1 units at price 75.730003, total balance 9921.199990
# day 194, sell 1 units at price 73.970001, investment -2.324049 %, total balance 9995.169991,
# day 232: buy 1 units at price 71.930000, total balance 9923.239991
# day 235, sell 1 units at price 68.000000, investment -5.463645 %, total balance 9991.239991,
# day 238: buy 1 units at price 68.029999, total balance 9923.209992
# day 241, sell 1 units at price 64.669998, investment -4.938999 %, total balance 9987.879990,
# day 262: buy 1 units at price 66.550003, total balance 9921.329987
# day 294, sell 1 units at price 71.459999, investment 7.377905 %, total balance 9992.789986,
# day 312: buy 1 units at price 73.849998, total balance 9918.939988
# day 331, sell 1 units at price 72.400002, investment -1.963434 %, total balance 9991.339990,
# day 357: buy 1 units at price 62.180000, total balance 9929.159990
# day 401, sell 1 units at price 62.209999, investment 0.048245 %, total balance 9991.369989,
# day 424: buy 1 units at price 64.739998, total balance 9926.629991
# day 437, sell 1 units at price 58.750000, investment -9.252391 %, total balance 9985.379991,
# day 456: buy 1 units at price 60.509998, total balance 9924.869993
# day 488, sell 1 units at price 61.099998, investment 0.975045 %, total balance 9985.969991,

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Signal Rolling agent

# %%
df= df_full.copy()
name = 'Signal Rolling agent'

# %%
def buy_stock(
    real_movement,
    delay = 5,
    initial_state = 1,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 1000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    delay_change_decision = delay
    current_decision = 0
    state = initial_state
    current_val = real_movement[0]
    states_sell = []
    states_buy = []
    current_inventory = 0

    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory

    if state == 1:
        initial_money, current_inventory = buy(
            0, initial_money, current_inventory
        )

    for i in range(1, real_movement.shape[0], 1):
        if real_movement[i] < current_val and state == 0:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 1
                initial_money, current_inventory = buy(
                    i, initial_money, current_inventory
                )
                current_decision = 0
                states_buy.append(i)
        if real_movement[i] > current_val and state == 1:
            if current_decision < delay_change_decision:
                current_decision += 1
            else:
                state = 0

                if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
                else:
                    if current_inventory > max_sell:
                        sell_units = max_sell
                    else:
                        sell_units = current_inventory
                    current_inventory -= sell_units
                    total_sell = sell_units * real_movement[i]
                    initial_money += total_sell
                    try:
                        invest = (
                            (real_movement[i] - real_movement[states_buy[-1]])
                            / real_movement[states_buy[-1]]
                        ) * 100
                    except:
                        invest = 0
                    print(
                        'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                        % (i, sell_units, total_sell, invest, initial_money)
                    )

                current_decision = 0
                states_sell.append(i)
        current_val = real_movement[i]
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest

# %%
states_buy, states_sell, total_gains, invest = buy_stock(df.Close, initial_state = 1, 
                                                         delay = 4, initial_money = 10000)
# Out:
# day 0: buy 1 units at price 70.949997, total balance 9929.050003
# day 5, sell 1 units at price 73.459999, investment 3.537706 %, total balance 10002.510002,
# day 22: buy 1 units at price 75.720001, total balance 9926.790001
# day 29, sell 1 units at price 78.110001, investment 3.156366 %, total balance 10004.900002,
# day 40: buy 1 units at price 80.650002, total balance 9924.250000
# day 46, sell 1 units at price 84.709999, investment 5.034094 %, total balance 10008.959999,
# day 52: buy 1 units at price 83.809998, total balance 9925.150001
# day 63, sell 1 units at price 80.720001, investment -3.686907 %, total balance 10005.870002,
# day 74: buy 1 units at price 82.370003, total balance 9923.499999
# day 89, sell 1 units at price 75.949997, investment -7.794107 %, total balance 9999.449996,
# day 97: buy 1 units at price 75.239998, total balance 9924.209998
# day 105, sell 1 units at price 77.220001, investment 2.631583 %, total balance 10001.429999,
# day 115: buy 1 units at price 80.010002, total balance 9921.419997
# day 126, sell 1 units at price 79.900002, investment -0.137483 %, total balance 10001.319999,
# day 138: buy 1 units at price 82.239998, total balance 9919.080001
# day 148, sell 1 units at price 77.820000, investment -5.374511 %, total balance 9996.900001,
# day 154: buy 1 units at price 75.419998, total balance 9921.480003
# day 164, sell 1 units at price 76.610001, investment 1.577835 %, total balance 9998.090004,
# day 175: buy 1 units at price 75.699997, total balance 9922.390007
# day 187, sell 1 units at price 77.150002, investment 1.915462 %, total balance 9999.540009,
# day 193: buy 1 units at price 74.110001, total balance 9925.430008
# day 206, sell 1 units at price 71.480003, investment -3.548776 %, total balance 9996.910011,
# day 213: buy 1 units at price 69.459999, total balance 9927.450012
# day 222, sell 1 units at price 70.330002, investment 1.252524 %, total balance 9997.780014,
# day 233: buy 1 units at price 70.019997, total balance 9927.760017
# day 248, sell 1 units at price 63.080002, investment -9.911447 %, total balance 9990.840019,
# day 256: buy 1 units at price 64.260002, total balance 9926.580017
# day 263, sell 1 units at price 67.820000, investment 5.539990 %, total balance 9994.400017,
# day 274: buy 1 units at price 71.209999, total balance 9923.190018
# day 282, sell 1 units at price 73.559998, investment 3.300097 %, total balance 9996.750016,
# day 288: buy 1 units at price 72.040001, total balance 9924.710015
# day 301, sell 1 units at price 72.129997, investment 0.124925 %, total balance 9996.840012,
# day 309: buy 1 units at price 71.029999, total balance 9925.810013
# day 316, sell 1 units at price 74.199997, investment 4.462900 %, total balance 10000.010010,
# day 328: buy 1 units at price 72.669998, total balance 9927.340012
# day 338, sell 1 units at price 58.980000, investment -18.838583 %, total balance 9986.320012,
# day 355: buy 1 units at price 60.540001, total balance 9925.780011
# day 361, sell 1 units at price 63.369999, investment 4.674592 %, total balance 9989.150010,
# day 371: buy 1 units at price 63.160000, total balance 9925.990010
# day 380, sell 1 units at price 64.379997, investment 1.931598 %, total balance 9990.370007,
# day 391: buy 1 units at price 65.760002, total balance 9924.610005
# day 402, sell 1 units at price 63.959999, investment -2.737231 %, total balance 9988.570004,
# day 410: buy 1 units at price 61.580002, total balance 9926.990002
# day 419, sell 1 units at price 61.480000, investment -0.162394 %, total balance 9988.470002,
# day 430: buy 1 units at price 63.509998, total balance 9924.960004
# day 442, sell 1 units at price 60.509998, investment -4.723666 %, total balance 9985.470002,
# day 452: buy 1 units at price 60.639999, total balance 9924.830003
# day 461, sell 1 units at price 60.939999, investment 0.494723 %, total balance 9985.770002,
# day 475: buy 1 units at price 63.509998, total balance 9922.260004
# day 490, sell 1 units at price 61.770000, investment -2.739723 %, total balance 9984.030004,
# day 501: buy 1 units at price 61.650002, total balance 9922.380002

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Policy Gradient agent

# %%
df = df_full.copy()
name = 'Policy Gradient agent'
class Agent:

    LEARNING_RATE = 1e-4
    LAYER_SIZE = 256
    GAMMA = 0.9
    OUTPUT_SIZE = 3

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.X = tf.placeholder(tf.float32, (None, self.state_size))
        self.REWARDS = tf.placeholder(tf.float32, (None))
        self.ACTIONS = tf.placeholder(tf.int32, (None))
        feed_forward = tf.layers.dense(self.X, self.LAYER_SIZE, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, self.OUTPUT_SIZE, activation = tf.nn.softmax)
        input_y = tf.one_hot(self.ACTIONS, self.OUTPUT_SIZE)
        loglike = tf.log((input_y * (input_y - self.logits) + (1 - input_y) * (input_y + self.logits)) + 1)
        rewards = tf.tile(tf.reshape(self.REWARDS, (-1,1)), [1, self.OUTPUT_SIZE])
        self.cost = -tf.reduce_mean(loglike * (rewards + 1)) 
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def discount_rewards(self, r):
        discounted_r = np.zeros_like(r)
        running_add = 0
        for t in reversed(range(0, r.size)):
            running_add = running_add * self.GAMMA + r[t]
            discounted_r[t] = running_add
        return discounted_r
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.get_predicted_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            ep_history = []
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.get_predicted_action(state)
                next_state = self.get_state(t + 1)
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= close[t]
                
                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                ep_history.append([state,action,starting_money,next_state])
                state = next_state
            ep_history = np.array(ep_history)
            ep_history[:,2] = self.discount_rewards(ep_history[:,2])
            cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict={self.X:np.vstack(ep_history[:,0]),
                                                    self.REWARDS:ep_history[:,2],
                                                    self.ACTIONS:ep_history[:,1]})
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
agent = Agent(state_size = window_size,
             window_size = window_size,
             trend = close,skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-18-78fc16a616dd>:19: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# epoch: 10, total rewards: -808.810001.3, cost: -13543.971680, total money: 426.550023
# epoch: 20, total rewards: -606.819975.3, cost: -22042.265625, total money: 4856.940028
# epoch: 30, total rewards: -261.559990.3, cost: -28397.937500, total money: 8254.910015
# epoch: 40, total rewards: -256.149988.3, cost: -29106.380859, total money: 8804.530012
# epoch: 50, total rewards: -397.829963.3, cost: -28083.925781, total money: 8114.680039
# epoch: 60, total rewards: -473.319956.3, cost: -27432.636719, total money: 7912.340043
# epoch: 70, total rewards: -309.409965.3, cost: -29717.314453, total money: 8808.180025
# epoch: 80, total rewards: -204.369970.3, cost: -31339.281250, total money: 9795.630030
# epoch: 90, total rewards: -295.589991.3, cost: -30306.917969, total money: 9704.410009
# epoch: 100, total rewards: -234.349940.3, cost: -30204.548828, total money: 9257.120052
# epoch: 110, total rewards: -257.739946.3, cost: -29962.013672, total money: 8861.920048
# epoch: 120, total rewards: -144.099957.3, cost: -31224.830078, total money: 8976.970037
# epoch: 130, total rewards: -147.809959.3, cost: -32285.216797, total money: 9852.190041
# epoch: 140, total rewards: -89.159934.3, cost: -33436.820312, total money: 9910.840066
# epoch: 150, total rewards: -436.709921.3, cost: -27980.962891, total money: 7333.220076
# epoch: 160, total rewards: -33.509935.3, cost: -33752.074219, total money: 9713.210061
# epoch: 170, total rewards: -338.819928.3, cost: -29723.136719, total money: 7988.830077
# epoch: 180, total rewards: -459.479973.3, cost: -28005.041016, total money: 7054.620016
# epoch: 190, total rewards: -121.039919.3, cost: -33240.621094, total money: 9307.990074
# epoch: 200, total rewards: -73.319987.3, cost: -33862.980469, total money: 9800.740010

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 8: buy 1 unit at price 74.559998, total balance 9925.440002
# day 9: buy 1 unit at price 74.730003, total balance 9850.709999
# day 10: buy 1 unit at price 75.839996, total balance 9774.870003
# day 14, sell 1 unit at price 78.260002, investment 4.962452 %, total balance 9853.130005,
# day 15: buy 1 unit at price 78.449997, total balance 9774.680008
# day 16: buy 1 unit at price 77.949997, total balance 9696.730011
# day 17: buy 1 unit at price 78.430000, total balance 9618.300011
# day 18, sell 1 unit at price 78.150002, investment 4.576474 %, total balance 9696.450013,
# day 19: buy 1 unit at price 77.760002, total balance 9618.690011
# day 20, sell 1 unit at price 77.980003, investment 2.821739 %, total balance 9696.670014,
# day 22, sell 1 unit at price 75.720001, investment -3.479919 %, total balance 9772.390015,
# day 23: buy 1 unit at price 73.290001, total balance 9699.100014
# day 25, sell 1 unit at price 76.519997, investment -1.834509 %, total balance 9775.620011,
# day 27, sell 1 unit at price 76.290001, investment -2.728546 %, total balance 9851.910012,
# day 28: buy 1 unit at price 77.430000, total balance 9774.480012
# day 29: buy 1 unit at price 78.110001, total balance 9696.370011
# day 31, sell 1 unit at price 81.370003, investment 4.642491 %, total balance 9777.740014,
# day 32: buy 1 unit at price 80.949997, total balance 9696.790017
# day 33, sell 1 unit at price 81.540001, investment 11.256652 %, total balance 9778.330018,
# day 34: buy 1 unit at price 81.800003, total balance 9696.530015
# day 35, sell 1 unit at price 81.610001, investment 5.398426 %, total balance 9778.140016,
# day 36: buy 1 unit at price 82.529999, total balance 9695.610017
# day 37, sell 1 unit at price 82.970001, investment 6.221995 %, total balance 9778.580018,
# day 39: buy 1 unit at price 82.019997, total balance 9696.560021
# day 46, sell 1 unit at price 84.709999, investment 4.644845 %, total balance 9781.270020,
# day 48: buy 1 unit at price 83.790001, total balance 9697.480019
# day 49, sell 1 unit at price 83.629997, investment 2.237156 %, total balance 9781.110016,
# day 51: buy 1 unit at price 84.599998, total balance 9696.510018
# day 55, sell 1 unit at price 80.970001, investment -1.890219 %, total balance 9777.480019,
# day 57: buy 1 unit at price 81.629997, total balance 9695.850022
# day 58: buy 1 unit at price 80.080002, total balance 9615.770020
# day 59, sell 1 unit at price 79.669998, investment -2.865154 %, total balance 9695.440018,
# day 60: buy 1 unit at price 80.500000, total balance 9614.940018
# day 61: buy 1 unit at price 79.209999, total balance 9535.730019
# day 63: buy 1 unit at price 80.720001, total balance 9455.010018
# day 64: buy 1 unit at price 80.919998, total balance 9374.090020
# day 67, sell 1 unit at price 80.400002, investment -4.045828 %, total balance 9454.490022,
# day 72: buy 1 unit at price 82.190002, total balance 9372.300020
# day 75: buy 1 unit at price 81.769997, total balance 9290.530023
# day 76: buy 1 unit at price 81.570000, total balance 9208.960023
# day 78: buy 1 unit at price 80.910004, total balance 9128.050019
# day 79: buy 1 unit at price 81.730003, total balance 9046.320016
# day 80, sell 1 unit at price 81.620003, investment -3.522453 %, total balance 9127.940019,
# day 81: buy 1 unit at price 81.820000, total balance 9046.120019
# day 82, sell 1 unit at price 81.820000, investment 0.232761 %, total balance 9127.940019,
# day 83: buy 1 unit at price 81.379997, total balance 9046.560022
# day 85, sell 1 unit at price 82.169998, investment 2.609885 %, total balance 9128.730020,
# day 89, sell 1 unit at price 75.949997, investment -5.652178 %, total balance 9204.680017,
# day 90: buy 1 unit at price 76.580002, total balance 9128.100015
# day 91, sell 1 unit at price 75.860001, investment -4.229262 %, total balance 9203.960016,
# day 95: buy 1 unit at price 76.040001, total balance 9127.920015
# day 96: buy 1 unit at price 75.750000, total balance 9052.170015
# day 97: buy 1 unit at price 75.239998, total balance 8976.930017
# day 101: buy 1 unit at price 74.410004, total balance 8902.520013
# day 102, sell 1 unit at price 75.690002, investment -6.231416 %, total balance 8978.210015,
# day 103: buy 1 unit at price 75.349998, total balance 8902.860017
# day 104, sell 1 unit at price 76.870003, investment -5.004937 %, total balance 8979.730020,
# day 105, sell 1 unit at price 77.220001, investment -6.046965 %, total balance 9056.950021,
# day 106, sell 1 unit at price 77.029999, investment -5.796745 %, total balance 9133.980020,
# day 107: buy 1 unit at price 78.139999, total balance 9055.840021
# day 109, sell 1 unit at price 77.110001, investment -5.467695 %, total balance 9132.950022,
# day 111: buy 1 unit at price 78.250000, total balance 9054.700022
# day 112: buy 1 unit at price 78.019997, total balance 8976.680025
# day 114: buy 1 unit at price 80.699997, total balance 8895.980028
# day 115: buy 1 unit at price 80.010002, total balance 8815.970026
# day 116: buy 1 unit at price 79.199997, total balance 8736.770029
# day 119: buy 1 unit at price 78.699997, total balance 8658.070032
# day 120, sell 1 unit at price 77.959999, investment -3.646032 %, total balance 8736.030031,
# day 125: buy 1 unit at price 79.489998, total balance 8656.540033
# day 126: buy 1 unit at price 79.900002, total balance 8576.640031
# day 128, sell 1 unit at price 80.559998, investment -1.431549 %, total balance 8657.200029,
# day 130, sell 1 unit at price 81.750000, investment -0.085554 %, total balance 8738.950029,
# day 133: buy 1 unit at price 81.709999, total balance 8657.240030
# day 136: buy 1 unit at price 82.330002, total balance 8574.910028
# day 138, sell 1 unit at price 82.239998, investment 1.056772 %, total balance 8657.150026,
# day 139: buy 1 unit at price 82.669998, total balance 8574.480028
# day 141, sell 1 unit at price 82.839996, investment 8.174450 %, total balance 8657.320024,
# day 142, sell 1 unit at price 82.720001, investment 8.784850 %, total balance 8740.040025,
# day 143, sell 1 unit at price 81.559998, investment 7.669964 %, total balance 8821.600023,
# day 144, sell 1 unit at price 80.760002, investment 7.336529 %, total balance 8902.360025,
# day 145: buy 1 unit at price 81.500000, total balance 8820.860025
# day 146, sell 1 unit at price 82.089996, investment 10.321182 %, total balance 8902.950021,
# day 147, sell 1 unit at price 76.860001, investment 2.003985 %, total balance 8979.810022,
# day 148: buy 1 unit at price 77.820000, total balance 8901.990022
# day 150: buy 1 unit at price 78.070000, total balance 8823.920022
# day 151, sell 1 unit at price 77.239998, investment -1.151780 %, total balance 8901.160020,
# day 154: buy 1 unit at price 75.419998, total balance 8825.740022
# day 155: buy 1 unit at price 75.220001, total balance 8750.520021
# day 156, sell 1 unit at price 74.540001, investment -4.741213 %, total balance 8825.060022,
# day 158, sell 1 unit at price 75.559998, investment -3.153037 %, total balance 8900.620020,
# day 159, sell 1 unit at price 74.910004, investment -7.174713 %, total balance 8975.530024,
# day 160: buy 1 unit at price 74.900002, total balance 8900.630022
# day 161: buy 1 unit at price 75.260002, total balance 8825.370020
# day 162: buy 1 unit at price 75.110001, total balance 8750.260019
# day 164: buy 1 unit at price 76.610001, total balance 8673.650018
# day 165: buy 1 unit at price 76.660004, total balance 8596.990014
# day 166, sell 1 unit at price 77.690002, investment -2.899637 %, total balance 8674.680016,
# day 168: buy 1 unit at price 78.430000, total balance 8596.250016
# day 171: buy 1 unit at price 75.720001, total balance 8520.530015
# day 172: buy 1 unit at price 75.730003, total balance 8444.800012
# day 173: buy 1 unit at price 75.559998, total balance 8369.240014
# day 174: buy 1 unit at price 76.610001, total balance 8292.630013
# day 175: buy 1 unit at price 75.699997, total balance 8216.930016
# day 176: buy 1 unit at price 77.199997, total balance 8139.730019
# day 177, sell 1 unit at price 76.279999, investment -3.686866 %, total balance 8216.010018,
# day 178: buy 1 unit at price 75.959999, total balance 8140.050019
# day 180, sell 1 unit at price 76.099998, investment -3.303684 %, total balance 8216.150017,
# day 182: buy 1 unit at price 77.610001, total balance 8138.540016
# day 183, sell 1 unit at price 77.269997, investment -2.792805 %, total balance 8215.810013,
# day 184, sell 1 unit at price 76.820000, investment -3.854821 %, total balance 8292.630013,
# day 185, sell 1 unit at price 76.790001, investment -6.021292 %, total balance 8369.420014,
# day 186, sell 1 unit at price 76.760002, investment -6.765456 %, total balance 8446.180016,
# day 187: buy 1 unit at price 77.150002, total balance 8369.030014
# day 188: buy 1 unit at price 76.980003, total balance 8292.050011
# day 189: buy 1 unit at price 77.279999, total balance 8214.770012
# day 191: buy 1 unit at price 76.099998, total balance 8138.670014
# day 193, sell 1 unit at price 74.110001, investment -10.354418 %, total balance 8212.780015,
# day 194: buy 1 unit at price 73.970001, total balance 8138.810014
# day 195: buy 1 unit at price 71.440002, total balance 8067.370012
# day 196: buy 1 unit at price 70.290001, total balance 7997.080011
# day 197: buy 1 unit at price 72.169998, total balance 7924.910013
# day 201, sell 1 unit at price 73.589996, investment -9.705526 %, total balance 7998.500009,
# day 202: buy 1 unit at price 73.690002, total balance 7924.810007
# day 203: buy 1 unit at price 73.589996, total balance 7851.220011
# day 204, sell 1 unit at price 73.410004, investment -5.666919 %, total balance 7924.630015,
# day 205, sell 1 unit at price 70.150002, investment -10.144739 %, total balance 7994.780017,
# day 206: buy 1 unit at price 71.480003, total balance 7923.300014
# day 208, sell 1 unit at price 69.220001, investment -8.220627 %, total balance 7992.520015,
# day 209, sell 1 unit at price 66.519997, investment -11.566078 %, total balance 8059.040012,
# day 210, sell 1 unit at price 69.029999, investment -7.837120 %, total balance 8128.070011,
# day 212: buy 1 unit at price 69.500000, total balance 8058.570011
# day 213: buy 1 unit at price 69.459999, total balance 7989.110012
# day 214: buy 1 unit at price 69.650002, total balance 7919.460010
# day 219: buy 1 unit at price 69.610001, total balance 7849.850009
# day 220: buy 1 unit at price 67.570000, total balance 7782.280009
# day 221, sell 1 unit at price 68.669998, investment -8.756317 %, total balance 7850.950007,
# day 222, sell 1 unit at price 70.330002, investment -6.363998 %, total balance 7921.280009,
# day 225, sell 1 unit at price 68.669998, investment -10.364186 %, total balance 7989.950007,
# day 226, sell 1 unit at price 67.980003, investment -11.322724 %, total balance 8057.930010,
# day 227: buy 1 unit at price 68.750000, total balance 7989.180010
# day 228, sell 1 unit at price 69.900002, investment -10.875938 %, total balance 8059.080012,
# day 231: buy 1 unit at price 71.230003, total balance 7987.850009
# day 232: buy 1 unit at price 71.930000, total balance 7915.920009
# day 234, sell 1 unit at price 69.400002, investment -8.346538 %, total balance 7985.320011,
# day 236, sell 1 unit at price 67.089996, investment -11.408962 %, total balance 8052.410007,
# day 237: buy 1 unit at price 67.260002, total balance 7985.150005
# day 238, sell 1 unit at price 68.029999, investment -9.965589 %, total balance 8053.180004,
# day 240, sell 1 unit at price 67.769997, investment -11.538969 %, total balance 8120.950001,
# day 242, sell 1 unit at price 64.620003, investment -14.636717 %, total balance 8185.570004,
# day 243: buy 1 unit at price 64.230003, total balance 8121.340001
# day 245, sell 1 unit at price 60.090000, investment -22.163209 %, total balance 8181.430001,
# day 247, sell 1 unit at price 62.360001, investment -17.904158 %, total balance 8243.790002,
# day 249: buy 1 unit at price 62.930000, total balance 8180.860002
# day 252, sell 1 unit at price 61.099998, investment -21.273035 %, total balance 8241.960000,
# day 254, sell 1 unit at price 63.599998, investment -17.563193 %, total balance 8305.559998,
# day 257: buy 1 unit at price 64.809998, total balance 8240.750000
# day 258: buy 1 unit at price 64.919998, total balance 8175.830002
# day 259, sell 1 unit at price 64.629997, investment -16.043135 %, total balance 8240.459999,
# day 261: buy 1 unit at price 65.790001, total balance 8174.669998
# day 265, sell 1 unit at price 67.059998, investment -13.224639 %, total balance 8241.729996,
# day 267, sell 1 unit at price 70.019997, investment -7.989489 %, total balance 8311.749993,
# day 268, sell 1 unit at price 68.949997, investment -6.786540 %, total balance 8380.699990,
# day 269: buy 1 unit at price 68.660004, total balance 8312.039986
# day 270, sell 1 unit at price 69.800003, investment -2.295631 %, total balance 8381.839989,
# day 271, sell 1 unit at price 69.680000, investment -0.867835 %, total balance 8451.519989,
# day 274, sell 1 unit at price 71.209999, investment -1.330191 %, total balance 8522.729988,
# day 276: buy 1 unit at price 72.989998, total balance 8449.739990
# day 278, sell 1 unit at price 72.970001, investment -0.977067 %, total balance 8522.709991,
# day 282, sell 1 unit at price 73.559998, investment -0.040764 %, total balance 8596.269989,
# day 284: buy 1 unit at price 72.250000, total balance 8524.019989
# day 285: buy 1 unit at price 71.339996, total balance 8452.679993
# day 286, sell 1 unit at price 72.379997, investment 1.259085 %, total balance 8525.059990,
# day 288: buy 1 unit at price 72.040001, total balance 8453.019989
# day 289, sell 1 unit at price 71.309998, investment 2.604314 %, total balance 8524.329987,
# day 292: buy 1 unit at price 71.760002, total balance 8452.569985
# day 293: buy 1 unit at price 71.389999, total balance 8381.179986
# day 294: buy 1 unit at price 71.459999, total balance 8309.719987
# day 295, sell 1 unit at price 72.330002, investment 4.131879 %, total balance 8382.049989,
# day 296: buy 1 unit at price 71.150002, total balance 8310.899987
# day 297: buy 1 unit at price 72.349998, total balance 8238.549989
# day 298: buy 1 unit at price 71.779999, total balance 8166.769990
# day 299, sell 1 unit at price 71.209999, investment 2.239766 %, total balance 8237.979989,
# day 300: buy 1 unit at price 70.930000, total balance 8167.049989
# day 305, sell 1 unit at price 72.199997, investment 3.720724 %, total balance 8239.249986,
# day 306, sell 1 unit at price 70.889999, investment 4.913422 %, total balance 8310.139985,
# day 308, sell 1 unit at price 71.089996, investment 3.403631 %, total balance 8381.229981,
# day 310: buy 1 unit at price 71.580002, total balance 8309.649979
# day 311: buy 1 unit at price 72.449997, total balance 8237.199982
# day 313, sell 1 unit at price 73.570000, investment 3.285128 %, total balance 8310.769982,
# day 317, sell 1 unit at price 74.410004, investment 3.447802 %, total balance 8385.179986,
# day 321, sell 1 unit at price 74.290001, investment 10.451976 %, total balance 8459.469987,
# day 322, sell 1 unit at price 74.320000, investment 15.709165 %, total balance 8533.789987,
# day 324: buy 1 unit at price 72.150002, total balance 8461.639985
# day 325: buy 1 unit at price 71.339996, total balance 8390.299989
# day 328, sell 1 unit at price 72.669998, investment 15.477512 %, total balance 8462.969987,
# day 329: buy 1 unit at price 72.930000, total balance 8390.039987
# day 330: buy 1 unit at price 73.370003, total balance 8316.669984
# day 331, sell 1 unit at price 72.400002, investment 11.711162 %, total balance 8389.069986,
# day 334: buy 1 unit at price 66.610001, total balance 8322.459985
# day 336, sell 1 unit at price 59.599998, investment -8.194701 %, total balance 8382.059983,
# day 337: buy 1 unit at price 58.509998, total balance 8323.549985
# day 340: buy 1 unit at price 59.130001, total balance 8264.419984
# day 341: buy 1 unit at price 56.880001, total balance 8207.539983
# day 342, sell 1 unit at price 57.750000, investment -12.220704 %, total balance 8265.289983,
# day 343: buy 1 unit at price 58.599998, total balance 8206.689985
# day 344: buy 1 unit at price 58.639999, total balance 8148.049986
# day 345: buy 1 unit at price 59.439999, total balance 8088.609987
# day 346, sell 1 unit at price 59.990002, investment -12.627442 %, total balance 8148.599989,
# day 347: buy 1 unit at price 61.000000, total balance 8087.599989
# day 348, sell 1 unit at price 61.500000, investment -15.741880 %, total balance 8149.099989,
# day 349: buy 1 unit at price 61.080002, total balance 8088.019987
# day 350, sell 1 unit at price 61.869999, investment -14.366783 %, total balance 8149.889986,
# day 351: buy 1 unit at price 62.070000, total balance 8087.819986
# day 352, sell 1 unit at price 61.880001, investment -13.260437 %, total balance 8149.699987,
# day 353: buy 1 unit at price 62.360001, total balance 8087.339986
# day 355: buy 1 unit at price 60.540001, total balance 8026.799985
# day 356: buy 1 unit at price 61.099998, total balance 7965.699987
# day 357: buy 1 unit at price 62.180000, total balance 7903.519987
# day 358: buy 1 unit at price 61.900002, total balance 7841.619985
# day 361, sell 1 unit at price 63.369999, investment -12.034983 %, total balance 7904.989984,
# day 362, sell 1 unit at price 62.150002, investment -13.391861 %, total balance 7967.139986,
# day 364: buy 1 unit at price 61.639999, total balance 7905.499987
# day 369, sell 1 unit at price 64.459999, investment -9.707242 %, total balance 7969.959986,
# day 370, sell 1 unit at price 64.050003, investment -10.369432 %, total balance 8034.009989,
# day 372: buy 1 unit at price 63.060001, total balance 7970.949988
# day 374: buy 1 unit at price 63.389999, total balance 7907.559989
# day 375: buy 1 unit at price 64.279999, total balance 7843.279990
# day 376, sell 1 unit at price 64.360001, investment -9.543220 %, total balance 7907.639991,
# day 378: buy 1 unit at price 64.709999, total balance 7842.929992
# day 380: buy 1 unit at price 64.379997, total balance 7778.549995
# day 381: buy 1 unit at price 64.059998, total balance 7714.489997
# day 383, sell 1 unit at price 65.860001, investment -8.970279 %, total balance 7780.349998,
# day 385: buy 1 unit at price 65.949997, total balance 7714.400001
# day 387, sell 1 unit at price 65.930000, investment -8.149901 %, total balance 7780.330001,
# day 388, sell 1 unit at price 65.139999, investment -8.162979 %, total balance 7845.470000,
# day 389: buy 1 unit at price 65.550003, total balance 7779.919997
# day 390, sell 1 unit at price 65.870003, investment -7.977087 %, total balance 7845.790000,
# day 392: buy 1 unit at price 65.779999, total balance 7780.010001
# day 393, sell 1 unit at price 66.400002, investment -8.350580 %, total balance 7846.410003,
# day 394, sell 1 unit at price 66.040001, investment -8.468470 %, total balance 7912.450004,
# day 395, sell 1 unit at price 65.330002, investment -8.424438 %, total balance 7977.780006,
# day 396, sell 1 unit at price 65.139999, investment -10.681477 %, total balance 8042.920005,
# day 397, sell 1 unit at price 66.410004, investment -9.486164 %, total balance 8109.330009,
# day 398: buy 1 unit at price 63.490002, total balance 8045.840007
# day 399, sell 1 unit at price 62.040001, investment -6.860832 %, total balance 8107.880008,
# day 400: buy 1 unit at price 62.580002, total balance 8045.300006
# day 402, sell 1 unit at price 63.959999, investment 9.314649 %, total balance 8109.260005,
# day 404, sell 1 unit at price 61.169998, investment 3.450020 %, total balance 8170.430003,
# day 405: buy 1 unit at price 61.740002, total balance 8108.690001
# day 406: buy 1 unit at price 60.650002, total balance 8048.039999
# day 408, sell 1 unit at price 61.220001, investment 7.630098 %, total balance 8109.260000,
# day 409: buy 1 unit at price 61.860001, total balance 8047.399999
# day 411, sell 1 unit at price 61.939999, investment 5.699661 %, total balance 8109.339998,
# day 414: buy 1 unit at price 59.869999, total balance 8049.469999
# day 416: buy 1 unit at price 60.240002, total balance 7989.229997
# day 417, sell 1 unit at price 61.380001, investment 4.672582 %, total balance 8050.609998,
# day 421: buy 1 unit at price 64.260002, total balance 7986.349996
# day 422: buy 1 unit at price 64.449997, total balance 7921.899999
# day 423, sell 1 unit at price 64.180000, investment 7.974430 %, total balance 7986.079999,
# day 425, sell 1 unit at price 65.360001, investment 7.147543 %, total balance 8051.440000,
# day 426: buy 1 unit at price 64.839996, total balance 7986.600004
# day 427, sell 1 unit at price 64.330002, investment 5.320890 %, total balance 8050.930006,
# day 429: buy 1 unit at price 64.000000, total balance 7986.930006
# day 430, sell 1 unit at price 63.509998, investment 2.319958 %, total balance 8050.440004,
# day 431: buy 1 unit at price 63.470001, total balance 7986.970003
# day 432: buy 1 unit at price 61.799999, total balance 7925.170004
# day 433: buy 1 unit at price 60.830002, total balance 7864.340002
# day 435, sell 1 unit at price 60.189999, investment -3.479798 %, total balance 7924.530001,
# day 437: buy 1 unit at price 58.750000, total balance 7865.780001
# day 439: buy 1 unit at price 60.619999, total balance 7805.160002
# day 440: buy 1 unit at price 59.939999, total balance 7745.220003
# day 441, sell 1 unit at price 60.180000, investment -0.594650 %, total balance 7805.400003,
# day 442: buy 1 unit at price 60.509998, total balance 7744.890005
# day 443: buy 1 unit at price 60.279999, total balance 7684.610006
# day 445, sell 1 unit at price 59.439999, investment -2.716856 %, total balance 7744.050005,
# day 447: buy 1 unit at price 60.610001, total balance 7683.440004
# day 448: buy 1 unit at price 60.380001, total balance 7623.060003
# day 449: buy 1 unit at price 61.340000, total balance 7561.720003
# day 450: buy 1 unit at price 61.389999, total balance 7500.330004
# day 451, sell 1 unit at price 61.380001, investment -1.286586 %, total balance 7561.710005,
# day 452: buy 1 unit at price 60.639999, total balance 7501.070006
# day 453: buy 1 unit at price 60.779999, total balance 7440.290007
# day 455: buy 1 unit at price 60.349998, total balance 7379.940009
# day 460, sell 1 unit at price 59.889999, investment -3.247178 %, total balance 7439.830008,
# day 462, sell 1 unit at price 61.230000, investment -0.665151 %, total balance 7501.060008,
# day 463: buy 1 unit at price 62.070000, total balance 7438.990008
# day 465: buy 1 unit at price 62.259998, total balance 7376.730010
# day 466, sell 1 unit at price 63.029999, investment -0.047577 %, total balance 7439.760009,
# day 468: buy 1 unit at price 62.639999, total balance 7377.120010
# day 469, sell 1 unit at price 62.840000, investment -0.867643 %, total balance 7439.960010,
# day 470, sell 1 unit at price 62.509998, investment -2.753580 %, total balance 7502.470008,
# day 471: buy 1 unit at price 63.110001, total balance 7439.360007
# day 472: buy 1 unit at price 63.380001, total balance 7375.980006
# day 473: buy 1 unit at price 63.630001, total balance 7312.350005
# day 474: buy 1 unit at price 63.919998, total balance 7248.430007
# day 475, sell 1 unit at price 63.509998, investment -1.854429 %, total balance 7311.940005,
# day 476: buy 1 unit at price 63.400002, total balance 7248.540003
# day 478, sell 1 unit at price 63.360001, investment -1.584337 %, total balance 7311.900004,
# day 480: buy 1 unit at price 64.150002, total balance 7247.750002
# day 482: buy 1 unit at price 63.540001, total balance 7184.210001
# day 484: buy 1 unit at price 62.400002, total balance 7121.809999
# day 485, sell 1 unit at price 62.209999, investment -2.887916 %, total balance 7184.019998,
# day 486, sell 1 unit at price 62.660000, investment -4.988623 %, total balance 7246.679998,
# day 487, sell 1 unit at price 61.880001, investment -5.598782 %, total balance 7308.559999,
# day 488, sell 1 unit at price 61.099998, investment -7.114626 %, total balance 7369.659997,
# day 493, sell 1 unit at price 61.759998, investment -2.724845 %, total balance 7431.419995,
# day 494, sell 1 unit at price 62.320000, investment -0.415471 %, total balance 7493.739995,
# day 495, sell 1 unit at price 62.709999, investment 1.571100 %, total balance 7556.449994,
# day 496, sell 1 unit at price 63.220001, investment 4.237426 %, total balance 7619.669995,
# day 499, sell 1 unit at price 62.119999, investment 0.420301 %, total balance 7681.789994,
# day 500, sell 1 unit at price 62.160000, investment 3.824956 %, total balance 7743.949994,
# day 501, sell 1 unit at price 61.650002, investment 2.340637 %, total balance 7805.599996,
# day 502, sell 1 unit at price 62.020000, investment -3.485842 %, total balance 7867.619996,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Q-learning agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Q-learning agent'

class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: -56.080002.3, cost: 0.405325, total money: 44.899990
# epoch: 20, total rewards: -232.370004.3, cost: 0.341718, total money: 64.569998
# epoch: 30, total rewards: -369.100017.3, cost: 0.301792, total money: 12.459989
# epoch: 40, total rewards: -615.449991.3, cost: 0.268549, total money: 103.640000
# epoch: 50, total rewards: -749.359991.3, cost: 0.240714, total money: 200.129997
# epoch: 60, total rewards: -660.130004.3, cost: 0.124322, total money: 2452.469976
# epoch: 70, total rewards: -559.989993.3, cost: 0.079935, total money: 3627.999981
# epoch: 80, total rewards: -589.969988.3, cost: 0.076761, total money: 3720.299992
# epoch: 90, total rewards: -552.460002.3, cost: 0.067178, total money: 3976.659985
# epoch: 100, total rewards: -512.569996.3, cost: 0.045011, total money: 4791.249984
# epoch: 110, total rewards: -529.850003.3, cost: 0.043088, total money: 4854.669970
# epoch: 120, total rewards: -528.570002.3, cost: 0.039476, total money: 5002.369969
# epoch: 130, total rewards: -526.109991.3, cost: 0.038208, total money: 5067.489980
# epoch: 140, total rewards: -501.819995.3, cost: 0.040118, total money: 4895.029980
# epoch: 150, total rewards: -490.939998.3, cost: 0.031073, total money: 5403.689975
# epoch: 160, total rewards: -500.909991.3, cost: 0.037277, total money: 5094.079983
# epoch: 170, total rewards: -515.149985.3, cost: 0.030991, total money: 5366.919991
# epoch: 180, total rewards: -497.119994.3, cost: 0.036320, total money: 5085.089981
# epoch: 190, total rewards: -487.920001.3, cost: 0.043163, total money: 4826.199979
# epoch: 200, total rewards: -454.949996.3, cost: 0.034971, total money: 5206.439980

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 8: buy 1 unit at price 74.559998, total balance 9925.440002
# day 9, sell 1 unit at price 74.730003, investment 0.228011 %, total balance 10000.170005,
# day 10: buy 1 unit at price 75.839996, total balance 9924.330009
# day 11: buy 1 unit at price 76.750000, total balance 9847.580009
# day 12: buy 1 unit at price 77.290001, total balance 9770.290008
# day 15: buy 1 unit at price 78.449997, total balance 9691.840011
# day 16: buy 1 unit at price 77.949997, total balance 9613.890014
# day 17: buy 1 unit at price 78.430000, total balance 9535.460014
# day 18: buy 1 unit at price 78.150002, total balance 9457.310012
# day 19: buy 1 unit at price 77.760002, total balance 9379.550010
# day 20: buy 1 unit at price 77.980003, total balance 9301.570007
# day 21: buy 1 unit at price 77.500000, total balance 9224.070007
# day 22: buy 1 unit at price 75.720001, total balance 9148.350006
# day 23, sell 1 unit at price 73.290001, investment -3.362335 %, total balance 9221.640007,
# day 24, sell 1 unit at price 73.900002, investment -3.713352 %, total balance 9295.540009,
# day 25: buy 1 unit at price 76.519997, total balance 9219.020012
# day 26: buy 1 unit at price 75.160004, total balance 9143.860008
# day 28: buy 1 unit at price 77.430000, total balance 9066.430008
# day 31, sell 1 unit at price 81.370003, investment 5.278823 %, total balance 9147.800011,
# day 34, sell 1 unit at price 81.800003, investment 4.270244 %, total balance 9229.600014,
# day 35: buy 1 unit at price 81.610001, total balance 9147.990013
# day 36, sell 1 unit at price 82.529999, investment 5.875564 %, total balance 9230.520012,
# day 37: buy 1 unit at price 82.970001, total balance 9147.550011
# day 38, sell 1 unit at price 82.510002, investment 5.202094 %, total balance 9230.060013,
# day 39: buy 1 unit at price 82.019997, total balance 9148.040016
# day 40: buy 1 unit at price 80.650002, total balance 9067.390014
# day 41: buy 1 unit at price 81.279999, total balance 8986.110015
# day 44: buy 1 unit at price 83.250000, total balance 8902.860015
# day 45: buy 1 unit at price 83.220001, total balance 8819.640014
# day 47, sell 1 unit at price 84.070000, investment 7.575173 %, total balance 8903.710014,
# day 48, sell 1 unit at price 83.790001, investment 7.754628 %, total balance 8987.500015,
# day 50, sell 1 unit at price 84.830002, investment 8.784302 %, total balance 9072.330017,
# day 53, sell 1 unit at price 84.309998, investment 8.787094 %, total balance 9156.640015,
# day 54: buy 1 unit at price 83.349998, total balance 9073.290017
# day 56: buy 1 unit at price 79.260002, total balance 8994.030015
# day 57: buy 1 unit at price 81.629997, total balance 8912.400018
# day 58: buy 1 unit at price 80.080002, total balance 8832.320016
# day 59: buy 1 unit at price 79.669998, total balance 8752.650018
# day 60, sell 1 unit at price 80.500000, investment 6.312730 %, total balance 8833.150018,
# day 61: buy 1 unit at price 79.209999, total balance 8753.940019
# day 63, sell 1 unit at price 80.720001, investment 5.488767 %, total balance 8834.660020,
# day 65: buy 1 unit at price 79.070000, total balance 8755.590020
# day 66, sell 1 unit at price 78.910004, investment 4.989356 %, total balance 8834.500024,
# day 67, sell 1 unit at price 80.400002, investment 3.835725 %, total balance 8914.900026,
# day 68, sell 1 unit at price 79.930000, investment -2.058572 %, total balance 8994.830026,
# day 70: buy 1 unit at price 80.820000, total balance 8914.010026
# day 71, sell 1 unit at price 81.769997, investment -1.446311 %, total balance 8995.780023,
# day 72: buy 1 unit at price 82.190002, total balance 8913.590021
# day 73: buy 1 unit at price 82.699997, total balance 8830.890024
# day 74, sell 1 unit at price 82.370003, investment 0.426733 %, total balance 8913.260027,
# day 75: buy 1 unit at price 81.769997, total balance 8831.490030
# day 76, sell 1 unit at price 81.570000, investment 1.140729 %, total balance 8913.060030,
# day 77: buy 1 unit at price 80.800003, total balance 8832.260027
# day 80, sell 1 unit at price 81.620003, investment 0.418312 %, total balance 8913.880030,
# day 81, sell 1 unit at price 81.820000, investment -1.717718 %, total balance 8995.700030,
# day 83, sell 1 unit at price 81.379997, investment -2.211012 %, total balance 9077.080027,
# day 86, sell 1 unit at price 77.860001, investment -6.586679 %, total balance 9154.940028,
# day 87: buy 1 unit at price 75.550003, total balance 9079.390025
# day 91: buy 1 unit at price 75.860001, total balance 9003.530024
# day 92, sell 1 unit at price 75.459999, investment -4.794351 %, total balance 9078.990023,
# day 93, sell 1 unit at price 75.389999, investment -7.644246 %, total balance 9154.380022,
# day 96: buy 1 unit at price 75.750000, total balance 9078.630022
# day 98: buy 1 unit at price 75.760002, total balance 9002.870020
# day 99: buy 1 unit at price 75.930000, total balance 8926.940020
# day 100: buy 1 unit at price 75.779999, total balance 8851.160021
# day 102, sell 1 unit at price 75.690002, investment -5.482018 %, total balance 8926.850023,
# day 104: buy 1 unit at price 76.870003, total balance 8849.980020
# day 105: buy 1 unit at price 77.220001, total balance 8772.760019
# day 109: buy 1 unit at price 77.110001, total balance 8695.650018
# day 112: buy 1 unit at price 78.019997, total balance 8617.630021
# day 113, sell 1 unit at price 78.550003, investment -1.405793 %, total balance 8696.180024,
# day 117: buy 1 unit at price 78.820000, total balance 8617.360024
# day 118: buy 1 unit at price 77.680000, total balance 8539.680024
# day 119: buy 1 unit at price 78.699997, total balance 8460.980027
# day 123, sell 1 unit at price 79.019997, investment -0.239871 %, total balance 8540.000024,
# day 125, sell 1 unit at price 79.489998, investment 0.531172 %, total balance 8619.490022,
# day 127: buy 1 unit at price 79.889999, total balance 8539.600023
# day 128, sell 1 unit at price 80.559998, investment -0.321705 %, total balance 8620.160021,
# day 129: buy 1 unit at price 80.980003, total balance 8539.180018
# day 134: buy 1 unit at price 81.959999, total balance 8457.220019
# day 137: buy 1 unit at price 82.379997, total balance 8374.840022
# day 138: buy 1 unit at price 82.239998, total balance 8292.600024
# day 139: buy 1 unit at price 82.669998, total balance 8209.930026
# day 140: buy 1 unit at price 82.260002, total balance 8127.670024
# day 142: buy 1 unit at price 82.720001, total balance 8044.950023
# day 143, sell 1 unit at price 81.559998, investment -0.766521 %, total balance 8126.510021,
# day 144, sell 1 unit at price 80.760002, investment -2.345822 %, total balance 8207.270023,
# day 145, sell 1 unit at price 81.500000, investment -0.330191 %, total balance 8288.770023,
# day 146, sell 1 unit at price 82.089996, investment 1.596526 %, total balance 8370.860019,
# day 150: buy 1 unit at price 78.070000, total balance 8292.790019
# day 152: buy 1 unit at price 76.260002, total balance 8216.530017
# day 153, sell 1 unit at price 75.559998, investment 0.013230 %, total balance 8292.090015,
# day 154: buy 1 unit at price 75.419998, total balance 8216.670017
# day 155, sell 1 unit at price 75.220001, investment -0.843659 %, total balance 8291.890018,
# day 159, sell 1 unit at price 74.910004, investment -1.108906 %, total balance 8366.800022,
# day 160: buy 1 unit at price 74.900002, total balance 8291.900020
# day 163, sell 1 unit at price 75.860001, investment 0.131994 %, total balance 8367.760021,
# day 164: buy 1 unit at price 76.610001, total balance 8291.150020
# day 165: buy 1 unit at price 76.660004, total balance 8214.490016
# day 166: buy 1 unit at price 77.690002, total balance 8136.800014
# day 173: buy 1 unit at price 75.559998, total balance 8061.240016
# day 174, sell 1 unit at price 76.610001, investment 0.895563 %, total balance 8137.850017,
# day 177: buy 1 unit at price 76.279999, total balance 8061.570018
# day 178: buy 1 unit at price 75.959999, total balance 7985.610019
# day 181, sell 1 unit at price 77.169998, investment 1.834256 %, total balance 8062.780017,
# day 185, sell 1 unit at price 76.790001, investment -0.104074 %, total balance 8139.570018,
# day 186: buy 1 unit at price 76.760002, total balance 8062.810016
# day 187: buy 1 unit at price 77.150002, total balance 7985.660014
# day 188: buy 1 unit at price 76.980003, total balance 7908.680011
# day 191: buy 1 unit at price 76.099998, total balance 7832.580013
# day 195: buy 1 unit at price 71.440002, total balance 7761.140011
# day 196, sell 1 unit at price 70.290001, investment -8.974359 %, total balance 7831.430012,
# day 201: buy 1 unit at price 73.589996, total balance 7757.840016
# day 202, sell 1 unit at price 73.690002, investment -4.435221 %, total balance 7831.530018,
# day 203: buy 1 unit at price 73.589996, total balance 7757.940022
# day 205, sell 1 unit at price 70.150002, investment -10.087151 %, total balance 7828.090024,
# day 206: buy 1 unit at price 71.480003, total balance 7756.610021
# day 207: buy 1 unit at price 70.529999, total balance 7686.080022
# day 208: buy 1 unit at price 69.220001, total balance 7616.860021
# day 209: buy 1 unit at price 66.519997, total balance 7550.340024
# day 214: buy 1 unit at price 69.650002, total balance 7480.690022
# day 217, sell 1 unit at price 70.339996, investment -10.758696 %, total balance 7551.030018,
# day 221, sell 1 unit at price 68.669998, investment -11.598870 %, total balance 7619.700016,
# day 222: buy 1 unit at price 70.330002, total balance 7549.370014
# day 225: buy 1 unit at price 68.669998, total balance 7480.700016
# day 226: buy 1 unit at price 67.980003, total balance 7412.720013
# day 229, sell 1 unit at price 70.760002, investment -10.088939 %, total balance 7483.480015,
# day 235: buy 1 unit at price 68.000000, total balance 7415.480015
# day 236, sell 1 unit at price 67.089996, investment -16.022034 %, total balance 7482.570011,
# day 237: buy 1 unit at price 67.260002, total balance 7415.310009
# day 238: buy 1 unit at price 68.029999, total balance 7347.280010
# day 239: buy 1 unit at price 69.080002, total balance 7278.200008
# day 241: buy 1 unit at price 64.669998, total balance 7213.530010
# day 242, sell 1 unit at price 64.620003, investment -20.202518 %, total balance 7278.150013,
# day 244: buy 1 unit at price 62.779999, total balance 7215.370014
# day 245, sell 1 unit at price 60.090000, investment -26.683747 %, total balance 7275.460014,
# day 246, sell 1 unit at price 60.020000, investment -27.142508 %, total balance 7335.480014,
# day 248: buy 1 unit at price 63.080002, total balance 7272.400012
# day 256, sell 1 unit at price 64.260002, investment -21.862836 %, total balance 7336.660014,
# day 257: buy 1 unit at price 64.809998, total balance 7271.850016
# day 259: buy 1 unit at price 64.629997, total balance 7207.220019
# day 262: buy 1 unit at price 66.550003, total balance 7140.670016
# day 263: buy 1 unit at price 67.820000, total balance 7072.850016
# day 267: buy 1 unit at price 70.019997, total balance 7002.830019
# day 268, sell 1 unit at price 68.949997, investment -16.596107 %, total balance 7071.780016,
# day 270: buy 1 unit at price 69.800003, total balance 7001.980013
# day 271: buy 1 unit at price 69.680000, total balance 6932.300013
# day 274, sell 1 unit at price 71.209999, investment -13.433021 %, total balance 7003.510012,
# day 276: buy 1 unit at price 72.989998, total balance 6930.520014
# day 277, sell 1 unit at price 73.160004, investment -11.557056 %, total balance 7003.680018,
# day 278: buy 1 unit at price 72.970001, total balance 6930.710017
# day 279, sell 1 unit at price 73.449997, investment -5.917770 %, total balance 7004.160014,
# day 280: buy 1 unit at price 73.580002, total balance 6930.580012
# day 282: buy 1 unit at price 73.559998, total balance 6857.020014
# day 284, sell 1 unit at price 72.250000, investment -5.258329 %, total balance 6929.270014,
# day 285: buy 1 unit at price 71.339996, total balance 6857.930018
# day 286, sell 1 unit at price 72.379997, investment -4.030763 %, total balance 6930.310015,
# day 287, sell 1 unit at price 72.250000, investment -3.538053 %, total balance 7002.560015,
# day 289: buy 1 unit at price 71.309998, total balance 6931.250017
# day 290: buy 1 unit at price 70.980003, total balance 6860.270014
# day 292, sell 1 unit at price 71.760002, investment -6.330765 %, total balance 6932.030016,
# day 293, sell 1 unit at price 71.389999, investment -6.874517 %, total balance 7003.420015,
# day 294: buy 1 unit at price 71.459999, total balance 6931.960016
# day 295: buy 1 unit at price 72.330002, total balance 6859.630014
# day 296, sell 1 unit at price 71.150002, investment -8.418072 %, total balance 6930.780016,
# day 298: buy 1 unit at price 71.779999, total balance 6859.000017
# day 299, sell 1 unit at price 71.209999, investment -5.757013 %, total balance 6930.210016,
# day 300: buy 1 unit at price 70.930000, total balance 6859.280016
# day 301: buy 1 unit at price 72.129997, total balance 6787.150019
# day 302: buy 1 unit at price 71.879997, total balance 6715.270022
# day 304, sell 1 unit at price 71.709999, investment -5.991086 %, total balance 6786.980021,
# day 305, sell 1 unit at price 72.199997, investment -4.949976 %, total balance 6859.180018,
# day 306: buy 1 unit at price 70.889999, total balance 6788.290019
# day 310: buy 1 unit at price 71.580002, total balance 6716.710017
# day 311: buy 1 unit at price 72.449997, total balance 6644.260020
# day 312, sell 1 unit at price 73.849998, investment -3.791042 %, total balance 6718.110018,
# day 314, sell 1 unit at price 74.180000, investment -3.849646 %, total balance 6792.290018,
# day 315, sell 1 unit at price 73.790001, investment -4.143936 %, total balance 6866.080019,
# day 318, sell 1 unit at price 74.370003, investment -2.273318 %, total balance 6940.450022,
# day 319, sell 1 unit at price 74.599998, investment 4.423287 %, total balance 7015.050020,
# day 320: buy 1 unit at price 74.190002, total balance 6940.860018
# day 322: buy 1 unit at price 74.320000, total balance 6866.540018
# day 323: buy 1 unit at price 71.900002, total balance 6794.640016
# day 324: buy 1 unit at price 72.150002, total balance 6722.490014
# day 325, sell 1 unit at price 71.339996, investment -3.057481 %, total balance 6793.830010,
# day 326: buy 1 unit at price 71.480003, total balance 6722.350007
# day 328: buy 1 unit at price 72.669998, total balance 6649.680009
# day 330, sell 1 unit at price 73.370003, investment -0.298944 %, total balance 6723.050012,
# day 331, sell 1 unit at price 72.400002, investment 1.287072 %, total balance 6795.450014,
# day 333, sell 1 unit at price 72.180000, investment 2.339431 %, total balance 6867.630014,
# day 334: buy 1 unit at price 66.610001, total balance 6801.020013
# day 335, sell 1 unit at price 59.250000, investment -14.403353 %, total balance 6860.270013,
# day 336: buy 1 unit at price 59.599998, total balance 6800.670015
# day 337: buy 1 unit at price 58.509998, total balance 6742.160017
# day 338: buy 1 unit at price 58.980000, total balance 6683.180017
# day 339: buy 1 unit at price 59.099998, total balance 6624.080019
# day 340: buy 1 unit at price 59.130001, total balance 6564.950018
# day 342, sell 1 unit at price 57.750000, investment -13.184001 %, total balance 6622.700018,
# day 346: buy 1 unit at price 59.990002, total balance 6562.710016
# day 347, sell 1 unit at price 61.000000, investment -12.419242 %, total balance 6623.710016,
# day 353: buy 1 unit at price 62.360001, total balance 6561.350015
# day 354: buy 1 unit at price 61.930000, total balance 6499.420015
# day 355: buy 1 unit at price 60.540001, total balance 6438.880014
# day 356: buy 1 unit at price 61.099998, total balance 6377.780016
# day 357: buy 1 unit at price 62.180000, total balance 6315.600016
# day 366: buy 1 unit at price 63.720001, total balance 6251.880015
# day 367: buy 1 unit at price 62.610001, total balance 6189.270014
# day 368, sell 1 unit at price 64.169998, investment -8.758714 %, total balance 6253.440012,
# day 371, sell 1 unit at price 63.160000, investment -8.023880 %, total balance 6316.600012,
# day 372: buy 1 unit at price 63.060001, total balance 6253.540011
# day 373: buy 1 unit at price 63.060001, total balance 6190.480010
# day 374, sell 1 unit at price 63.389999, investment -6.751991 %, total balance 6253.870009,
# day 376: buy 1 unit at price 64.360001, total balance 6189.510008
# day 377, sell 1 unit at price 64.180000, investment -5.617647 %, total balance 6253.690008,
# day 379, sell 1 unit at price 64.199997, investment -4.549517 %, total balance 6317.890005,
# day 380: buy 1 unit at price 64.379997, total balance 6253.510008
# day 382, sell 1 unit at price 65.290001, investment -4.027632 %, total balance 6318.800009,
# day 383: buy 1 unit at price 65.860001, total balance 6252.940008
# day 386, sell 1 unit at price 65.239998, investment -5.558778 %, total balance 6318.180006,
# day 388: buy 1 unit at price 65.139999, total balance 6253.040007
# day 389: buy 1 unit at price 65.550003, total balance 6187.490004
# day 390: buy 1 unit at price 65.870003, total balance 6121.620001
# day 391, sell 1 unit at price 65.760002, investment 1.685486 %, total balance 6187.380003,
# day 392: buy 1 unit at price 65.779999, total balance 6121.600004
# day 394, sell 1 unit at price 66.040001, investment 5.192740 %, total balance 6187.640005,
# day 395: buy 1 unit at price 65.330002, total balance 6122.310003
# day 397: buy 1 unit at price 66.410004, total balance 6055.899999
# day 398: buy 1 unit at price 63.490002, total balance 5992.409997
# day 400: buy 1 unit at price 62.580002, total balance 5929.829995
# day 403: buy 1 unit at price 62.459999, total balance 5867.369996
# day 404, sell 1 unit at price 61.169998, investment -3.027907 %, total balance 5928.539994,
# day 406: buy 1 unit at price 60.650002, total balance 5867.889992
# day 407: buy 1 unit at price 60.580002, total balance 5807.309990
# day 410: buy 1 unit at price 61.580002, total balance 5745.729988
# day 411, sell 1 unit at price 61.939999, investment -4.428328 %, total balance 5807.669987,
# day 412: buy 1 unit at price 61.200001, total balance 5746.469986
# day 414, sell 1 unit at price 59.869999, investment -7.364998 %, total balance 5806.339985,
# day 415: buy 1 unit at price 59.700001, total balance 5746.639984
# day 416: buy 1 unit at price 60.240002, total balance 5686.399982
# day 417: buy 1 unit at price 61.380001, total balance 5625.019981
# day 419, sell 1 unit at price 61.480000, investment -7.618336 %, total balance 5686.499981,
# day 424: buy 1 unit at price 64.739998, total balance 5621.759983
# day 425: buy 1 unit at price 65.360001, total balance 5556.399982
# day 426, sell 1 unit at price 64.839996, investment -4.393990 %, total balance 5621.239978,
# day 428, sell 1 unit at price 63.990002, investment -8.611818 %, total balance 5685.229980,
# day 429: buy 1 unit at price 64.000000, total balance 5621.229980
# day 431: buy 1 unit at price 63.470001, total balance 5557.759979
# day 432: buy 1 unit at price 61.799999, total balance 5495.959980
# day 434, sell 1 unit at price 59.919998, investment -14.154734 %, total balance 5555.879978,
# day 437, sell 1 unit at price 58.750000, investment -15.685993 %, total balance 5614.629978,
# day 438, sell 1 unit at price 60.270000, investment -17.427043 %, total balance 5674.899978,
# day 439: buy 1 unit at price 60.619999, total balance 5614.279979
# day 440: buy 1 unit at price 59.939999, total balance 5554.339980
# day 442, sell 1 unit at price 60.509998, investment -17.075514 %, total balance 5614.849978,
# day 445, sell 1 unit at price 59.439999, investment -19.217182 %, total balance 5674.289977,
# day 449: buy 1 unit at price 61.340000, total balance 5612.949977
# day 452, sell 1 unit at price 60.639999, investment -17.563893 %, total balance 5673.589976,
# day 453: buy 1 unit at price 60.779999, total balance 5612.809977
# day 455: buy 1 unit at price 60.349998, total balance 5552.459979
# day 458: buy 1 unit at price 60.669998, total balance 5491.789981
# day 462: buy 1 unit at price 61.230000, total balance 5430.559981
# day 463: buy 1 unit at price 62.070000, total balance 5368.489981
# day 464, sell 1 unit at price 61.919998, investment -13.204371 %, total balance 5430.409979,
# day 467, sell 1 unit at price 62.860001, investment -11.849667 %, total balance 5493.269980,
# day 468, sell 1 unit at price 62.639999, investment -11.749794 %, total balance 5555.909979,
# day 470, sell 1 unit at price 62.509998, investment -12.524491 %, total balance 5618.419977,
# day 471: buy 1 unit at price 63.110001, total balance 5555.309976
# day 472: buy 1 unit at price 63.380001, total balance 5491.929975
# day 473: buy 1 unit at price 63.630001, total balance 5428.299974
# day 474: buy 1 unit at price 63.919998, total balance 5364.379976
# day 475, sell 1 unit at price 63.509998, investment -12.194116 %, total balance 5427.889974,
# day 476: buy 1 unit at price 63.400002, total balance 5364.489972
# day 477: buy 1 unit at price 63.189999, total balance 5301.299973
# day 478: buy 1 unit at price 63.360001, total balance 5237.939972
# day 479: buy 1 unit at price 63.730000, total balance 5174.209972
# day 480, sell 1 unit at price 64.150002, investment -10.629698 %, total balance 5238.359974,
# day 481: buy 1 unit at price 64.110001, total balance 5174.249973
# day 482, sell 1 unit at price 63.540001, investment -10.418721 %, total balance 5237.789974,
# day 484, sell 1 unit at price 62.400002, investment -13.489526 %, total balance 5300.189976,
# day 485, sell 1 unit at price 62.209999, investment -13.452975 %, total balance 5362.399975,
# day 486: buy 1 unit at price 62.660000, total balance 5299.739975
# day 487, sell 1 unit at price 61.880001, investment -12.709829 %, total balance 5361.619976,
# day 488: buy 1 unit at price 61.099998, total balance 5300.519978
# day 489, sell 1 unit at price 60.680000, investment -15.227720 %, total balance 5361.199978,
# day 492, sell 1 unit at price 61.660000, investment -14.893026 %, total balance 5422.859978,
# day 498, sell 1 unit at price 62.400002, investment -15.891629 %, total balance 5485.259980,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Evolution Strategy agent

# %%
import pkg_resources
import types

df= df_full.copy()
name = 'Evolution Strategy agent'


def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            name = val.__name__.split('.')[0]
        elif isinstance(val, type):
            name = val.__module__.split('.')[0]
        poorly_named_packages = {'PIL': 'Pillow', 'sklearn': 'scikit-learn'}
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
        yield name


imports = list(set(get_imports()))
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name != 'pip':
        requirements.append((m.project_name, m.version))

for r in requirements:
    print('{}=={}'.format(*r))
# Out:
# tensorflow==1.15.0
# seaborn==0.9.0
# pandas==0.25.3
# numpy==1.17.4
# matplotlib==3.1.2
# google==2.0.3

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
initial_money = 10000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 500, checkpoint = 10)
# Out:
# iter 10. reward: -0.348700
# iter 20. reward: 0.510200
# iter 30. reward: 1.536200
# iter 40. reward: 2.060200
# iter 50. reward: 2.527400
# iter 60. reward: 2.423100
# iter 70. reward: 2.619300
# iter 80. reward: 2.919700
# iter 90. reward: 2.798100
# iter 100. reward: 3.048900
# iter 110. reward: 3.277600
# iter 120. reward: 3.653700
# iter 130. reward: 3.421400
# iter 140. reward: 4.089500
# iter 150. reward: 4.377300
# iter 160. reward: 4.489800
# iter 170. reward: 4.515999
# iter 180. reward: 4.986399
# iter 190. reward: 4.846899
# iter 200. reward: 4.903199
# iter 210. reward: 5.294999
# iter 220. reward: 5.297799
# iter 230. reward: 5.169699
# iter 240. reward: 5.172299
# iter 250. reward: 5.053999
# iter 260. reward: 5.451299
# iter 270. reward: 5.379899
# iter 280. reward: 5.322299
# iter 290. reward: 5.180900
# iter 300. reward: 5.331899
# iter 310. reward: 5.286899
# iter 320. reward: 5.409699
# iter 330. reward: 5.474499
# iter 340. reward: 5.457399
# iter 350. reward: 5.687199
# iter 360. reward: 5.713599
# iter 370. reward: 5.529199
# iter 380. reward: 5.331999
# iter 390. reward: 5.588800
# iter 400. reward: 5.513100
# iter 410. reward: 5.732900
# iter 420. reward: 5.498500
# iter 430. reward: 5.614299
# iter 440. reward: 5.564000
# iter 450. reward: 5.674000
# iter 460. reward: 5.861000
# iter 470. reward: 5.730600
# iter 480. reward: 5.907700
# iter 490. reward: 5.810200
# iter 500. reward: 5.731400
# time taken to train: 129.5800850391388 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 61: buy 1 unit at price 79.209999, total balance 9920.790001
# day 62, sell 1 unit at price 80.050003, investment 1.060477 %, total balance 10000.840004,
# day 63: buy 1 unit at price 80.720001, total balance 9920.120003
# day 64: buy 1 unit at price 80.919998, total balance 9839.200005
# day 65: buy 1 unit at price 79.070000, total balance 9760.130005
# day 66: buy 1 unit at price 78.910004, total balance 9681.220001
# day 67, sell 1 unit at price 80.400002, investment -0.396431 %, total balance 9761.620003,
# day 68: buy 1 unit at price 79.930000, total balance 9681.690003
# day 69, sell 1 unit at price 81.550003, investment 0.778553 %, total balance 9763.240006,
# day 71, sell 1 unit at price 81.769997, investment 3.414692 %, total balance 9845.010003,
# day 72, sell 1 unit at price 82.190002, investment 4.156631 %, total balance 9927.200005,
# day 73, sell 1 unit at price 82.699997, investment 3.465529 %, total balance 10009.900002,
# day 77: buy 1 unit at price 80.800003, total balance 9929.099999
# day 78, sell 1 unit at price 80.910004, investment 0.136140 %, total balance 10010.010003,
# day 80: buy 1 unit at price 81.620003, total balance 9928.390000
# day 81, sell 1 unit at price 81.820000, investment 0.245034 %, total balance 10010.210000,
# day 87: buy 1 unit at price 75.550003, total balance 9934.659997
# day 88: buy 1 unit at price 75.029999, total balance 9859.629998
# day 89: buy 1 unit at price 75.949997, total balance 9783.680001
# day 90: buy 1 unit at price 76.580002, total balance 9707.099999
# day 91: buy 1 unit at price 75.860001, total balance 9631.239998
# day 92: buy 1 unit at price 75.459999, total balance 9555.779999
# day 93: buy 1 unit at price 75.389999, total balance 9480.390000
# day 94: buy 1 unit at price 75.779999, total balance 9404.610001
# day 95: buy 1 unit at price 76.040001, total balance 9328.570000
# day 96: buy 1 unit at price 75.750000, total balance 9252.820000
# day 97: buy 1 unit at price 75.239998, total balance 9177.580002
# day 98: buy 1 unit at price 75.760002, total balance 9101.820000
# day 99: buy 1 unit at price 75.930000, total balance 9025.890000
# day 100: buy 1 unit at price 75.779999, total balance 8950.110001
# day 101: buy 1 unit at price 74.410004, total balance 8875.699997
# day 102: buy 1 unit at price 75.690002, total balance 8800.009995
# day 103: buy 1 unit at price 75.349998, total balance 8724.659997
# day 104: buy 1 unit at price 76.870003, total balance 8647.789994
# day 105: buy 1 unit at price 77.220001, total balance 8570.569993
# day 106: buy 1 unit at price 77.029999, total balance 8493.539994
# day 108: buy 1 unit at price 76.720001, total balance 8416.819993
# day 109, sell 1 unit at price 77.110001, investment 2.064855 %, total balance 8493.929994,
# day 110: buy 1 unit at price 76.970001, total balance 8416.959993
# day 111: buy 1 unit at price 78.250000, total balance 8338.709993
# day 112: buy 1 unit at price 78.019997, total balance 8260.689996
# day 113: buy 1 unit at price 78.550003, total balance 8182.139993
# day 115: buy 1 unit at price 80.010002, total balance 8102.129991
# day 116, sell 1 unit at price 79.199997, investment 5.557774 %, total balance 8181.329988,
# day 117, sell 1 unit at price 78.820000, investment 3.778806 %, total balance 8260.149988,
# day 118, sell 1 unit at price 77.680000, investment 1.436404 %, total balance 8337.829988,
# day 119, sell 1 unit at price 78.699997, investment 3.743733 %, total balance 8416.529985,
# day 120: buy 1 unit at price 77.959999, total balance 8338.569986
# day 123, sell 1 unit at price 79.019997, investment 4.717729 %, total balance 8417.589983,
# day 124, sell 1 unit at price 78.989998, investment 4.775168 %, total balance 8496.579981,
# day 125, sell 1 unit at price 79.489998, investment 4.895750 %, total balance 8576.069979,
# day 126, sell 1 unit at price 79.900002, investment 5.076277 %, total balance 8655.969981,
# day 127, sell 1 unit at price 79.889999, investment 5.465345 %, total balance 8735.859980,
# day 128, sell 1 unit at price 80.559998, investment 7.070707 %, total balance 8816.419978,
# day 129, sell 1 unit at price 80.980003, investment 6.890181 %, total balance 8897.399981,
# day 130, sell 1 unit at price 81.750000, investment 7.664955 %, total balance 8979.149981,
# day 131, sell 1 unit at price 81.589996, investment 7.666927 %, total balance 9060.739977,
# day 132, sell 1 unit at price 83.320000, investment 11.974191 %, total balance 9144.059977,
# day 133, sell 1 unit at price 81.709999, investment 7.953490 %, total balance 9225.769976,
# day 134, sell 1 unit at price 81.959999, investment 8.772397 %, total balance 9307.729975,
# day 135, sell 1 unit at price 82.739998, investment 7.636262 %, total balance 9390.469973,
# day 136, sell 1 unit at price 82.330002, investment 6.617458 %, total balance 9472.799975,
# day 137, sell 1 unit at price 82.379997, investment 6.945343 %, total balance 9555.179972,
# day 138, sell 1 unit at price 82.239998, investment 7.194991 %, total balance 9637.419970,
# day 139, sell 1 unit at price 82.669998, investment 7.405479 %, total balance 9720.089968,
# day 140, sell 1 unit at price 82.260002, investment 5.124603 %, total balance 9802.349970,
# day 141, sell 1 unit at price 82.839996, investment 6.177902 %, total balance 9885.189966,
# day 142, sell 1 unit at price 82.720001, investment 5.308718 %, total balance 9967.909967,
# day 143, sell 1 unit at price 81.559998, investment 1.937253 %, total balance 10049.469965,
# day 144, sell 1 unit at price 80.760002, investment 3.591589 %, total balance 10130.229967,
# day 147: buy 1 unit at price 76.860001, total balance 10053.369966
# day 148, sell 1 unit at price 77.820000, investment 1.249023 %, total balance 10131.189966,
# day 152: buy 1 unit at price 76.260002, total balance 10054.929964
# day 153, sell 1 unit at price 75.559998, investment -0.917918 %, total balance 10130.489962,
# day 154: buy 1 unit at price 75.419998, total balance 10055.069964
# day 155: buy 1 unit at price 75.220001, total balance 9979.849963
# day 156: buy 1 unit at price 74.540001, total balance 9905.309962
# day 157: buy 1 unit at price 75.099998, total balance 9830.209964
# day 158: buy 1 unit at price 75.559998, total balance 9754.649966
# day 159: buy 1 unit at price 74.910004, total balance 9679.739962
# day 160: buy 1 unit at price 74.900002, total balance 9604.839960
# day 161: buy 1 unit at price 75.260002, total balance 9529.579958
# day 162: buy 1 unit at price 75.110001, total balance 9454.469957
# day 163: buy 1 unit at price 75.860001, total balance 9378.609956
# day 164: buy 1 unit at price 76.610001, total balance 9301.999955
# day 166: buy 1 unit at price 77.690002, total balance 9224.309953
# day 167: buy 1 unit at price 77.389999, total balance 9146.919954
# day 169: buy 1 unit at price 75.639999, total balance 9071.279955
# day 170, sell 1 unit at price 75.290001, investment -0.172364 %, total balance 9146.569956,
# day 171: buy 1 unit at price 75.720001, total balance 9070.849955
# day 172: buy 1 unit at price 75.730003, total balance 8995.119952
# day 173, sell 1 unit at price 75.559998, investment 0.452003 %, total balance 9070.679950,
# day 176: buy 1 unit at price 77.199997, total balance 8993.479953
# day 178, sell 1 unit at price 75.959999, investment 1.905015 %, total balance 9069.439952,
# day 179, sell 1 unit at price 76.879997, investment 2.370172 %, total balance 9146.319949,
# day 180: buy 1 unit at price 76.099998, total balance 9070.219951
# day 181, sell 1 unit at price 77.169998, investment 2.130757 %, total balance 9147.389949,
# day 182, sell 1 unit at price 77.610001, investment 3.604321 %, total balance 9224.999950,
# day 183, sell 1 unit at price 77.269997, investment 3.164212 %, total balance 9302.269947,
# day 184, sell 1 unit at price 76.820000, investment 2.072812 %, total balance 9379.089947,
# day 185, sell 1 unit at price 76.790001, investment 2.236719 %, total balance 9455.879948,
# day 186, sell 1 unit at price 76.760002, investment 1.186397 %, total balance 9532.639950,
# day 187, sell 1 unit at price 77.150002, investment 0.704870 %, total balance 9609.789952,
# day 188, sell 1 unit at price 76.980003, investment -0.913887 %, total balance 9686.769955,
# day 189, sell 1 unit at price 77.279999, investment -0.142137 %, total balance 9764.049954,
# day 191, sell 1 unit at price 76.099998, investment 0.608143 %, total balance 9840.149952,
# day 192, sell 1 unit at price 75.209999, investment -0.673537 %, total balance 9915.359951,
# day 193, sell 1 unit at price 74.110001, investment -2.139181 %, total balance 9989.469952,
# day 194: buy 1 unit at price 73.970001, total balance 9915.499951
# day 195: buy 1 unit at price 71.440002, total balance 9844.059949
# day 196: buy 1 unit at price 70.290001, total balance 9773.769948
# day 197: buy 1 unit at price 72.169998, total balance 9701.599950
# day 198: buy 1 unit at price 72.010002, total balance 9629.589948
# day 199, sell 1 unit at price 73.500000, investment -4.792742 %, total balance 9703.089948,
# day 201, sell 1 unit at price 73.589996, investment -3.298294 %, total balance 9776.679944,
# day 202, sell 1 unit at price 73.690002, investment -0.378530 %, total balance 9850.369946,
# day 203: buy 1 unit at price 73.589996, total balance 9776.779950
# day 204, sell 1 unit at price 73.410004, investment 2.757562 %, total balance 9850.189954,
# day 205: buy 1 unit at price 70.150002, total balance 9780.039952
# day 206: buy 1 unit at price 71.480003, total balance 9708.559949
# day 207: buy 1 unit at price 70.529999, total balance 9638.029950
# day 208: buy 1 unit at price 69.220001, total balance 9568.809949
# day 209: buy 1 unit at price 66.519997, total balance 9502.289952
# day 210: buy 1 unit at price 69.029999, total balance 9433.259953
# day 211: buy 1 unit at price 68.779999, total balance 9364.479954
# day 212: buy 1 unit at price 69.500000, total balance 9294.979954
# day 214: buy 1 unit at price 69.650002, total balance 9225.329952
# day 215, sell 1 unit at price 71.370003, investment 1.536495 %, total balance 9296.699955,
# day 216: buy 1 unit at price 71.239998, total balance 9225.459957
# day 217: buy 1 unit at price 70.339996, total balance 9155.119961
# day 218: buy 1 unit at price 69.550003, total balance 9085.569958
# day 219: buy 1 unit at price 69.610001, total balance 9015.959957
# day 220: buy 1 unit at price 67.570000, total balance 8948.389957
# day 221: buy 1 unit at price 68.669998, total balance 8879.719959
# day 222: buy 1 unit at price 70.330002, total balance 8809.389957
# day 223: buy 1 unit at price 69.209999, total balance 8740.179958
# day 224: buy 1 unit at price 67.610001, total balance 8672.569957
# day 225: buy 1 unit at price 68.669998, total balance 8603.899959
# day 226, sell 1 unit at price 67.980003, investment -5.805730 %, total balance 8671.879962,
# day 227, sell 1 unit at price 68.750000, investment -4.527152 %, total balance 8740.629962,
# day 228: buy 1 unit at price 69.900002, total balance 8670.729960
# day 229: buy 1 unit at price 70.760002, total balance 8599.969958
# day 231, sell 1 unit at price 71.230003, investment -3.206948 %, total balance 8671.199961,
# day 233: buy 1 unit at price 70.019997, total balance 8601.179964
# day 234: buy 1 unit at price 69.400002, total balance 8531.779962
# day 235, sell 1 unit at price 68.000000, investment -3.064864 %, total balance 8599.779962,
# day 236: buy 1 unit at price 67.089996, total balance 8532.689966
# day 237: buy 1 unit at price 67.260002, total balance 8465.429964
# day 238: buy 1 unit at price 68.029999, total balance 8397.399965
# day 240: buy 1 unit at price 67.769997, total balance 8329.629968
# day 241: buy 1 unit at price 64.669998, total balance 8264.959970
# day 242: buy 1 unit at price 64.620003, total balance 8200.339967
# day 243: buy 1 unit at price 64.230003, total balance 8136.109964
# day 244: buy 1 unit at price 62.779999, total balance 8073.329965
# day 245: buy 1 unit at price 60.090000, total balance 8013.239965
# day 246: buy 1 unit at price 60.020000, total balance 7953.219965
# day 247: buy 1 unit at price 62.360001, total balance 7890.859964
# day 248: buy 1 unit at price 63.080002, total balance 7827.779962
# day 249: buy 1 unit at price 62.930000, total balance 7764.849962
# day 250: buy 1 unit at price 63.480000, total balance 7701.369962
# day 251: buy 1 unit at price 63.090000, total balance 7638.279962
# day 252: buy 1 unit at price 61.099998, total balance 7577.179964
# day 253: buy 1 unit at price 63.700001, total balance 7513.479963
# day 254: buy 1 unit at price 63.599998, total balance 7449.879965
# day 255: buy 1 unit at price 64.320000, total balance 7385.559965
# day 257: buy 1 unit at price 64.809998, total balance 7320.749967
# day 258: buy 1 unit at price 64.919998, total balance 7255.829969
# day 259: buy 1 unit at price 64.629997, total balance 7191.199972
# day 260: buy 1 unit at price 65.989998, total balance 7125.209974
# day 261: buy 1 unit at price 65.790001, total balance 7059.419973
# day 262: buy 1 unit at price 66.550003, total balance 6992.869970
# day 265, sell 1 unit at price 67.059998, investment -6.183555 %, total balance 7059.929968,
# day 267, sell 1 unit at price 70.019997, investment -0.723099 %, total balance 7129.949965,
# day 268, sell 1 unit at price 68.949997, investment -0.390066 %, total balance 7198.899962,
# day 269: buy 1 unit at price 68.660004, total balance 7130.239958
# day 271, sell 1 unit at price 69.680000, investment 4.750456 %, total balance 7199.919958,
# day 272, sell 1 unit at price 70.139999, investment 1.607997 %, total balance 7270.059957,
# day 274, sell 1 unit at price 71.209999, investment 3.533004 %, total balance 7341.269956,
# day 275, sell 1 unit at price 74.500000, investment 7.194245 %, total balance 7415.769956,
# day 276, sell 1 unit at price 72.989998, investment 4.795400 %, total balance 7488.759954,
# day 277, sell 1 unit at price 73.160004, investment 2.695124 %, total balance 7561.919958,
# day 278, sell 1 unit at price 72.970001, investment 3.738989 %, total balance 7634.889959,
# day 279, sell 1 unit at price 73.449997, investment 5.607468 %, total balance 7708.339956,
# day 280, sell 1 unit at price 73.580002, investment 5.703205 %, total balance 7781.919958,
# day 281, sell 1 unit at price 73.120003, investment 8.213709 %, total balance 7855.039961,
# day 282, sell 1 unit at price 73.559998, investment 7.121014 %, total balance 7928.599959,
# day 283, sell 1 unit at price 73.180000, investment 4.052322 %, total balance 8001.779959,
# day 284, sell 1 unit at price 72.250000, investment 4.392430 %, total balance 8074.029959,
# day 285, sell 1 unit at price 71.339996, investment 5.516928 %, total balance 8145.369955,
# day 286, sell 1 unit at price 72.379997, investment 5.402649 %, total balance 8217.749952,
# day 287, sell 1 unit at price 72.250000, investment 3.361943 %, total balance 8289.999952,
# day 288, sell 1 unit at price 72.040001, investment 1.808930 %, total balance 8362.039953,
# day 290, sell 1 unit at price 70.980003, investment 1.371045 %, total balance 8433.019956,
# day 291, sell 1 unit at price 72.129997, investment 3.933710 %, total balance 8505.149953,
# day 292, sell 1 unit at price 71.760002, investment 6.960808 %, total balance 8576.909955,
# day 293, sell 1 unit at price 71.389999, investment 6.140346 %, total balance 8648.299954,
# day 294, sell 1 unit at price 71.459999, investment 5.041893 %, total balance 8719.759953,
# day 295, sell 1 unit at price 72.330002, investment 6.728649 %, total balance 8792.089955,
# day 296, sell 1 unit at price 71.150002, investment 10.020109 %, total balance 8863.239957,
# day 297, sell 1 unit at price 72.349998, investment 11.962232 %, total balance 8935.589955,
# day 298, sell 1 unit at price 71.779999, investment 11.754625 %, total balance 9007.369954,
# day 299, sell 1 unit at price 71.209999, investment 13.427843 %, total balance 9078.579953,
# day 300, sell 1 unit at price 70.930000, investment 18.039607 %, total balance 9149.509953,
# day 301: buy 1 unit at price 72.129997, total balance 9077.379956
# day 302, sell 1 unit at price 71.879997, investment 19.760075 %, total balance 9149.259953,
# day 303, sell 1 unit at price 72.019997, investment 15.490693 %, total balance 9221.279950,
# day 305: buy 1 unit at price 72.199997, total balance 9149.079953
# day 306: buy 1 unit at price 70.889999, total balance 9078.189954
# day 307, sell 1 unit at price 70.750000, investment 12.159159 %, total balance 9148.939954,
# day 309: buy 1 unit at price 71.029999, total balance 9077.909955
# day 310: buy 1 unit at price 71.580002, total balance 9006.329953
# day 311, sell 1 unit at price 72.449997, investment 15.127915 %, total balance 9078.779950,
# day 312, sell 1 unit at price 73.849998, investment 16.335851 %, total balance 9152.629948,
# day 313, sell 1 unit at price 73.570000, investment 16.611190 %, total balance 9226.199948,
# day 314, sell 1 unit at price 74.180000, investment 21.407533 %, total balance 9300.379948,
# day 315, sell 1 unit at price 73.790001, investment 15.839874 %, total balance 9374.169949,
# day 316, sell 1 unit at price 74.199997, investment 16.666666 %, total balance 9448.369946,
# day 317, sell 1 unit at price 74.410004, investment 15.687195 %, total balance 9522.779950,
# day 318, sell 1 unit at price 74.370003, investment 14.750818 %, total balance 9597.149953,
# day 319, sell 1 unit at price 74.599998, investment 14.910660 %, total balance 9671.749951,
# day 320, sell 1 unit at price 74.190002, investment 14.791901 %, total balance 9745.939953,
# day 321, sell 1 unit at price 74.290001, investment 12.577668 %, total balance 9820.229954,
# day 322, sell 1 unit at price 74.320000, investment 12.965495 %, total balance 9894.549954,
# day 323, sell 1 unit at price 71.900002, investment 8.039067 %, total balance 9966.449956,
# day 324, sell 1 unit at price 72.150002, investment 5.083015 %, total balance 10038.599958,
# day 325: buy 1 unit at price 71.339996, total balance 9967.259962
# day 326, sell 1 unit at price 71.480003, investment -0.901142 %, total balance 10038.739965,
# day 328: buy 1 unit at price 72.669998, total balance 9966.069967
# day 329, sell 1 unit at price 72.930000, investment 1.011085 %, total balance 10038.999967,
# day 330, sell 1 unit at price 73.370003, investment 3.498383 %, total balance 10112.369970,
# day 331, sell 1 unit at price 72.400002, investment 1.928767 %, total balance 10184.769972,
# day 332, sell 1 unit at price 72.959999, investment 1.927909 %, total balance 10257.729971,
# day 333, sell 1 unit at price 72.180000, investment 1.177466 %, total balance 10329.909971,
# day 334: buy 1 unit at price 66.610001, total balance 10263.299970
# day 335: buy 1 unit at price 59.250000, total balance 10204.049970
# day 336: buy 1 unit at price 59.599998, total balance 10144.449972
# day 337: buy 1 unit at price 58.509998, total balance 10085.939974
# day 338: buy 1 unit at price 58.980000, total balance 10026.959974
# day 339: buy 1 unit at price 59.099998, total balance 9967.859976
# day 340: buy 1 unit at price 59.130001, total balance 9908.729975
# day 341: buy 1 unit at price 56.880001, total balance 9851.849974
# day 342: buy 1 unit at price 57.750000, total balance 9794.099974
# day 343: buy 1 unit at price 58.599998, total balance 9735.499976
# day 344: buy 1 unit at price 58.639999, total balance 9676.859977
# day 345: buy 1 unit at price 59.439999, total balance 9617.419978
# day 346: buy 1 unit at price 59.990002, total balance 9557.429976
# day 347: buy 1 unit at price 61.000000, total balance 9496.429976
# day 348: buy 1 unit at price 61.500000, total balance 9434.929976
# day 349: buy 1 unit at price 61.080002, total balance 9373.849974
# day 350: buy 1 unit at price 61.869999, total balance 9311.979975
# day 351: buy 1 unit at price 62.070000, total balance 9249.909975
# day 352: buy 1 unit at price 61.880001, total balance 9188.029974
# day 353: buy 1 unit at price 62.360001, total balance 9125.669973
# day 354: buy 1 unit at price 61.930000, total balance 9063.739973
# day 357: buy 1 unit at price 62.180000, total balance 9001.559973
# day 358: buy 1 unit at price 61.900002, total balance 8939.659971
# day 359: buy 1 unit at price 62.779999, total balance 8876.879972
# day 360: buy 1 unit at price 63.029999, total balance 8813.849973
# day 361, sell 1 unit at price 63.369999, investment -12.797577 %, total balance 8877.219972,
# day 363: buy 1 unit at price 62.340000, total balance 8814.879972
# day 364: buy 1 unit at price 61.639999, total balance 8753.239973
# day 365, sell 1 unit at price 62.560001, investment -6.080168 %, total balance 8815.799974,
# day 366, sell 1 unit at price 63.720001, investment 7.544305 %, total balance 8879.519975,
# day 367, sell 1 unit at price 62.610001, investment 5.050341 %, total balance 8942.129976,
# day 368, sell 1 unit at price 64.169998, investment 9.673560 %, total balance 9006.299974,
# day 369, sell 1 unit at price 64.459999, investment 9.291283 %, total balance 9070.759973,
# day 370, sell 1 unit at price 64.050003, investment 8.375643 %, total balance 9134.809976,
# day 371, sell 1 unit at price 63.160000, investment 6.815489 %, total balance 9197.969976,
# day 372, sell 1 unit at price 63.060001, investment 10.864979 %, total balance 9261.029977,
# day 373, sell 1 unit at price 63.060001, investment 9.194807 %, total balance 9324.089978,
# day 374, sell 1 unit at price 63.389999, investment 8.174063 %, total balance 9387.479977,
# day 375, sell 1 unit at price 64.279999, investment 9.618008 %, total balance 9451.759976,
# day 377, sell 1 unit at price 64.180000, investment 7.974430 %, total balance 9515.939976,
# day 378, sell 1 unit at price 64.709999, investment 7.867973 %, total balance 9580.649975,
# day 379, sell 1 unit at price 64.199997, investment 5.245897 %, total balance 9644.849972,
# day 380, sell 1 unit at price 64.379997, investment 4.682922 %, total balance 9709.229969,
# day 381, sell 1 unit at price 64.059998, investment 4.878841 %, total balance 9773.289967,
# day 382, sell 1 unit at price 65.290001, investment 5.527723 %, total balance 9838.579968,
# day 384, sell 1 unit at price 65.820000, investment 6.041566 %, total balance 9904.399968,
# day 386, sell 1 unit at price 65.239998, investment 5.429859 %, total balance 9969.639966,
# day 387, sell 1 unit at price 65.930000, investment 5.724822 %, total balance 10035.569966,
# day 388, sell 1 unit at price 65.139999, investment 5.183270 %, total balance 10100.709965,
# day 389, sell 1 unit at price 65.550003, investment 5.419754 %, total balance 10166.259968,
# day 390, sell 1 unit at price 65.870003, investment 6.413572 %, total balance 10232.129971,
# day 391, sell 1 unit at price 65.760002, investment 4.746739 %, total balance 10297.889973,
# day 393, sell 1 unit at price 66.400002, investment 5.346665 %, total balance 10364.289975,
# day 394, sell 1 unit at price 66.040001, investment 5.935196 %, total balance 10430.329976,
# day 395, sell 1 unit at price 65.330002, investment 5.986377 %, total balance 10495.659978,
# day 400: buy 1 unit at price 62.580002, total balance 10433.079976
# day 401: buy 1 unit at price 62.209999, total balance 10370.869977
# day 402, sell 1 unit at price 63.959999, investment 2.205173 %, total balance 10434.829976,
# day 403: buy 1 unit at price 62.459999, total balance 10372.369977
# day 404: buy 1 unit at price 61.169998, total balance 10311.199979
# day 405, sell 1 unit at price 61.740002, investment -0.755501 %, total balance 10372.939981,
# day 406: buy 1 unit at price 60.650002, total balance 10312.289979
# day 407, sell 1 unit at price 60.580002, investment -3.009922 %, total balance 10372.869981,
# day 408: buy 1 unit at price 61.220001, total balance 10311.649980
# day 409: buy 1 unit at price 61.860001, total balance 10249.789979
# day 410: buy 1 unit at price 61.580002, total balance 10188.209977
# day 411: buy 1 unit at price 61.939999, total balance 10126.269978
# day 412: buy 1 unit at price 61.200001, total balance 10065.069977
# day 413: buy 1 unit at price 60.000000, total balance 10005.069977
# day 414: buy 1 unit at price 59.869999, total balance 9945.199978
# day 415: buy 1 unit at price 59.700001, total balance 9885.499977
# day 416: buy 1 unit at price 60.240002, total balance 9825.259975
# day 417: buy 1 unit at price 61.380001, total balance 9763.879974
# day 418: buy 1 unit at price 61.389999, total balance 9702.489975
# day 420: buy 1 unit at price 62.410000, total balance 9640.079975
# day 421, sell 1 unit at price 64.260002, investment 5.051503 %, total balance 9704.339977,
# day 422, sell 1 unit at price 64.449997, investment 6.265449 %, total balance 9768.789974,
# day 423: buy 1 unit at price 64.180000, total balance 9704.609974
# day 424, sell 1 unit at price 64.739998, investment 5.749750 %, total balance 9769.349972,
# day 425, sell 1 unit at price 65.360001, investment 5.657937 %, total balance 9834.709973,
# day 427, sell 1 unit at price 64.330002, investment 4.465735 %, total balance 9899.039975,
# day 429, sell 1 unit at price 64.000000, investment 3.325801 %, total balance 9963.039975,
# day 430, sell 1 unit at price 63.509998, investment 3.774505 %, total balance 10026.549973,
# day 432: buy 1 unit at price 61.799999, total balance 9964.749974
# day 433, sell 1 unit at price 60.830002, investment 1.383337 %, total balance 10025.579976,
# day 434: buy 1 unit at price 59.919998, total balance 9965.659978
# day 435: buy 1 unit at price 60.189999, total balance 9905.469979
# day 436, sell 1 unit at price 59.660000, investment -0.350758 %, total balance 9965.129979,
# day 437: buy 1 unit at price 58.750000, total balance 9906.379979
# day 438: buy 1 unit at price 60.270000, total balance 9846.109979
# day 439: buy 1 unit at price 60.619999, total balance 9785.489980
# day 440, sell 1 unit at price 59.939999, investment 0.402007 %, total balance 9845.429979,
# day 441: buy 1 unit at price 60.180000, total balance 9785.249979
# day 442: buy 1 unit at price 60.509998, total balance 9724.739981
# day 443, sell 1 unit at price 60.279999, investment 0.066396 %, total balance 9785.019980,
# day 444: buy 1 unit at price 58.900002, total balance 9726.119978
# day 445, sell 1 unit at price 59.439999, investment -3.160642 %, total balance 9785.559977,
# day 446, sell 1 unit at price 59.799999, investment -2.589998 %, total balance 9845.359976,
# day 447: buy 1 unit at price 60.610001, total balance 9784.749975
# day 448: buy 1 unit at price 60.380001, total balance 9724.369974
# day 449, sell 1 unit at price 61.340000, investment -1.714469 %, total balance 9785.709974,
# day 450, sell 1 unit at price 61.389999, investment -4.347150 %, total balance 9847.099973,
# day 451: buy 1 unit at price 61.380001, total balance 9785.719972
# day 452: buy 1 unit at price 60.639999, total balance 9725.079973
# day 453: buy 1 unit at price 60.779999, total balance 9664.299974
# day 454: buy 1 unit at price 59.900002, total balance 9604.399972
# day 455: buy 1 unit at price 60.349998, total balance 9544.049974
# day 456: buy 1 unit at price 60.509998, total balance 9483.539976
# day 457: buy 1 unit at price 60.459999, total balance 9423.079977
# day 458: buy 1 unit at price 60.669998, total balance 9362.409979
# day 459: buy 1 unit at price 60.450001, total balance 9301.959978
# day 460: buy 1 unit at price 59.889999, total balance 9242.069979
# day 461: buy 1 unit at price 60.939999, total balance 9181.129980
# day 462: buy 1 unit at price 61.230000, total balance 9119.899980
# day 463, sell 1 unit at price 62.070000, investment 0.436895 %, total balance 9181.969980,
# day 465, sell 1 unit at price 62.259998, investment 3.905207 %, total balance 9244.229978,
# day 466, sell 1 unit at price 63.029999, investment 4.718392 %, total balance 9307.259977,
# day 467, sell 1 unit at price 62.860001, investment 6.995746 %, total balance 9370.119978,
# day 468, sell 1 unit at price 62.639999, investment 3.932303 %, total balance 9432.759977,
# day 469, sell 1 unit at price 62.840000, investment 3.662159 %, total balance 9495.599977,
# day 470, sell 1 unit at price 62.509998, investment 3.871715 %, total balance 9558.109975,
# day 471, sell 1 unit at price 63.110001, investment 4.296816 %, total balance 9621.219976,
# day 472, sell 1 unit at price 63.380001, investment 7.606110 %, total balance 9684.599977,
# day 473, sell 1 unit at price 63.630001, investment 4.982676 %, total balance 9748.229978,
# day 474, sell 1 unit at price 63.919998, investment 5.862863 %, total balance 9812.149976,
# day 475, sell 1 unit at price 63.509998, investment 3.470181 %, total balance 9875.659974,
# day 476, sell 1 unit at price 63.400002, investment 4.551456 %, total balance 9939.059976,
# day 477, sell 1 unit at price 63.189999, investment 3.965120 %, total balance 10002.249975,
# day 478, sell 1 unit at price 63.360001, investment 5.776292 %, total balance 10065.609976,
# day 479, sell 1 unit at price 63.730000, investment 5.600666 %, total balance 10129.339976,
# day 480, sell 1 unit at price 64.150002, investment 6.015541 %, total balance 10193.489978,
# day 481, sell 1 unit at price 64.110001, investment 6.037053 %, total balance 10257.599979,
# day 482, sell 1 unit at price 63.540001, investment 4.730514 %, total balance 10321.139980,
# day 483, sell 1 unit at price 62.750000, investment 3.804796 %, total balance 10383.889980,
# day 484, sell 1 unit at price 62.400002, investment 4.191022 %, total balance 10446.289982,
# day 485, sell 1 unit at price 62.209999, investment 2.084017 %, total balance 10508.499981,
# day 486, sell 1 unit at price 62.660000, investment 2.335456 %, total balance 10571.159981,
# day 492: buy 1 unit at price 61.660000, total balance 10509.499981
# day 493: buy 1 unit at price 61.759998, total balance 10447.739983
# day 494, sell 1 unit at price 62.320000, investment 1.070386 %, total balance 10510.059983,
# day 495, sell 1 unit at price 62.709999, investment 1.538214 %, total balance 10572.769982,
# day 501: buy 1 unit at price 61.650002, total balance 10511.119980
# day 502, sell 1 unit at price 62.020000, investment 0.600159 %, total balance 10573.139980,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Double Q-learning agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Double Q-learning agent'

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed_forward = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed_forward, output_size)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                state = next_state
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: -443.960029.3, cost: 0.006606, total money: 7640.279975
# epoch: 20, total rewards: -64.789974.3, cost: 0.002774, total money: 9437.990029
# epoch: 30, total rewards: -49.480016.3, cost: 0.003473, total money: 9446.179979
# epoch: 40, total rewards: -364.839972.3, cost: 0.015701, total money: 8581.700036
# epoch: 50, total rewards: -13.889941.3, cost: 0.007391, total money: 9986.110059
# epoch: 60, total rewards: -35.489910.3, cost: 0.000428, total money: 9902.110088
# epoch: 70, total rewards: -24.290001.3, cost: 0.001665, total money: 9975.709999
# epoch: 80, total rewards: 58.840029.3, cost: 0.006793, total money: 9996.210028
# epoch: 90, total rewards: -15.269992.3, cost: 0.001954, total money: 9984.730008
# epoch: 100, total rewards: -40.059961.3, cost: 0.000351, total money: 9897.920039
# epoch: 110, total rewards: 0.439989.3, cost: 0.000548, total money: 10000.439989
# epoch: 120, total rewards: -48.619999.3, cost: 0.000902, total money: 9951.380001
# epoch: 130, total rewards: -38.579951.3, cost: 0.000428, total money: 9961.420049
# epoch: 140, total rewards: -18.670015.3, cost: 0.005374, total money: 9981.329985
# epoch: 150, total rewards: -32.080002.3, cost: 0.001550, total money: 9967.919998
# epoch: 160, total rewards: 20.279962.3, cost: 0.000593, total money: 10020.279962
# epoch: 170, total rewards: -13.899963.3, cost: 0.001753, total money: 9986.100037
# epoch: 180, total rewards: -20.219961.3, cost: 0.000637, total money: 9979.780039
# epoch: 190, total rewards: -3.269989.3, cost: 0.000812, total money: 9996.730011
# epoch: 200, total rewards: -0.780013.3, cost: 0.000067, total money: 9999.219987

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 17: buy 1 unit at price 78.430000, total balance 9921.570000
# day 18, sell 1 unit at price 78.150002, investment -0.357004 %, total balance 9999.720002,
# day 23: buy 1 unit at price 73.290001, total balance 9926.430001
# day 24, sell 1 unit at price 73.900002, investment 0.832311 %, total balance 10000.330003,
# day 29: buy 1 unit at price 78.110001, total balance 9922.220002
# day 30, sell 1 unit at price 79.820000, investment 2.189219 %, total balance 10002.040002,
# day 45: buy 1 unit at price 83.220001, total balance 9918.820001
# day 46, sell 1 unit at price 84.709999, investment 1.790433 %, total balance 10003.530000,
# day 51: buy 1 unit at price 84.599998, total balance 9918.930002
# day 52: buy 1 unit at price 83.809998, total balance 9835.120004
# day 53, sell 1 unit at price 84.309998, investment -0.342790 %, total balance 9919.430002,
# day 55, sell 1 unit at price 80.970001, investment -3.388614 %, total balance 10000.400003,
# day 70: buy 1 unit at price 80.820000, total balance 9919.580003
# day 71, sell 1 unit at price 81.769997, investment 1.175448 %, total balance 10001.350000,
# day 79: buy 1 unit at price 81.730003, total balance 9919.619997
# day 80, sell 1 unit at price 81.620003, investment -0.134589 %, total balance 10001.240000,
# day 99: buy 1 unit at price 75.930000, total balance 9925.310000
# day 100, sell 1 unit at price 75.779999, investment -0.197552 %, total balance 10001.089999,
# day 102: buy 1 unit at price 75.690002, total balance 9925.399997
# day 103, sell 1 unit at price 75.349998, investment -0.449206 %, total balance 10000.749995,
# day 107: buy 1 unit at price 78.139999, total balance 9922.609996
# day 108: buy 1 unit at price 76.720001, total balance 9845.889995
# day 109, sell 1 unit at price 77.110001, investment -1.318144 %, total balance 9922.999996,
# day 110, sell 1 unit at price 76.970001, investment 0.325860 %, total balance 9999.969997,
# day 115: buy 1 unit at price 80.010002, total balance 9919.959995
# day 116, sell 1 unit at price 79.199997, investment -1.012380 %, total balance 9999.159992,
# day 126: buy 1 unit at price 79.900002, total balance 9919.259990
# day 127: buy 1 unit at price 79.889999, total balance 9839.369991
# day 128, sell 1 unit at price 80.559998, investment 0.826028 %, total balance 9919.929989,
# day 129, sell 1 unit at price 80.980003, investment 1.364381 %, total balance 10000.909992,
# day 132: buy 1 unit at price 83.320000, total balance 9917.589992
# day 133, sell 1 unit at price 81.709999, investment -1.932310 %, total balance 9999.299991,
# day 148: buy 1 unit at price 77.820000, total balance 9921.479991
# day 150, sell 1 unit at price 78.070000, investment 0.321254 %, total balance 9999.549991,
# day 190: buy 1 unit at price 76.559998, total balance 9922.989993
# day 191, sell 1 unit at price 76.099998, investment -0.600836 %, total balance 9999.089991,
# day 196: buy 1 unit at price 70.290001, total balance 9928.799990
# day 197, sell 1 unit at price 72.169998, investment 2.674629 %, total balance 10000.969988,
# day 198: buy 1 unit at price 72.010002, total balance 9928.959986
# day 199, sell 1 unit at price 73.500000, investment 2.069154 %, total balance 10002.459986,
# day 200: buy 1 unit at price 73.989998, total balance 9928.469988
# day 201, sell 1 unit at price 73.589996, investment -0.540616 %, total balance 10002.059984,
# day 204: buy 1 unit at price 73.410004, total balance 9928.649980
# day 205, sell 1 unit at price 70.150002, investment -4.440814 %, total balance 9998.799982,
# day 207: buy 1 unit at price 70.529999, total balance 9928.269983
# day 208, sell 1 unit at price 69.220001, investment -1.857363 %, total balance 9997.489984,
# day 211: buy 1 unit at price 68.779999, total balance 9928.709985
# day 212, sell 1 unit at price 69.500000, investment 1.046817 %, total balance 9998.209985,
# day 215: buy 1 unit at price 71.370003, total balance 9926.839982
# day 216: buy 1 unit at price 71.239998, total balance 9855.599984
# day 217, sell 1 unit at price 70.339996, investment -1.443193 %, total balance 9925.939980,
# day 218, sell 1 unit at price 69.550003, investment -2.372256 %, total balance 9995.489983,
# day 222: buy 1 unit at price 70.330002, total balance 9925.159981
# day 225, sell 1 unit at price 68.669998, investment -2.360307 %, total balance 9993.829979,
# day 245: buy 1 unit at price 60.090000, total balance 9933.739979
# day 246, sell 1 unit at price 60.020000, investment -0.116492 %, total balance 9993.759979,
# day 257: buy 1 unit at price 64.809998, total balance 9928.949981
# day 258, sell 1 unit at price 64.919998, investment 0.169727 %, total balance 9993.869979,
# day 265: buy 1 unit at price 67.059998, total balance 9926.809981
# day 266, sell 1 unit at price 68.120003, investment 1.580682 %, total balance 9994.929984,
# day 279: buy 1 unit at price 73.449997, total balance 9921.479987
# day 280, sell 1 unit at price 73.580002, investment 0.176998 %, total balance 9995.059989,
# day 283: buy 1 unit at price 73.180000, total balance 9921.879989
# day 284, sell 1 unit at price 72.250000, investment -1.270839 %, total balance 9994.129989,
# day 288: buy 1 unit at price 72.040001, total balance 9922.089988
# day 289, sell 1 unit at price 71.309998, investment -1.013330 %, total balance 9993.399986,
# day 291: buy 1 unit at price 72.129997, total balance 9921.269989
# day 292: buy 1 unit at price 71.760002, total balance 9849.509987
# day 293, sell 1 unit at price 71.389999, investment -1.025923 %, total balance 9920.899986,
# day 294, sell 1 unit at price 71.459999, investment -0.418064 %, total balance 9992.359985,
# day 295: buy 1 unit at price 72.330002, total balance 9920.029983
# day 296, sell 1 unit at price 71.150002, investment -1.631412 %, total balance 9991.179985,
# day 299: buy 1 unit at price 71.209999, total balance 9919.969986
# day 300, sell 1 unit at price 70.930000, investment -0.393202 %, total balance 9990.899986,
# day 301: buy 1 unit at price 72.129997, total balance 9918.769989
# day 303, sell 1 unit at price 72.019997, investment -0.152502 %, total balance 9990.789986,
# day 326: buy 1 unit at price 71.480003, total balance 9919.309983
# day 327, sell 1 unit at price 72.849998, investment 1.916613 %, total balance 9992.159981,
# day 328: buy 1 unit at price 72.669998, total balance 9919.489983
# day 329, sell 1 unit at price 72.930000, investment 0.357785 %, total balance 9992.419983,
# day 333: buy 1 unit at price 72.180000, total balance 9920.239983
# day 335, sell 1 unit at price 59.250000, investment -17.913549 %, total balance 9979.489983,
# day 340: buy 1 unit at price 59.130001, total balance 9920.359982
# day 341, sell 1 unit at price 56.880001, investment -3.805175 %, total balance 9977.239983,
# day 342: buy 1 unit at price 57.750000, total balance 9919.489983
# day 343, sell 1 unit at price 58.599998, investment 1.471858 %, total balance 9978.089981,
# day 346: buy 1 unit at price 59.990002, total balance 9918.099979
# day 347, sell 1 unit at price 61.000000, investment 1.683611 %, total balance 9979.099979,
# day 372: buy 1 unit at price 63.060001, total balance 9916.039978
# day 373, sell 1 unit at price 63.060001, investment 0.000000 %, total balance 9979.099979,
# day 375: buy 1 unit at price 64.279999, total balance 9914.819980
# day 376: buy 1 unit at price 64.360001, total balance 9850.459979
# day 377, sell 1 unit at price 64.180000, investment -0.155568 %, total balance 9914.639979,
# day 378, sell 1 unit at price 64.709999, investment 0.543813 %, total balance 9979.349978,
# day 382: buy 1 unit at price 65.290001, total balance 9914.059977
# day 384, sell 1 unit at price 65.820000, investment 0.811761 %, total balance 9979.879977,
# day 390: buy 1 unit at price 65.870003, total balance 9914.009974
# day 391, sell 1 unit at price 65.760002, investment -0.166997 %, total balance 9979.769976,
# day 396: buy 1 unit at price 65.139999, total balance 9914.629977
# day 397, sell 1 unit at price 66.410004, investment 1.949655 %, total balance 9981.039981,
# day 404: buy 1 unit at price 61.169998, total balance 9919.869983
# day 405, sell 1 unit at price 61.740002, investment 0.931836 %, total balance 9981.609985,
# day 410: buy 1 unit at price 61.580002, total balance 9920.029983
# day 411, sell 1 unit at price 61.939999, investment 0.584601 %, total balance 9981.969982,
# day 419: buy 1 unit at price 61.480000, total balance 9920.489982
# day 420, sell 1 unit at price 62.410000, investment 1.512687 %, total balance 9982.899982,
# day 437: buy 1 unit at price 58.750000, total balance 9924.149982
# day 438, sell 1 unit at price 60.270000, investment 2.587234 %, total balance 9984.419982,
# day 462: buy 1 unit at price 61.230000, total balance 9923.189982
# day 463, sell 1 unit at price 62.070000, investment 1.371877 %, total balance 9985.259982,
# day 470: buy 1 unit at price 62.509998, total balance 9922.749984
# day 471, sell 1 unit at price 63.110001, investment 0.959851 %, total balance 9985.859985,
# day 476: buy 1 unit at price 63.400002, total balance 9922.459983
# day 478: buy 1 unit at price 63.360001, total balance 9859.099982
# day 479: buy 1 unit at price 63.730000, total balance 9795.369982
# day 480, sell 1 unit at price 64.150002, investment 1.182965 %, total balance 9859.519984,
# day 481, sell 1 unit at price 64.110001, investment 1.183712 %, total balance 9923.629985,
# day 482, sell 1 unit at price 63.540001, investment -0.298131 %, total balance 9987.169986,
# day 497: buy 1 unit at price 62.630001, total balance 9924.539985
# day 498, sell 1 unit at price 62.400002, investment -0.367235 %, total balance 9986.939987,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Recurrent Q-learning agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Recurrent Q-learning agent'
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.X = tf.placeholder(tf.float32, (None, None, self.state_size))
        self.Y = tf.placeholder(tf.float32, (None, self.OUTPUT_SIZE))
        cell = tf.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
        self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * self.LAYER_SIZE))
        self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
        self.logits = tf.layers.dense(self.rnn[:,-1], self.OUTPUT_SIZE)
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.logits, feed_dict={self.X:states, self.hidden_layer:init_values})
        Q_new = self.sess.run(self.logits, feed_dict={self.X:new_states, self.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * np.amax(Q_new[i])
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.logits,self.last_state],
                                                feed_dict={self.X:[self.INITIAL_FEATURES],
                                                            self.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.logits,
                                                  self.last_state],
                                                  feed_dict={self.X:[self.INITIAL_FEATURES],
                                                             self.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.cost, self.optimizer], 
                                        feed_dict={self.X: X, self.Y:Y,
                                                  self.hidden_layer: INIT_VAL})
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
                
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-36-221ab996fe71>:30: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f4bc80e4320>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:From <ipython-input-36-221ab996fe71>:34: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:958: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:962: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: -145.769985.3, cost: 0.010313, total money: 8604.170013
# epoch: 20, total rewards: -143.299964.3, cost: 0.002092, total money: 9732.930035
# epoch: 30, total rewards: -0.469994.3, cost: 0.001391, total money: 9562.860003
# epoch: 40, total rewards: 2.379993.3, cost: 0.002333, total money: 9814.369991
# epoch: 50, total rewards: -117.199989.3, cost: 0.007222, total money: 8455.440005
# epoch: 60, total rewards: -91.630020.3, cost: 0.001389, total money: 9846.719978
# epoch: 70, total rewards: -64.400003.3, cost: 0.013661, total money: 9873.949995
# epoch: 80, total rewards: 81.269971.3, cost: 0.008868, total money: 10081.269971
# epoch: 90, total rewards: -31.589954.3, cost: 0.019048, total money: 9906.250046
# epoch: 100, total rewards: -60.470027.3, cost: 0.163295, total money: 7780.379971
# epoch: 110, total rewards: -134.869982.3, cost: 0.015919, total money: 8444.810025
# epoch: 120, total rewards: -35.140020.3, cost: 0.013026, total money: 9841.089979
# epoch: 130, total rewards: -293.690061.3, cost: 0.062672, total money: 8536.629937
# epoch: 140, total rewards: 41.720008.3, cost: 0.054306, total money: 10041.720008
# epoch: 150, total rewards: 43.369986.3, cost: 0.028960, total money: 10043.369986
# epoch: 160, total rewards: -15.790002.3, cost: 0.032639, total money: 9110.169996
# epoch: 170, total rewards: 29.789960.3, cost: 0.006060, total money: 10029.789960
# epoch: 180, total rewards: 21.800004.3, cost: 0.002708, total money: 10021.800004
# epoch: 190, total rewards: -32.850007.3, cost: 0.004684, total money: 9842.399993
# epoch: 200, total rewards: 26.630010.3, cost: 0.173548, total money: 9964.610010

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Double Recurrent Q-learning agent

# %%
from collections import deque
import random


df= df_full.copy()
name = 'Double Recurrent Q-learning agent'


class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate, name):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            cell = tf.nn.rnn_cell.LSTMCell(layer_size, state_is_tuple = False)
            self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * layer_size))
            self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            self.logits = tf.layers.dense(self.rnn[:,-1], output_size)
            self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                           'real_model')
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                                   'negative_model')
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.model.logits, feed_dict={self.model.X:states, 
                                                   self.model.hidden_layer:init_values})
        Q_new = self.sess.run(self.model.logits, feed_dict={self.model.X:new_states, 
                                                       self.model.hidden_layer:init_values})
        Q_new_negative = self.sess.run(self.model_negative.logits, 
                                  feed_dict={self.model_negative.X:new_states, 
                                             self.model_negative.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.model.logits,self.model.last_state],
                                                feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                            self.model.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('real_model', 'negative_model')
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.model.logits,
                                                  self.model.last_state],
                                                  feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                             self.model.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y,
                                                  self.model.hidden_layer: INIT_VAL})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f4bd7e25908>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f4bd7e245c0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: -70.529992.3, cost: 0.003106, total money: 9177.520012
# epoch: 20, total rewards: 6.299966.3, cost: 0.000809, total money: 9944.279966
# epoch: 30, total rewards: -256.529925.3, cost: 0.004183, total money: 9372.350076
# epoch: 40, total rewards: -26.440028.3, cost: 0.001058, total money: 9973.559972
# epoch: 50, total rewards: 29.430075.3, cost: 0.002569, total money: 9905.150072
# epoch: 60, total rewards: -96.599984.3, cost: 0.002025, total money: 9903.400016
# epoch: 70, total rewards: -82.029996.3, cost: 0.001509, total money: 9856.320002
# epoch: 80, total rewards: -66.049971.3, cost: 0.001663, total money: 9809.160028
# epoch: 90, total rewards: 65.420018.3, cost: 0.003234, total money: 10003.260018
# epoch: 100, total rewards: 4.679964.3, cost: 0.012715, total money: 9755.389963
# epoch: 110, total rewards: -39.090027.3, cost: 0.001192, total money: 9960.909973
# epoch: 120, total rewards: -74.770007.3, cost: 0.003645, total money: 9800.479993
# epoch: 130, total rewards: -131.280018.3, cost: 0.001598, total money: 9806.699982
# epoch: 140, total rewards: -4.759982.3, cost: 0.000674, total money: 9933.220018
# epoch: 150, total rewards: -54.230012.3, cost: 0.005966, total money: 9821.489989
# epoch: 160, total rewards: 23.620000.3, cost: 0.006195, total money: 9396.649994
# epoch: 170, total rewards: -278.549982.3, cost: 0.013090, total money: 9223.920021
# epoch: 180, total rewards: -15.389926.3, cost: 0.001228, total money: 9736.170075
# epoch: 190, total rewards: 35.600023.3, cost: 0.001111, total money: 10035.600023
# epoch: 200, total rewards: 47.950025.3, cost: 0.000310, total money: 10047.950025

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 70.949997, total balance 9929.050003
# day 1: buy 1 unit at price 71.550003, total balance 9857.500000
# day 2: buy 1 unit at price 72.680000, total balance 9784.820000
# day 3: buy 1 unit at price 73.300003, total balance 9711.519997
# day 4: buy 1 unit at price 73.370003, total balance 9638.149994
# day 5: buy 1 unit at price 73.459999, total balance 9564.689995
# day 6: buy 1 unit at price 73.970001, total balance 9490.719994
# day 7: buy 1 unit at price 74.010002, total balance 9416.709992
# day 8: buy 1 unit at price 74.559998, total balance 9342.149994
# day 9: buy 1 unit at price 74.730003, total balance 9267.419991
# day 10: buy 1 unit at price 75.839996, total balance 9191.579995
# day 25: buy 1 unit at price 76.519997, total balance 9115.059998
# day 26: buy 1 unit at price 75.160004, total balance 9039.899994
# day 27: buy 1 unit at price 76.290001, total balance 8963.609993
# day 28: buy 1 unit at price 77.430000, total balance 8886.179993
# day 29, sell 1 unit at price 78.110001, investment 10.091620 %, total balance 8964.289994,
# day 30, sell 1 unit at price 79.820000, investment 11.558346 %, total balance 9044.109994,
# day 31, sell 1 unit at price 81.370003, investment 11.956526 %, total balance 9125.479997,
# day 32, sell 1 unit at price 80.949997, investment 10.436553 %, total balance 9206.429994,
# day 33, sell 1 unit at price 81.540001, investment 11.135338 %, total balance 9287.969995,
# day 34, sell 1 unit at price 81.800003, investment 11.353123 %, total balance 9369.769998,
# day 35, sell 1 unit at price 81.610001, investment 10.328511 %, total balance 9451.379999,
# day 37, sell 1 unit at price 82.970001, investment 12.106470 %, total balance 9534.350000,
# day 38, sell 1 unit at price 82.510002, investment 10.662559 %, total balance 9616.860002,
# day 40, sell 1 unit at price 80.650002, investment 7.921850 %, total balance 9697.510004,
# day 41, sell 1 unit at price 81.279999, investment 7.173000 %, total balance 9778.790003,
# day 42, sell 1 unit at price 82.269997, investment 7.514376 %, total balance 9861.060000,
# day 43, sell 1 unit at price 83.070000, investment 10.524209 %, total balance 9944.130000,
# day 44, sell 1 unit at price 83.250000, investment 9.123082 %, total balance 10027.380000,
# day 45, sell 1 unit at price 83.220001, investment 7.477723 %, total balance 10110.600001,
# day 63: buy 1 unit at price 80.720001, total balance 10029.880000
# day 64: buy 1 unit at price 80.919998, total balance 9948.960002
# day 65, sell 1 unit at price 79.070000, investment -2.044104 %, total balance 10028.030002,
# day 67, sell 1 unit at price 80.400002, investment -0.642605 %, total balance 10108.430004,
# day 68: buy 1 unit at price 79.930000, total balance 10028.500004
# day 69: buy 1 unit at price 81.550003, total balance 9946.950001
# day 70, sell 1 unit at price 80.820000, investment 1.113474 %, total balance 10027.770001,
# day 71, sell 1 unit at price 81.769997, investment 0.269766 %, total balance 10109.539998,
# day 73: buy 1 unit at price 82.699997, total balance 10026.840001
# day 74, sell 1 unit at price 82.370003, investment -0.399025 %, total balance 10109.210004,
# day 87: buy 1 unit at price 75.550003, total balance 10033.660001
# day 89: buy 1 unit at price 75.949997, total balance 9957.710004
# day 90: buy 1 unit at price 76.580002, total balance 9881.130002
# day 91, sell 1 unit at price 75.860001, investment 0.410322 %, total balance 9956.990003,
# day 92: buy 1 unit at price 75.459999, total balance 9881.530004
# day 93, sell 1 unit at price 75.389999, investment -0.737325 %, total balance 9956.920003,
# day 94, sell 1 unit at price 75.779999, investment -1.044663 %, total balance 10032.700002,
# day 95, sell 1 unit at price 76.040001, investment 0.768622 %, total balance 10108.740003,
# day 102: buy 1 unit at price 75.690002, total balance 10033.050001
# day 103, sell 1 unit at price 75.349998, investment -0.449206 %, total balance 10108.399999,
# day 112: buy 1 unit at price 78.019997, total balance 10030.380002
# day 113: buy 1 unit at price 78.550003, total balance 9951.829999
# day 114, sell 1 unit at price 80.699997, investment 3.435017 %, total balance 10032.529996,
# day 115, sell 1 unit at price 80.010002, investment 1.858687 %, total balance 10112.539998,
# day 124: buy 1 unit at price 78.989998, total balance 10033.550000
# day 125, sell 1 unit at price 79.489998, investment 0.632992 %, total balance 10113.039998,
# day 136: buy 1 unit at price 82.330002, total balance 10030.709996
# day 137: buy 1 unit at price 82.379997, total balance 9948.329999
# day 138: buy 1 unit at price 82.239998, total balance 9866.090001
# day 139: buy 1 unit at price 82.669998, total balance 9783.420003
# day 140, sell 1 unit at price 82.260002, investment -0.085024 %, total balance 9865.680005,
# day 141, sell 1 unit at price 82.839996, investment 0.558387 %, total balance 9948.520001,
# day 142, sell 1 unit at price 82.720001, investment 0.583661 %, total balance 10031.240002,
# day 143, sell 1 unit at price 81.559998, investment -1.342688 %, total balance 10112.800000,
# day 146: buy 1 unit at price 82.089996, total balance 10030.710004
# day 147: buy 1 unit at price 76.860001, total balance 9953.850003
# day 148, sell 1 unit at price 77.820000, investment -5.201603 %, total balance 10031.670003,
# day 149, sell 1 unit at price 78.489998, investment 2.120735 %, total balance 10110.160001,
# day 151: buy 1 unit at price 77.239998, total balance 10032.920003
# day 152, sell 1 unit at price 76.260002, investment -1.268768 %, total balance 10109.180005,
# day 153: buy 1 unit at price 75.559998, total balance 10033.620007
# day 154, sell 1 unit at price 75.419998, investment -0.185283 %, total balance 10109.040005,
# day 158: buy 1 unit at price 75.559998, total balance 10033.480007
# day 159: buy 1 unit at price 74.910004, total balance 9958.570003
# day 160: buy 1 unit at price 74.900002, total balance 9883.670001
# day 161, sell 1 unit at price 75.260002, investment -0.397030 %, total balance 9958.930003,
# day 162: buy 1 unit at price 75.110001, total balance 9883.820002
# day 163, sell 1 unit at price 75.860001, investment 1.268184 %, total balance 9959.680003,
# day 164, sell 1 unit at price 76.610001, investment 2.283043 %, total balance 10036.290004,
# day 165, sell 1 unit at price 76.660004, investment 2.063644 %, total balance 10112.950008,
# day 244: buy 1 unit at price 62.779999, total balance 10050.170009
# day 245: buy 1 unit at price 60.090000, total balance 9990.080009
# day 246: buy 1 unit at price 60.020000, total balance 9930.060009
# day 247, sell 1 unit at price 62.360001, investment -0.669000 %, total balance 9992.420010,
# day 249, sell 1 unit at price 62.930000, investment 4.726244 %, total balance 10055.350010,
# day 250, sell 1 unit at price 63.480000, investment 5.764745 %, total balance 10118.830010,
# day 261: buy 1 unit at price 65.790001, total balance 10053.040009
# day 262: buy 1 unit at price 66.550003, total balance 9986.490006
# day 264, sell 1 unit at price 66.800003, investment 1.535191 %, total balance 10053.290009,
# day 265, sell 1 unit at price 67.059998, investment 0.766334 %, total balance 10120.350007,
# day 356: buy 1 unit at price 61.099998, total balance 10059.250009
# day 357, sell 1 unit at price 62.180000, investment 1.767597 %, total balance 10121.430009,
# day 359: buy 1 unit at price 62.779999, total balance 10058.650010
# day 360: buy 1 unit at price 63.029999, total balance 9995.620011
# day 361: buy 1 unit at price 63.369999, total balance 9932.250012
# day 362: buy 1 unit at price 62.150002, total balance 9870.100010
# day 364, sell 1 unit at price 61.639999, investment -1.815865 %, total balance 9931.740009,
# day 367, sell 1 unit at price 62.610001, investment -0.666346 %, total balance 9994.350010,
# day 368, sell 1 unit at price 64.169998, investment 1.262425 %, total balance 10058.520008,
# day 369, sell 1 unit at price 64.459999, investment 3.716809 %, total balance 10122.980007,
# day 417: buy 1 unit at price 61.380001, total balance 10061.600006
# day 418, sell 1 unit at price 61.389999, investment 0.016289 %, total balance 10122.990005,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Duel Q-learning agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Duel Q-learning agent'

class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 512, activation = tf.nn.relu)
        tensor_action, tensor_validation = tf.split(feed,2,1)
        feed_action = tf.layers.dense(tensor_action, self.action_size)
        feed_validation = tf.layers.dense(tensor_validation, 1)
        self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: -593.979994.3, cost: 0.066998, total money: 5455.770005
# epoch: 20, total rewards: -559.099990.3, cost: 0.058373, total money: 5563.420005
# epoch: 30, total rewards: -616.739988.3, cost: 0.053546, total money: 5575.830010
# epoch: 40, total rewards: -620.809993.3, cost: 0.057340, total money: 5285.620002
# epoch: 50, total rewards: -598.389990.3, cost: 0.048313, total money: 5522.700005
# epoch: 60, total rewards: -594.389991.3, cost: 0.048043, total money: 5407.300003
# epoch: 70, total rewards: -607.219982.3, cost: 0.056699, total money: 5019.410007
# epoch: 80, total rewards: -611.319995.3, cost: 0.051733, total money: 5112.949997
# epoch: 90, total rewards: -629.289989.3, cost: 0.052590, total money: 5006.710003
# epoch: 100, total rewards: -559.459993.3, cost: 0.058429, total money: 4727.960001
# epoch: 110, total rewards: -571.789986.3, cost: 0.053588, total money: 4859.000003
# epoch: 120, total rewards: -539.479981.3, cost: 0.053242, total money: 4826.470012
# epoch: 130, total rewards: -581.309991.3, cost: 0.059975, total money: 4509.420009
# epoch: 140, total rewards: -612.329983.3, cost: 0.051620, total money: 4824.650009
# epoch: 150, total rewards: -595.079984.3, cost: 0.054433, total money: 4617.600016
# epoch: 160, total rewards: -560.139982.3, cost: 0.059271, total money: 4312.200018
# epoch: 170, total rewards: -578.159982.3, cost: 0.050863, total money: 4644.880015
# epoch: 180, total rewards: -551.309987.3, cost: 0.050956, total money: 4610.450012
# epoch: 190, total rewards: -564.719984.3, cost: 0.052137, total money: 4583.640021
# epoch: 200, total rewards: -583.939985.3, cost: 0.055118, total money: 4439.940016

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 1: buy 1 unit at price 71.550003, total balance 9928.449997
# day 2: buy 1 unit at price 72.680000, total balance 9855.769997
# day 3: buy 1 unit at price 73.300003, total balance 9782.469994
# day 4: buy 1 unit at price 73.370003, total balance 9709.099991
# day 7: buy 1 unit at price 74.010002, total balance 9635.089989
# day 8: buy 1 unit at price 74.559998, total balance 9560.529991
# day 9, sell 1 unit at price 74.730003, investment 4.444444 %, total balance 9635.259994,
# day 10: buy 1 unit at price 75.839996, total balance 9559.419998
# day 11: buy 1 unit at price 76.750000, total balance 9482.669998
# day 12: buy 1 unit at price 77.290001, total balance 9405.379997
# day 13, sell 1 unit at price 77.959999, investment 7.264721 %, total balance 9483.339996,
# day 14: buy 1 unit at price 78.260002, total balance 9405.079994
# day 15: buy 1 unit at price 78.449997, total balance 9326.629997
# day 16: buy 1 unit at price 77.949997, total balance 9248.680000
# day 17: buy 1 unit at price 78.430000, total balance 9170.250000
# day 18: buy 1 unit at price 78.150002, total balance 9092.099998
# day 19: buy 1 unit at price 77.760002, total balance 9014.339996
# day 20: buy 1 unit at price 77.980003, total balance 8936.359993
# day 21: buy 1 unit at price 77.500000, total balance 8858.859993
# day 25: buy 1 unit at price 76.519997, total balance 8782.339996
# day 26: buy 1 unit at price 75.160004, total balance 8707.179992
# day 27: buy 1 unit at price 76.290001, total balance 8630.889991
# day 29: buy 1 unit at price 78.110001, total balance 8552.779990
# day 31, sell 1 unit at price 81.370003, investment 11.009549 %, total balance 8634.149993,
# day 32: buy 1 unit at price 80.949997, total balance 8553.199996
# day 36, sell 1 unit at price 82.529999, investment 12.484661 %, total balance 8635.729995,
# day 37: buy 1 unit at price 82.970001, total balance 8552.759994
# day 39: buy 1 unit at price 82.019997, total balance 8470.739997
# day 40, sell 1 unit at price 80.650002, investment 8.971760 %, total balance 8551.389999,
# day 41, sell 1 unit at price 81.279999, investment 9.012877 %, total balance 8632.669998,
# day 42: buy 1 unit at price 82.269997, total balance 8550.400001
# day 43: buy 1 unit at price 83.070000, total balance 8467.330001
# day 44: buy 1 unit at price 83.250000, total balance 8384.080001
# day 45: buy 1 unit at price 83.220001, total balance 8300.860000
# day 46: buy 1 unit at price 84.709999, total balance 8216.150001
# day 51: buy 1 unit at price 84.599998, total balance 8131.550003
# day 52: buy 1 unit at price 83.809998, total balance 8047.740005
# day 53, sell 1 unit at price 84.309998, investment 11.168252 %, total balance 8132.050003,
# day 54: buy 1 unit at price 83.349998, total balance 8048.700005
# day 55: buy 1 unit at price 80.970001, total balance 7967.730004
# day 56, sell 1 unit at price 79.260002, investment 3.270361 %, total balance 8046.990006,
# day 57, sell 1 unit at price 81.629997, investment 5.615210 %, total balance 8128.620003,
# day 58: buy 1 unit at price 80.080002, total balance 8048.540001
# day 59: buy 1 unit at price 79.669998, total balance 7968.870003
# day 60: buy 1 unit at price 80.500000, total balance 7888.370003
# day 61: buy 1 unit at price 79.209999, total balance 7809.160004
# day 62: buy 1 unit at price 80.050003, total balance 7729.110001
# day 63: buy 1 unit at price 80.720001, total balance 7648.390000
# day 64, sell 1 unit at price 80.919998, investment 3.398921 %, total balance 7729.309998,
# day 65: buy 1 unit at price 79.070000, total balance 7650.239998
# day 67, sell 1 unit at price 80.400002, investment 2.485666 %, total balance 7730.640000,
# day 68: buy 1 unit at price 79.930000, total balance 7650.710000
# day 69, sell 1 unit at price 81.550003, investment 4.618353 %, total balance 7732.260003,
# day 72: buy 1 unit at price 82.190002, total balance 7650.070001
# day 73, sell 1 unit at price 82.699997, investment 5.444341 %, total balance 7732.769998,
# day 74, sell 1 unit at price 82.370003, investment 5.399873 %, total balance 7815.140001,
# day 78, sell 1 unit at price 80.910004, investment 4.050928 %, total balance 7896.050005,
# day 79: buy 1 unit at price 81.730003, total balance 7814.320002
# day 81: buy 1 unit at price 81.820000, total balance 7732.500002
# day 86: buy 1 unit at price 77.860001, total balance 7654.640001
# day 88: buy 1 unit at price 75.029999, total balance 7579.610002
# day 89: buy 1 unit at price 75.949997, total balance 7503.660005
# day 90: buy 1 unit at price 76.580002, total balance 7427.080003
# day 91: buy 1 unit at price 75.860001, total balance 7351.220002
# day 92, sell 1 unit at price 75.459999, investment -3.231603 %, total balance 7426.680001,
# day 93, sell 1 unit at price 75.389999, investment -2.722582 %, total balance 7502.070000,
# day 95, sell 1 unit at price 76.040001, investment -0.627282 %, total balance 7578.110001,
# day 100: buy 1 unit at price 75.779999, total balance 7502.330002
# day 103, sell 1 unit at price 75.349998, investment 0.252786 %, total balance 7577.680000,
# day 104, sell 1 unit at price 76.870003, investment 0.760260 %, total balance 7654.550003,
# day 105, sell 1 unit at price 77.220001, investment -1.139419 %, total balance 7731.770004,
# day 106, sell 1 unit at price 77.029999, investment -4.842493 %, total balance 7808.800003,
# day 109, sell 1 unit at price 77.110001, investment -7.062794 %, total balance 7885.910004,
# day 110, sell 1 unit at price 76.970001, investment -6.157030 %, total balance 7962.880005,
# day 111: buy 1 unit at price 78.250000, total balance 7884.630005
# day 114, sell 1 unit at price 80.699997, investment -1.908351 %, total balance 7965.330002,
# day 117, sell 1 unit at price 78.820000, investment -5.116167 %, total balance 8044.150002,
# day 118, sell 1 unit at price 77.680000, investment -6.690691 %, total balance 8121.830002,
# day 119: buy 1 unit at price 78.699997, total balance 8043.130005
# day 120: buy 1 unit at price 77.959999, total balance 7965.170006
# day 121: buy 1 unit at price 78.449997, total balance 7886.720009
# day 124: buy 1 unit at price 78.989998, total balance 7807.730011
# day 126: buy 1 unit at price 79.900002, total balance 7727.830009
# day 128: buy 1 unit at price 80.559998, total balance 7647.270011
# day 129: buy 1 unit at price 80.980003, total balance 7566.290008
# day 130, sell 1 unit at price 81.750000, investment -1.766403 %, total balance 7648.040008,
# day 133: buy 1 unit at price 81.709999, total balance 7566.330009
# day 134, sell 1 unit at price 81.959999, investment -3.246370 %, total balance 7648.290008,
# day 135, sell 1 unit at price 82.739998, investment -2.198582 %, total balance 7731.030006,
# day 136: buy 1 unit at price 82.330002, total balance 7648.700004
# day 138: buy 1 unit at price 82.239998, total balance 7566.460006
# day 139, sell 1 unit at price 82.669998, investment -1.360220 %, total balance 7649.130004,
# day 140: buy 1 unit at price 82.260002, total balance 7566.870002
# day 141: buy 1 unit at price 82.839996, total balance 7484.030006
# day 142, sell 1 unit at price 82.720001, investment -0.755845 %, total balance 7566.750007,
# day 143: buy 1 unit at price 81.559998, total balance 7485.190009
# day 145: buy 1 unit at price 81.500000, total balance 7403.690009
# day 147: buy 1 unit at price 76.860001, total balance 7326.830008
# day 149, sell 1 unit at price 78.489998, investment -3.062866 %, total balance 7405.320006,
# day 150: buy 1 unit at price 78.070000, total balance 7327.250006
# day 151: buy 1 unit at price 77.239998, total balance 7250.010008
# day 153, sell 1 unit at price 75.559998, investment -5.644360 %, total balance 7325.570006,
# day 154: buy 1 unit at price 75.419998, total balance 7250.150008
# day 156, sell 1 unit at price 74.540001, investment -6.439058 %, total balance 7324.690009,
# day 160, sell 1 unit at price 74.900002, investment -6.956519 %, total balance 7399.590011,
# day 161, sell 1 unit at price 75.260002, investment -4.986740 %, total balance 7474.850013,
# day 163: buy 1 unit at price 75.860001, total balance 7398.990012
# day 164, sell 1 unit at price 76.610001, investment -4.297317 %, total balance 7475.600013,
# day 165, sell 1 unit at price 76.660004, investment -5.029729 %, total balance 7552.260017,
# day 167: buy 1 unit at price 77.389999, total balance 7474.870018
# day 169, sell 1 unit at price 75.639999, investment -4.337930 %, total balance 7550.510017,
# day 170, sell 1 unit at price 75.290001, investment -5.805078 %, total balance 7625.800018,
# day 171, sell 1 unit at price 75.720001, investment -7.872005 %, total balance 7701.520019,
# day 172: buy 1 unit at price 75.730003, total balance 7625.790016
# day 174, sell 1 unit at price 76.610001, investment -6.264532 %, total balance 7702.400017,
# day 175: buy 1 unit at price 75.699997, total balance 7626.700020
# day 177: buy 1 unit at price 76.279999, total balance 7550.420021
# day 182: buy 1 unit at price 77.610001, total balance 7472.810020
# day 183: buy 1 unit at price 77.269997, total balance 7395.540023
# day 186, sell 1 unit at price 76.760002, investment -6.184305 %, total balance 7472.300025,
# day 187, sell 1 unit at price 77.150002, investment -0.911892 %, total balance 7549.450027,
# day 188, sell 1 unit at price 76.980003, investment 2.598966 %, total balance 7626.430030,
# day 189, sell 1 unit at price 77.279999, investment 1.751155 %, total balance 7703.710029,
# day 190: buy 1 unit at price 76.559998, total balance 7627.150031
# day 193: buy 1 unit at price 74.110001, total balance 7553.040030
# day 195: buy 1 unit at price 71.440002, total balance 7481.600028
# day 197, sell 1 unit at price 72.169998, investment -5.758689 %, total balance 7553.770026,
# day 198: buy 1 unit at price 72.010002, total balance 7481.760024
# day 200: buy 1 unit at price 73.989998, total balance 7407.770026
# day 201, sell 1 unit at price 73.589996, investment -2.992361 %, total balance 7481.360022,
# day 202, sell 1 unit at price 73.690002, investment -2.757980 %, total balance 7555.050024,
# day 203: buy 1 unit at price 73.589996, total balance 7481.460028
# day 204, sell 1 unit at price 73.410004, investment -6.185298 %, total balance 7554.870032,
# day 208: buy 1 unit at price 69.220001, total balance 7485.650031
# day 209, sell 1 unit at price 66.519997, investment -15.476494 %, total balance 7552.170028,
# day 210, sell 1 unit at price 69.029999, investment -11.454592 %, total balance 7621.200027,
# day 211: buy 1 unit at price 68.779999, total balance 7552.420028
# day 212: buy 1 unit at price 69.500000, total balance 7482.920028
# day 213: buy 1 unit at price 69.459999, total balance 7413.460029
# day 214, sell 1 unit at price 69.650002, investment -11.217330 %, total balance 7483.110031,
# day 215: buy 1 unit at price 71.370003, total balance 7411.740028
# day 216: buy 1 unit at price 71.239998, total balance 7340.500030
# day 218: buy 1 unit at price 69.550003, total balance 7270.950027
# day 222, sell 1 unit at price 70.330002, investment -10.963408 %, total balance 7341.280029,
# day 223: buy 1 unit at price 69.209999, total balance 7272.070030
# day 225, sell 1 unit at price 68.669998, investment -14.055073 %, total balance 7340.740028,
# day 226, sell 1 unit at price 67.980003, investment -15.615684 %, total balance 7408.720031,
# day 227: buy 1 unit at price 68.750000, total balance 7339.970031
# day 228: buy 1 unit at price 69.900002, total balance 7270.070029
# day 229, sell 1 unit at price 70.760002, investment -12.620401 %, total balance 7340.830031,
# day 230: buy 1 unit at price 70.300003, total balance 7270.530028
# day 231: buy 1 unit at price 71.230003, total balance 7199.300025
# day 232: buy 1 unit at price 71.930000, total balance 7127.370025
# day 235, sell 1 unit at price 68.000000, investment -16.778851 %, total balance 7195.370025,
# day 236, sell 1 unit at price 67.089996, investment -18.510878 %, total balance 7262.460021,
# day 238, sell 1 unit at price 68.029999, investment -17.278696 %, total balance 7330.490020,
# day 240: buy 1 unit at price 67.769997, total balance 7262.720023
# day 241, sell 1 unit at price 64.669998, investment -21.383423 %, total balance 7327.390021,
# day 242, sell 1 unit at price 64.620003, investment -21.994198 %, total balance 7392.010024,
# day 243: buy 1 unit at price 64.230003, total balance 7327.780021
# day 244: buy 1 unit at price 62.779999, total balance 7265.000022
# day 248: buy 1 unit at price 63.080002, total balance 7201.920020
# day 250, sell 1 unit at price 63.480000, investment -22.167727 %, total balance 7265.400020,
# day 251, sell 1 unit at price 63.090000, investment -22.588957 %, total balance 7328.490020,
# day 253, sell 1 unit at price 63.700001, investment -17.122040 %, total balance 7392.190021,
# day 254: buy 1 unit at price 63.599998, total balance 7328.590023
# day 258, sell 1 unit at price 64.919998, investment -16.843861 %, total balance 7393.510021,
# day 259, sell 1 unit at price 64.629997, investment -16.325740 %, total balance 7458.140018,
# day 260, sell 1 unit at price 65.989998, investment -12.503315 %, total balance 7524.130016,
# day 261, sell 1 unit at price 65.790001, investment -13.274453 %, total balance 7589.920017,
# day 262: buy 1 unit at price 66.550003, total balance 7523.370014
# day 263, sell 1 unit at price 67.820000, investment -12.365938 %, total balance 7591.190014,
# day 264: buy 1 unit at price 66.800003, total balance 7524.390011
# day 266: buy 1 unit at price 68.120003, total balance 7456.270008
# day 268: buy 1 unit at price 68.949997, total balance 7387.320011
# day 271: buy 1 unit at price 69.680000, total balance 7317.640011
# day 272: buy 1 unit at price 70.139999, total balance 7247.500012
# day 273: buy 1 unit at price 71.290001, total balance 7176.210011
# day 274: buy 1 unit at price 71.209999, total balance 7105.000012
# day 275: buy 1 unit at price 74.500000, total balance 7030.500012
# day 276: buy 1 unit at price 72.989998, total balance 6957.510014
# day 279: buy 1 unit at price 73.449997, total balance 6884.060017
# day 281: buy 1 unit at price 73.120003, total balance 6810.940014
# day 282: buy 1 unit at price 73.559998, total balance 6737.380016
# day 284: buy 1 unit at price 72.250000, total balance 6665.130016
# day 286, sell 1 unit at price 72.379997, investment -4.423618 %, total balance 6737.510013,
# day 287: buy 1 unit at price 72.250000, total balance 6665.260013
# day 288: buy 1 unit at price 72.040001, total balance 6593.220012
# day 289: buy 1 unit at price 71.309998, total balance 6521.910014
# day 291, sell 1 unit at price 72.129997, investment -4.715984 %, total balance 6594.040011,
# day 292: buy 1 unit at price 71.760002, total balance 6522.280009
# day 294: buy 1 unit at price 71.459999, total balance 6450.820010
# day 296: buy 1 unit at price 71.150002, total balance 6379.670008
# day 298, sell 1 unit at price 71.779999, investment -5.899318 %, total balance 6451.450007,
# day 301: buy 1 unit at price 72.129997, total balance 6379.320010
# day 302, sell 1 unit at price 71.879997, investment -7.383074 %, total balance 6451.200007,
# day 303: buy 1 unit at price 72.019997, total balance 6379.180010
# day 306: buy 1 unit at price 70.889999, total balance 6308.290011
# day 307, sell 1 unit at price 70.750000, investment -8.437941 %, total balance 6379.040011,
# day 309: buy 1 unit at price 71.029999, total balance 6308.010012
# day 310: buy 1 unit at price 71.580002, total balance 6236.430010
# day 312: buy 1 unit at price 73.849998, total balance 6162.580012
# day 314, sell 1 unit at price 74.180000, investment -3.108670 %, total balance 6236.760012,
# day 315, sell 1 unit at price 73.790001, investment -0.431791 %, total balance 6310.550013,
# day 316, sell 1 unit at price 74.199997, investment 3.863375 %, total balance 6384.750010,
# day 317: buy 1 unit at price 74.410004, total balance 6310.340006
# day 318, sell 1 unit at price 74.370003, investment 3.277324 %, total balance 6384.710009,
# day 320: buy 1 unit at price 74.190002, total balance 6310.520007
# day 322, sell 1 unit at price 74.320000, investment 0.446009 %, total balance 6384.840007,
# day 323: buy 1 unit at price 71.900002, total balance 6312.940005
# day 324, sell 1 unit at price 72.150002, investment -1.956780 %, total balance 6385.090007,
# day 325: buy 1 unit at price 71.339996, total balance 6313.750011
# day 326: buy 1 unit at price 71.480003, total balance 6242.270008
# day 327: buy 1 unit at price 72.849998, total balance 6169.420010
# day 328: buy 1 unit at price 72.669998, total balance 6096.750012
# day 329: buy 1 unit at price 72.930000, total balance 6023.820012
# day 330: buy 1 unit at price 73.370003, total balance 5950.450009
# day 333: buy 1 unit at price 72.180000, total balance 5878.270009
# day 337: buy 1 unit at price 58.509998, total balance 5819.760011
# day 338: buy 1 unit at price 58.980000, total balance 5760.780011
# day 339: buy 1 unit at price 59.099998, total balance 5701.680013
# day 340: buy 1 unit at price 59.130001, total balance 5642.550012
# day 341, sell 1 unit at price 56.880001, investment -17.827217 %, total balance 5699.430013,
# day 343, sell 1 unit at price 58.599998, investment -14.800816 %, total balance 5758.030011,
# day 349, sell 1 unit at price 61.080002, investment -12.115105 %, total balance 5819.110013,
# day 351, sell 1 unit at price 62.070000, investment -10.639216 %, total balance 5881.180013,
# day 352, sell 1 unit at price 61.880001, investment -13.296906 %, total balance 5943.060014,
# day 353, sell 1 unit at price 62.360001, investment -12.464903 %, total balance 6005.420015,
# day 354, sell 1 unit at price 61.930000, investment -10.956150 %, total balance 6067.350015,
# day 355, sell 1 unit at price 60.540001, investment -12.527089 %, total balance 6127.890016,
# day 357, sell 1 unit at price 62.180000, investment -9.556364 %, total balance 6190.070016,
# day 358: buy 1 unit at price 61.900002, total balance 6128.170014
# day 359: buy 1 unit at price 62.779999, total balance 6065.390015
# day 360: buy 1 unit at price 63.029999, total balance 6002.360016
# day 365: buy 1 unit at price 62.560001, total balance 5939.800015
# day 366: buy 1 unit at price 63.720001, total balance 5876.080014
# day 368, sell 1 unit at price 64.169998, investment -8.197430 %, total balance 5940.250012,
# day 369: buy 1 unit at price 64.459999, total balance 5875.790013
# day 371, sell 1 unit at price 63.160000, investment -10.156476 %, total balance 5938.950013,
# day 372: buy 1 unit at price 63.060001, total balance 5875.890012
# day 374: buy 1 unit at price 63.389999, total balance 5812.500013
# day 375: buy 1 unit at price 64.279999, total balance 5748.220014
# day 376: buy 1 unit at price 64.360001, total balance 5683.860013
# day 378: buy 1 unit at price 64.709999, total balance 5619.150014
# day 380: buy 1 unit at price 64.379997, total balance 5554.770017
# day 382, sell 1 unit at price 65.290001, investment -8.339185 %, total balance 5620.060018,
# day 383: buy 1 unit at price 65.860001, total balance 5554.200017
# day 384: buy 1 unit at price 65.820000, total balance 5488.380017
# day 387: buy 1 unit at price 65.930000, total balance 5422.450017
# day 389, sell 1 unit at price 65.550003, investment -8.869730 %, total balance 5488.000020,
# day 390: buy 1 unit at price 65.870003, total balance 5422.130017
# day 391, sell 1 unit at price 65.760002, investment -2.965907 %, total balance 5487.890019,
# day 394, sell 1 unit at price 66.040001, investment 2.817995 %, total balance 5553.930020,
# day 395: buy 1 unit at price 65.330002, total balance 5488.600018
# day 396: buy 1 unit at price 65.139999, total balance 5423.460019
# day 397: buy 1 unit at price 66.410004, total balance 5357.050015
# day 398: buy 1 unit at price 63.490002, total balance 5293.560013
# day 401: buy 1 unit at price 62.209999, total balance 5231.350014
# day 402: buy 1 unit at price 63.959999, total balance 5167.390015
# day 403: buy 1 unit at price 62.459999, total balance 5104.930016
# day 404, sell 1 unit at price 61.169998, investment -2.564513 %, total balance 5166.100014,
# day 406: buy 1 unit at price 60.650002, total balance 5105.450012
# day 408, sell 1 unit at price 61.220001, investment -2.948638 %, total balance 5166.670013,
# day 409: buy 1 unit at price 61.860001, total balance 5104.810012
# day 412, sell 1 unit at price 61.200001, investment -3.773580 %, total balance 5166.010013,
# day 415, sell 1 unit at price 59.700001, investment -10.293015 %, total balance 5225.710014,
# day 416: buy 1 unit at price 60.240002, total balance 5165.470012
# day 417: buy 1 unit at price 61.380001, total balance 5104.090011
# day 418: buy 1 unit at price 61.389999, total balance 5042.700012
# day 420, sell 1 unit at price 62.410000, investment -6.571860 %, total balance 5105.110012,
# day 421, sell 1 unit at price 64.260002, investment -5.666472 %, total balance 5169.370014,
# day 422: buy 1 unit at price 64.449997, total balance 5104.920017
# day 423: buy 1 unit at price 64.180000, total balance 5040.740017
# day 424, sell 1 unit at price 64.739998, investment -6.105873 %, total balance 5105.480015,
# day 425, sell 1 unit at price 65.360001, investment -6.199769 %, total balance 5170.840016,
# day 426: buy 1 unit at price 64.839996, total balance 5106.000020
# day 429: buy 1 unit at price 64.000000, total balance 5042.000020
# day 430: buy 1 unit at price 63.509998, total balance 4978.490022
# day 431: buy 1 unit at price 63.470001, total balance 4915.020021
# day 432, sell 1 unit at price 61.799999, investment -11.890505 %, total balance 4976.820020,
# day 433: buy 1 unit at price 60.830002, total balance 4915.990018
# day 435, sell 1 unit at price 60.189999, investment -15.570209 %, total balance 4976.180017,
# day 436: buy 1 unit at price 59.660000, total balance 4916.520017
# day 437: buy 1 unit at price 58.750000, total balance 4857.770017
# day 438: buy 1 unit at price 60.270000, total balance 4797.500017
# day 439: buy 1 unit at price 60.619999, total balance 4736.880018
# day 444: buy 1 unit at price 58.900002, total balance 4677.980016
# day 445, sell 1 unit at price 59.439999, investment -16.528578 %, total balance 4737.420015,
# day 449, sell 1 unit at price 61.340000, investment -17.664430 %, total balance 4798.760015,
# day 450, sell 1 unit at price 61.389999, investment -15.892587 %, total balance 4860.150014,
# day 451: buy 1 unit at price 61.380001, total balance 4798.770013
# day 452, sell 1 unit at price 60.639999, investment -17.440434 %, total balance 4859.410012,
# day 453, sell 1 unit at price 60.779999, investment -16.876372 %, total balance 4920.190011,
# day 454: buy 1 unit at price 59.900002, total balance 4860.290009
# day 457: buy 1 unit at price 60.459999, total balance 4799.830010
# day 462: buy 1 unit at price 61.230000, total balance 4738.600010
# day 464: buy 1 unit at price 61.919998, total balance 4676.680012
# day 468, sell 1 unit at price 62.639999, investment -14.845024 %, total balance 4739.320011,
# day 470, sell 1 unit at price 62.509998, investment -13.480972 %, total balance 4801.830009,
# day 471: buy 1 unit at price 63.110001, total balance 4738.720008
# day 472: buy 1 unit at price 63.380001, total balance 4675.340007
# day 474: buy 1 unit at price 63.919998, total balance 4611.420009
# day 475: buy 1 unit at price 63.509998, total balance 4547.910011
# day 476, sell 1 unit at price 63.400002, investment -12.249132 %, total balance 4611.310013,
# day 477: buy 1 unit at price 63.189999, total balance 4548.120014
# day 478: buy 1 unit at price 63.360001, total balance 4484.760013
# day 480: buy 1 unit at price 64.150002, total balance 4420.610011
# day 485: buy 1 unit at price 62.209999, total balance 4358.400012
# day 486, sell 1 unit at price 62.660000, investment -13.020545 %, total balance 4421.060012,
# day 487: buy 1 unit at price 61.880001, total balance 4359.180011
# day 488: buy 1 unit at price 61.099998, total balance 4298.080013
# day 494, sell 1 unit at price 62.320000, investment -12.606925 %, total balance 4360.400013,
# day 497, sell 1 unit at price 62.630001, investment -12.722966 %, total balance 4423.030014,
# day 500, sell 1 unit at price 62.160000, investment -13.014273 %, total balance 4485.190014,
# day 502, sell 1 unit at price 62.020000, investment -12.832047 %, total balance 4547.210014,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Double Duel Q-learning agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Double Duel Q-learning agent'

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate):
        self.X = tf.placeholder(tf.float32, (None, input_size))
        self.Y = tf.placeholder(tf.float32, (None, output_size))
        feed = tf.layers.dense(self.X, layer_size, activation = tf.nn.relu)
        tensor_action, tensor_validation = tf.split(feed,2,1)
        feed_action = tf.layers.dense(tensor_action, output_size)
        feed_validation = tf.layers.dense(tensor_validation, 1)
        self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self):
        for i in range(len(self.trainable)//2):
            assign_op = self.trainable[i+len(self.trainable)//2].assign(self.trainable[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.predict(states)
        Q_new = self.predict(new_states)
        Q_new_negative = self.sess.run(self.model_negative.logits, feed_dict={self.model_negative.X:new_states})
        replay_size = len(replay)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, done_r = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not done_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
        return X, Y

    def predict(self, inputs):
        return self.sess.run(self.model.logits, feed_dict={self.model.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign()
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: -230.839917.3, cost: 0.031358, total money: 8719.380092
# epoch: 20, total rewards: -2.369973.3, cost: 0.005680, total money: 9685.040027
# epoch: 30, total rewards: -514.290057.3, cost: 0.021341, total money: 9171.449941
# epoch: 40, total rewards: -354.429951.3, cost: 0.007549, total money: 9273.320050
# epoch: 50, total rewards: -18.600060.3, cost: 0.001744, total money: 9732.559935
# epoch: 60, total rewards: -91.229972.3, cost: 0.002040, total money: 9784.210026
# epoch: 70, total rewards: -52.530011.3, cost: 0.001645, total money: 9947.469989
# epoch: 80, total rewards: -6.389988.3, cost: 0.000857, total money: 9931.450012
# epoch: 90, total rewards: 2.219983.3, cost: 0.000720, total money: 9940.199983
# epoch: 100, total rewards: 19.839974.3, cost: 0.005971, total money: 10019.839974
# epoch: 110, total rewards: -27.730038.3, cost: 0.001246, total money: 9972.269962
# epoch: 120, total rewards: 7.119989.3, cost: 0.000478, total money: 10007.119989
# epoch: 130, total rewards: 19.690054.3, cost: 0.000417, total money: 10019.690054
# epoch: 140, total rewards: -23.859962.3, cost: 0.000689, total money: 9976.140038
# epoch: 150, total rewards: -12.799953.3, cost: 0.000227, total money: 9925.550045
# epoch: 160, total rewards: -9.970018.3, cost: 0.000396, total money: 9990.029982
# epoch: 170, total rewards: -14.590009.3, cost: 0.000550, total money: 9985.409991
# epoch: 180, total rewards: -2.310010.3, cost: 0.000243, total money: 9997.689990
# epoch: 190, total rewards: -14.770013.3, cost: 0.000016, total money: 9985.229987
# epoch: 200, total rewards: -12.189991.3, cost: 0.003131, total money: 9987.810009

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 11: buy 1 unit at price 76.750000, total balance 9923.250000
# day 12, sell 1 unit at price 77.290001, investment 0.703584 %, total balance 10000.540001,
# day 14: buy 1 unit at price 78.260002, total balance 9922.279999
# day 15, sell 1 unit at price 78.449997, investment 0.242774 %, total balance 10000.729996,
# day 23: buy 1 unit at price 73.290001, total balance 9927.439995
# day 24: buy 1 unit at price 73.900002, total balance 9853.539993
# day 25, sell 1 unit at price 76.519997, investment 4.407144 %, total balance 9930.059990,
# day 27, sell 1 unit at price 76.290001, investment 3.234099 %, total balance 10006.349991,
# day 41: buy 1 unit at price 81.279999, total balance 9925.069992
# day 42, sell 1 unit at price 82.269997, investment 1.218009 %, total balance 10007.339989,
# day 43: buy 1 unit at price 83.070000, total balance 9924.269989
# day 44, sell 1 unit at price 83.250000, investment 0.216685 %, total balance 10007.519989,
# day 55: buy 1 unit at price 80.970001, total balance 9926.549988
# day 56: buy 1 unit at price 79.260002, total balance 9847.289986
# day 58, sell 1 unit at price 80.080002, investment -1.099171 %, total balance 9927.369988,
# day 59: buy 1 unit at price 79.669998, total balance 9847.699990
# day 60, sell 1 unit at price 80.500000, investment 1.564469 %, total balance 9928.199990,
# day 61: buy 1 unit at price 79.209999, total balance 9848.989991
# day 62, sell 1 unit at price 80.050003, investment 0.476974 %, total balance 9929.039994,
# day 63: buy 1 unit at price 80.720001, total balance 9848.319993
# day 64, sell 1 unit at price 80.919998, investment 2.158817 %, total balance 9929.239991,
# day 66, sell 1 unit at price 78.910004, investment -2.242315 %, total balance 10008.149995,
# day 77: buy 1 unit at price 80.800003, total balance 9927.349992
# day 79: buy 1 unit at price 81.730003, total balance 9845.619989
# day 81: buy 1 unit at price 81.820000, total balance 9763.799989
# day 82, sell 1 unit at price 81.820000, investment 1.262372 %, total balance 9845.619989,
# day 83: buy 1 unit at price 81.379997, total balance 9764.239992
# day 84: buy 1 unit at price 81.360001, total balance 9682.879991
# day 85: buy 1 unit at price 82.169998, total balance 9600.709993
# day 86, sell 1 unit at price 77.860001, investment -4.735106 %, total balance 9678.569994,
# day 87, sell 1 unit at price 75.550003, investment -7.663159 %, total balance 9754.119997,
# day 89, sell 1 unit at price 75.949997, investment -6.672401 %, total balance 9830.069994,
# day 90: buy 1 unit at price 76.580002, total balance 9753.489992
# day 91, sell 1 unit at price 75.860001, investment -6.760079 %, total balance 9829.349993,
# day 92, sell 1 unit at price 75.459999, investment -8.165996 %, total balance 9904.809992,
# day 93: buy 1 unit at price 75.389999, total balance 9829.419993
# day 94: buy 1 unit at price 75.779999, total balance 9753.639994
# day 96, sell 1 unit at price 75.750000, investment -1.083836 %, total balance 9829.389994,
# day 98: buy 1 unit at price 75.760002, total balance 9753.629992
# day 99, sell 1 unit at price 75.930000, investment 0.716277 %, total balance 9829.559992,
# day 100: buy 1 unit at price 75.779999, total balance 9753.779993
# day 101, sell 1 unit at price 74.410004, investment -1.807858 %, total balance 9828.189997,
# day 102, sell 1 unit at price 75.690002, investment -0.092397 %, total balance 9903.879999,
# day 103, sell 1 unit at price 75.349998, investment -0.567433 %, total balance 9979.229997,
# day 108: buy 1 unit at price 76.720001, total balance 9902.509996
# day 109, sell 1 unit at price 77.110001, investment 0.508342 %, total balance 9979.619997,
# day 115: buy 1 unit at price 80.010002, total balance 9899.609995
# day 117, sell 1 unit at price 78.820000, investment -1.487317 %, total balance 9978.429995,
# day 122: buy 1 unit at price 77.379997, total balance 9901.049998
# day 123, sell 1 unit at price 79.019997, investment 2.119411 %, total balance 9980.069995,
# day 124: buy 1 unit at price 78.989998, total balance 9901.079997
# day 125, sell 1 unit at price 79.489998, investment 0.632992 %, total balance 9980.569995,
# day 126: buy 1 unit at price 79.900002, total balance 9900.669993
# day 127, sell 1 unit at price 79.889999, investment -0.012519 %, total balance 9980.559992,
# day 131: buy 1 unit at price 81.589996, total balance 9898.969996
# day 132, sell 1 unit at price 83.320000, investment 2.120363 %, total balance 9982.289996,
# day 134: buy 1 unit at price 81.959999, total balance 9900.329997
# day 135, sell 1 unit at price 82.739998, investment 0.951683 %, total balance 9983.069995,
# day 156: buy 1 unit at price 74.540001, total balance 9908.529994
# day 157, sell 1 unit at price 75.099998, investment 0.751270 %, total balance 9983.629992,
# day 166: buy 1 unit at price 77.690002, total balance 9905.939990
# day 167: buy 1 unit at price 77.389999, total balance 9828.549991
# day 168, sell 1 unit at price 78.430000, investment 0.952501 %, total balance 9906.979991,
# day 169, sell 1 unit at price 75.639999, investment -2.261274 %, total balance 9982.619990,
# day 172: buy 1 unit at price 75.730003, total balance 9906.889987
# day 174, sell 1 unit at price 76.610001, investment 1.162020 %, total balance 9983.499988,
# day 177: buy 1 unit at price 76.279999, total balance 9907.219989
# day 178, sell 1 unit at price 75.959999, investment -0.419507 %, total balance 9983.179988,
# day 179: buy 1 unit at price 76.879997, total balance 9906.299991
# day 181, sell 1 unit at price 77.169998, investment 0.377213 %, total balance 9983.469989,
# day 197: buy 1 unit at price 72.169998, total balance 9911.299991
# day 198, sell 1 unit at price 72.010002, investment -0.221693 %, total balance 9983.309993,
# day 201: buy 1 unit at price 73.589996, total balance 9909.719997
# day 202, sell 1 unit at price 73.690002, investment 0.135896 %, total balance 9983.409999,
# day 207: buy 1 unit at price 70.529999, total balance 9912.880000
# day 208: buy 1 unit at price 69.220001, total balance 9843.659999
# day 209, sell 1 unit at price 66.519997, investment -5.685527 %, total balance 9910.179996,
# day 211, sell 1 unit at price 68.779999, investment -0.635657 %, total balance 9978.959995,
# day 221: buy 1 unit at price 68.669998, total balance 9910.289997
# day 222, sell 1 unit at price 70.330002, investment 2.417364 %, total balance 9980.619999,
# day 226: buy 1 unit at price 67.980003, total balance 9912.639996
# day 227, sell 1 unit at price 68.750000, investment 1.132682 %, total balance 9981.389996,
# day 241: buy 1 unit at price 64.669998, total balance 9916.719998
# day 243, sell 1 unit at price 64.230003, investment -0.680370 %, total balance 9980.950001,
# day 256: buy 1 unit at price 64.260002, total balance 9916.689999
# day 257, sell 1 unit at price 64.809998, investment 0.855892 %, total balance 9981.499997,
# day 262: buy 1 unit at price 66.550003, total balance 9914.949994
# day 263: buy 1 unit at price 67.820000, total balance 9847.129994
# day 264: buy 1 unit at price 66.800003, total balance 9780.329991
# day 265: buy 1 unit at price 67.059998, total balance 9713.269993
# day 266, sell 1 unit at price 68.120003, investment 2.359128 %, total balance 9781.389996,
# day 267, sell 1 unit at price 70.019997, investment 3.243876 %, total balance 9851.409993,
# day 268: buy 1 unit at price 68.949997, total balance 9782.459996
# day 269, sell 1 unit at price 68.660004, investment 2.784433 %, total balance 9851.120000,
# day 270, sell 1 unit at price 69.800003, investment 4.085901 %, total balance 9920.920003,
# day 271, sell 1 unit at price 69.680000, investment 1.058743 %, total balance 9990.600003,
# day 278: buy 1 unit at price 72.970001, total balance 9917.630002
# day 280, sell 1 unit at price 73.580002, investment 0.835961 %, total balance 9991.210004,
# day 284: buy 1 unit at price 72.250000, total balance 9918.960004
# day 285, sell 1 unit at price 71.339996, investment -1.259521 %, total balance 9990.300000,
# day 288: buy 1 unit at price 72.040001, total balance 9918.259999
# day 289, sell 1 unit at price 71.309998, investment -1.013330 %, total balance 9989.569997,
# day 294: buy 1 unit at price 71.459999, total balance 9918.109998
# day 295, sell 1 unit at price 72.330002, investment 1.217469 %, total balance 9990.440000,
# day 299: buy 1 unit at price 71.209999, total balance 9919.230001
# day 300, sell 1 unit at price 70.930000, investment -0.393202 %, total balance 9990.160001,
# day 303: buy 1 unit at price 72.019997, total balance 9918.140004
# day 304: buy 1 unit at price 71.709999, total balance 9846.430005
# day 305, sell 1 unit at price 72.199997, investment 0.249931 %, total balance 9918.630002,
# day 306, sell 1 unit at price 70.889999, investment -1.143495 %, total balance 9989.520001,
# day 310: buy 1 unit at price 71.580002, total balance 9917.939999
# day 311, sell 1 unit at price 72.449997, investment 1.215416 %, total balance 9990.389996,
# day 321: buy 1 unit at price 74.290001, total balance 9916.099995
# day 323: buy 1 unit at price 71.900002, total balance 9844.199993
# day 324: buy 1 unit at price 72.150002, total balance 9772.049991
# day 327, sell 1 unit at price 72.849998, investment -1.938354 %, total balance 9844.899989,
# day 328, sell 1 unit at price 72.669998, investment 1.070926 %, total balance 9917.569987,
# day 329, sell 1 unit at price 72.930000, investment 1.081078 %, total balance 9990.499987,
# day 330: buy 1 unit at price 73.370003, total balance 9917.129984
# day 331, sell 1 unit at price 72.400002, investment -1.322068 %, total balance 9989.529986,
# day 335: buy 1 unit at price 59.250000, total balance 9930.279986
# day 336, sell 1 unit at price 59.599998, investment 0.590714 %, total balance 9989.879984,
# day 338: buy 1 unit at price 58.980000, total balance 9930.899984
# day 339, sell 1 unit at price 59.099998, investment 0.203455 %, total balance 9989.999982,
# day 347: buy 1 unit at price 61.000000, total balance 9928.999982
# day 348, sell 1 unit at price 61.500000, investment 0.819672 %, total balance 9990.499982,
# day 350: buy 1 unit at price 61.869999, total balance 9928.629983
# day 352, sell 1 unit at price 61.880001, investment 0.016166 %, total balance 9990.509984,
# day 357: buy 1 unit at price 62.180000, total balance 9928.329984
# day 358, sell 1 unit at price 61.900002, investment -0.450302 %, total balance 9990.229986,
# day 361: buy 1 unit at price 63.369999, total balance 9926.859987
# day 362, sell 1 unit at price 62.150002, investment -1.925196 %, total balance 9989.009989,
# day 370: buy 1 unit at price 64.050003, total balance 9924.959986
# day 372, sell 1 unit at price 63.060001, investment -1.545670 %, total balance 9988.019987,
# day 378: buy 1 unit at price 64.709999, total balance 9923.309988
# day 379, sell 1 unit at price 64.199997, investment -0.788135 %, total balance 9987.509985,
# day 388: buy 1 unit at price 65.139999, total balance 9922.369986
# day 389, sell 1 unit at price 65.550003, investment 0.629420 %, total balance 9987.919989,
# day 390: buy 1 unit at price 65.870003, total balance 9922.049986
# day 391, sell 1 unit at price 65.760002, investment -0.166997 %, total balance 9987.809988,
# day 393: buy 1 unit at price 66.400002, total balance 9921.409986
# day 394, sell 1 unit at price 66.040001, investment -0.542170 %, total balance 9987.449987,
# day 400: buy 1 unit at price 62.580002, total balance 9924.869985
# day 401, sell 1 unit at price 62.209999, investment -0.591248 %, total balance 9987.079984,
# day 402: buy 1 unit at price 63.959999, total balance 9923.119985
# day 403, sell 1 unit at price 62.459999, investment -2.345216 %, total balance 9985.579984,
# day 406: buy 1 unit at price 60.650002, total balance 9924.929982
# day 408, sell 1 unit at price 61.220001, investment 0.939817 %, total balance 9986.149983,
# day 412: buy 1 unit at price 61.200001, total balance 9924.949982
# day 413, sell 1 unit at price 60.000000, investment -1.960786 %, total balance 9984.949982,
# day 417: buy 1 unit at price 61.380001, total balance 9923.569981
# day 418, sell 1 unit at price 61.389999, investment 0.016289 %, total balance 9984.959980,
# day 421: buy 1 unit at price 64.260002, total balance 9920.699978
# day 423, sell 1 unit at price 64.180000, investment -0.124497 %, total balance 9984.879978,
# day 431: buy 1 unit at price 63.470001, total balance 9921.409977
# day 432, sell 1 unit at price 61.799999, investment -2.631167 %, total balance 9983.209976,
# day 436: buy 1 unit at price 59.660000, total balance 9923.549976
# day 437, sell 1 unit at price 58.750000, investment -1.525310 %, total balance 9982.299976,
# day 439: buy 1 unit at price 60.619999, total balance 9921.679977
# day 440, sell 1 unit at price 59.939999, investment -1.121742 %, total balance 9981.619976,
# day 459: buy 1 unit at price 60.450001, total balance 9921.169975
# day 460, sell 1 unit at price 59.889999, investment -0.926389 %, total balance 9981.059974,
# day 500: buy 1 unit at price 62.160000, total balance 9918.899974
# day 501, sell 1 unit at price 61.650002, investment -0.820460 %, total balance 9980.549976,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Duel Recurrent Q-learning agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Duel Recurrent Q-learning agent'
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.X = tf.placeholder(tf.float32, (None, None, self.state_size))
        self.Y = tf.placeholder(tf.float32, (None, self.OUTPUT_SIZE))
        cell = tf.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
        self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * self.LAYER_SIZE))
        self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
        tensor_action, tensor_validation = tf.split(self.rnn[:,-1],2,1)
        feed_action = tf.layers.dense(tensor_action, self.OUTPUT_SIZE)
        feed_validation = tf.layers.dense(tensor_validation, 1)
        self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
        self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = self.LEARNING_RATE).minimize(self.cost)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.logits, feed_dict={self.X:states, self.hidden_layer:init_values})
        Q_new = self.sess.run(self.logits, feed_dict={self.X:new_states, self.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * np.amax(Q_new[i])
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.logits,self.last_state],
                                                feed_dict={self.X:[self.INITIAL_FEATURES],
                                                            self.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.logits,
                                                  self.last_state],
                                                  feed_dict={self.X:[self.INITIAL_FEATURES],
                                                             self.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.cost, self.optimizer], 
                                        feed_dict={self.X: X, self.Y:Y,
                                                  self.hidden_layer: INIT_VAL})
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
                
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f4b594b85c0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: -180.900023.3, cost: 0.002729, total money: 8876.829975
# epoch: 20, total rewards: -18.839995.3, cost: 0.002383, total money: 9794.270006
# epoch: 30, total rewards: -30.780028.3, cost: 0.000605, total money: 9845.449971
# epoch: 40, total rewards: -72.290013.3, cost: 0.000465, total money: 9865.589988
# epoch: 50, total rewards: 53.080042.3, cost: 0.004787, total money: 10053.080042
# epoch: 60, total rewards: -109.809968.3, cost: 0.006284, total money: 9580.930035
# epoch: 70, total rewards: -87.540026.3, cost: 0.000769, total money: 9912.459974
# epoch: 80, total rewards: -53.549948.3, cost: 0.001154, total money: 9884.430052
# epoch: 90, total rewards: -55.090054.3, cost: 0.001447, total money: 9882.889946
# epoch: 100, total rewards: -8.739962.3, cost: 0.000920, total money: 9991.260038
# epoch: 110, total rewards: 11.360001.3, cost: 0.000554, total money: 9949.340001
# epoch: 120, total rewards: -64.099996.3, cost: 0.000496, total money: 9873.880004
# epoch: 130, total rewards: -7.379982.3, cost: 0.000475, total money: 9804.880016
# epoch: 140, total rewards: 13.159998.3, cost: 0.093369, total money: 9888.639997
# epoch: 150, total rewards: -22.749987.3, cost: 0.000776, total money: 9977.250013
# epoch: 160, total rewards: 14.610005.3, cost: 0.982036, total money: 10014.610005
# epoch: 170, total rewards: 17.939977.3, cost: 0.001055, total money: 10017.939977
# epoch: 180, total rewards: -8.860020.3, cost: 0.000747, total money: 9866.959980
# epoch: 190, total rewards: 27.739964.3, cost: 0.431949, total money: 10027.739964
# epoch: 200, total rewards: 8.190019.3, cost: 0.737177, total money: 9883.630017

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Double Duel Recurrent Q-learning agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Double Duel Recurrent Q-learning agent'

class Model:
    def __init__(self, input_size, output_size, layer_size, learning_rate, name):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            cell = tf.nn.rnn_cell.LSTMCell(layer_size, state_is_tuple = False)
            self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * layer_size))
            self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            tensor_action, tensor_validation = tf.split(self.rnn[:,-1],2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            self.cost = tf.reduce_sum(tf.square(self.Y - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.model = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                           'real_model')
        self.model_negative = Model(self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE,
                                   'negative_model')
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
        self.trainable = tf.trainable_variables()
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)

    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()

    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action

    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.model.logits, feed_dict={self.model.X:states, 
                                                   self.model.hidden_layer:init_values})
        Q_new = self.sess.run(self.model.logits, feed_dict={self.model.X:new_states, 
                                                       self.model.hidden_layer:init_values})
        Q_new_negative = self.sess.run(self.model_negative.logits, 
                                  feed_dict={self.model_negative.X:new_states, 
                                             self.model_negative.hidden_layer:init_values})
        replay_size = len(replay)
        X = np.empty((replay_size, 4, self.state_size))
        Y = np.empty((replay_size, self.OUTPUT_SIZE))
        INIT_VAL = np.empty((replay_size, 2 * self.LAYER_SIZE))
        for i in range(replay_size):
            state_r, action_r, reward_r, new_state_r, dead_r, rnn_memory = replay[i]
            target = Q[i]
            target[action_r] = reward_r
            if not dead_r:
                target[action_r] += self.GAMMA * Q_new_negative[i, np.argmax(Q_new[i])]
            X[i] = state_r
            Y[i] = target
            INIT_VAL[i] = rnn_memory
        return X, Y, INIT_VAL
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            action, last_state = self.sess.run([self.model.logits,self.model.last_state],
                                                feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                            self.model.hidden_layer:init_value})
            action, init_value = np.argmax(action[0]), last_state
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
            
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('real_model', 'negative_model')
                
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.model.logits,
                                                  self.model.last_state],
                                                  feed_dict={self.model.X:[self.INITIAL_FEATURES],
                                                             self.model.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                X, Y, INIT_VAL = self._construct_memories(replay)
                
                cost, _ = self.sess.run([self.model.cost, self.model.optimizer], 
                                        feed_dict={self.model.X: X, self.model.Y:Y,
                                                  self.model.hidden_layer: INIT_VAL})
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f4b57ad8ba8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f4b57ad8860>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: -152.980000.3, cost: 0.003191, total money: 9475.860005
# epoch: 20, total rewards: 8.610044.3, cost: 0.000353, total money: 9884.090043
# epoch: 30, total rewards: -63.090014.3, cost: 0.000583, total money: 9936.909986
# epoch: 40, total rewards: 23.630001.3, cost: 0.000562, total money: 10023.630001
# epoch: 50, total rewards: -3.579980.3, cost: 0.000383, total money: 9934.400020
# epoch: 60, total rewards: -32.169956.3, cost: 0.001142, total money: 9967.830044
# epoch: 70, total rewards: 0.910008.3, cost: 0.000657, total money: 9938.750008
# epoch: 80, total rewards: 36.530033.3, cost: 0.000925, total money: 9601.650032
# epoch: 90, total rewards: 49.659964.3, cost: 0.000603, total money: 9987.499964
# epoch: 100, total rewards: 124.789991.3, cost: 0.000752, total money: 10001.119989
# epoch: 110, total rewards: -14.880028.3, cost: 0.000696, total money: 9985.119972
# epoch: 120, total rewards: -77.749974.3, cost: 0.007313, total money: 9860.230026
# epoch: 130, total rewards: -12.030004.3, cost: 0.000420, total money: 9926.319994
# epoch: 140, total rewards: 70.239954.3, cost: 0.000712, total money: 10070.239954
# epoch: 150, total rewards: -69.720037.3, cost: 0.001109, total money: 9930.279963
# epoch: 160, total rewards: 27.889984.3, cost: 0.000501, total money: 10027.889984
# epoch: 170, total rewards: 11.669979.3, cost: 0.001706, total money: 10011.669979
# epoch: 180, total rewards: -11.239992.3, cost: 0.000152, total money: 9988.760008
# epoch: 190, total rewards: 4.080033.3, cost: 0.000173, total money: 10004.080033
# epoch: 200, total rewards: 11.760060.3, cost: 0.000136, total money: 10011.760060

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 51: buy 1 unit at price 84.599998, total balance 9915.400002
# day 54, sell 1 unit at price 83.349998, investment -1.477541 %, total balance 9998.750000,
# day 58: buy 1 unit at price 80.080002, total balance 9918.669998
# day 64, sell 1 unit at price 80.919998, investment 1.048946 %, total balance 9999.589996,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Actor-critic agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Actor-critic agent'

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            feed_actor = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_actor, output_size)

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            self.REWARD = tf.placeholder(tf.float32, (None, 1))
            feed_critic = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            feed_critic = tf.layers.dense(feed_critic, output_size, activation = tf.nn.relu) + self.Y
            feed_critic = tf.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(tf.square(self.REWARD - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(self.critic.logits, self.critic.Y)
        self.actor_critic_grad = tf.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(self.actor.logits, weights_actor, -self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead):
        self.MEMORIES.append((state, action, reward, new_state, dead))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target})
        for i in range(len(replay)):
            if not replay[0][-1]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                state = next_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: -156.349969.3, cost: 0.008428, total money: 7604.040031
# epoch: 20, total rewards: -362.319994.3, cost: 0.007616, total money: 6543.959992
# epoch: 30, total rewards: -539.659938.3, cost: 0.009921, total money: 5452.770075
# epoch: 40, total rewards: -394.649948.3, cost: 0.006411, total money: 6024.950051
# epoch: 50, total rewards: -148.260041.3, cost: 0.026026, total money: 9418.429958
# epoch: 60, total rewards: -96.150028.3, cost: 0.343798, total money: 8725.639981
# epoch: 70, total rewards: -52.379935.3, cost: 43247.976562, total money: 9823.100064
# epoch: 80, total rewards: -590.060023.3, cost: 146565.625000, total money: 5375.129987
# epoch: 90, total rewards: -285.309985.3, cost: 225109.375000, total money: 7911.210017
# epoch: 100, total rewards: -64.470014.3, cost: 996036.625000, total money: 9811.479982
# epoch: 110, total rewards: -771.290039.3, cost: 238356.187500, total money: 50.789992
# epoch: 120, total rewards: -755.560076.3, cost: 417811.625000, total money: 55.249944
# epoch: 130, total rewards: -622.209982.3, cost: 3633.148926, total money: 12.430034
# epoch: 140, total rewards: -806.210019.3, cost: 395068.250000, total money: 53.639949
# epoch: 150, total rewards: -544.059991.3, cost: 432025.187500, total money: 40.980021
# epoch: 160, total rewards: -791.510015.3, cost: 418259.375000, total money: 101.319981
# epoch: 170, total rewards: -776.500072.3, cost: 26978.021484, total money: 8.269917
# epoch: 180, total rewards: -541.080021.3, cost: 26226.716797, total money: 24.460001
# epoch: 190, total rewards: -717.760043.3, cost: 30715.785156, total money: 81.549968
# epoch: 200, total rewards: -575.059996.3, cost: 113579.664062, total money: 44.550028

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 70.949997, total balance 9929.050003
# day 1: buy 1 unit at price 71.550003, total balance 9857.500000
# day 2: buy 1 unit at price 72.680000, total balance 9784.820000
# day 3, sell 1 unit at price 73.300003, investment 3.312200 %, total balance 9858.120003,
# day 4: buy 1 unit at price 73.370003, total balance 9784.750000
# day 5: buy 1 unit at price 73.459999, total balance 9711.290001
# day 6: buy 1 unit at price 73.970001, total balance 9637.320000
# day 7: buy 1 unit at price 74.010002, total balance 9563.309998
# day 9: buy 1 unit at price 74.730003, total balance 9488.579995
# day 10: buy 1 unit at price 75.839996, total balance 9412.739999
# day 11: buy 1 unit at price 76.750000, total balance 9335.989999
# day 12, sell 1 unit at price 77.290001, investment 8.022359 %, total balance 9413.280000,
# day 13: buy 1 unit at price 77.959999, total balance 9335.320001
# day 14: buy 1 unit at price 78.260002, total balance 9257.059999
# day 15: buy 1 unit at price 78.449997, total balance 9178.610002
# day 16: buy 1 unit at price 77.949997, total balance 9100.660005
# day 17: buy 1 unit at price 78.430000, total balance 9022.230005
# day 18: buy 1 unit at price 78.150002, total balance 8944.080003
# day 19: buy 1 unit at price 77.760002, total balance 8866.320001
# day 20: buy 1 unit at price 77.980003, total balance 8788.339998
# day 22: buy 1 unit at price 75.720001, total balance 8712.619997
# day 23, sell 1 unit at price 73.290001, investment 0.839297 %, total balance 8785.909998,
# day 24: buy 1 unit at price 73.900002, total balance 8712.009996
# day 25: buy 1 unit at price 76.519997, total balance 8635.489999
# day 27: buy 1 unit at price 76.290001, total balance 8559.199998
# day 28: buy 1 unit at price 77.430000, total balance 8481.769998
# day 29: buy 1 unit at price 78.110001, total balance 8403.659997
# day 31, sell 1 unit at price 81.370003, investment 10.903639 %, total balance 8485.030000,
# day 32: buy 1 unit at price 80.949997, total balance 8404.080003
# day 33: buy 1 unit at price 81.540001, total balance 8322.540002
# day 34: buy 1 unit at price 81.800003, total balance 8240.739999
# day 35: buy 1 unit at price 81.610001, total balance 8159.129998
# day 36: buy 1 unit at price 82.529999, total balance 8076.599999
# day 37: buy 1 unit at price 82.970001, total balance 7993.629998
# day 38: buy 1 unit at price 82.510002, total balance 7911.119996
# day 39: buy 1 unit at price 82.019997, total balance 7829.099999
# day 40: buy 1 unit at price 80.650002, total balance 7748.449997
# day 41: buy 1 unit at price 81.279999, total balance 7667.169998
# day 42: buy 1 unit at price 82.269997, total balance 7584.900001
# day 43, sell 1 unit at price 83.070000, investment 13.081951 %, total balance 7667.970001,
# day 47: buy 1 unit at price 84.070000, total balance 7583.900001
# day 48: buy 1 unit at price 83.790001, total balance 7500.110000
# day 49: buy 1 unit at price 83.629997, total balance 7416.480003
# day 50: buy 1 unit at price 84.830002, total balance 7331.650001
# day 51, sell 1 unit at price 84.599998, investment 14.370687 %, total balance 7416.249999,
# day 52: buy 1 unit at price 83.809998, total balance 7332.440001
# day 53: buy 1 unit at price 84.309998, total balance 7248.130003
# day 55: buy 1 unit at price 80.970001, total balance 7167.160002
# day 56: buy 1 unit at price 79.260002, total balance 7087.900000
# day 58: buy 1 unit at price 80.080002, total balance 7007.819998
# day 59: buy 1 unit at price 79.669998, total balance 6928.150000
# day 60: buy 1 unit at price 80.500000, total balance 6847.650000
# day 61: buy 1 unit at price 79.209999, total balance 6768.440001
# day 63, sell 1 unit at price 80.720001, investment 9.066341 %, total balance 6849.160002,
# day 65: buy 1 unit at price 79.070000, total balance 6770.090002
# day 66: buy 1 unit at price 78.910004, total balance 6691.179998
# day 67: buy 1 unit at price 80.400002, total balance 6610.779996
# day 68, sell 1 unit at price 79.930000, investment 6.958379 %, total balance 6690.709996,
# day 69: buy 1 unit at price 81.550003, total balance 6609.159993
# day 70: buy 1 unit at price 80.820000, total balance 6528.339993
# day 71: buy 1 unit at price 81.769997, total balance 6446.569996
# day 73: buy 1 unit at price 82.699997, total balance 6363.869999
# day 74: buy 1 unit at price 82.370003, total balance 6281.499996
# day 75: buy 1 unit at price 81.769997, total balance 6199.729999
# day 76: buy 1 unit at price 81.570000, total balance 6118.159999
# day 77: buy 1 unit at price 80.800003, total balance 6037.359996
# day 78: buy 1 unit at price 80.910004, total balance 5956.449992
# day 80: buy 1 unit at price 81.620003, total balance 5874.829989
# day 81: buy 1 unit at price 81.820000, total balance 5793.009989
# day 82: buy 1 unit at price 81.820000, total balance 5711.189989
# day 83, sell 1 unit at price 81.379997, investment 7.304854 %, total balance 5792.569986,
# day 84: buy 1 unit at price 81.360001, total balance 5711.209985
# day 85: buy 1 unit at price 82.169998, total balance 5629.039987
# day 87: buy 1 unit at price 75.550003, total balance 5553.489984
# day 88: buy 1 unit at price 75.029999, total balance 5478.459985
# day 89: buy 1 unit at price 75.949997, total balance 5402.509988
# day 90, sell 1 unit at price 76.580002, investment -0.221496 %, total balance 5479.089990,
# day 91: buy 1 unit at price 75.860001, total balance 5403.229989
# day 92: buy 1 unit at price 75.459999, total balance 5327.769990
# day 93: buy 1 unit at price 75.389999, total balance 5252.379991
# day 95, sell 1 unit at price 76.040001, investment -2.462799 %, total balance 5328.419992,
# day 96: buy 1 unit at price 75.750000, total balance 5252.669992
# day 97: buy 1 unit at price 75.239998, total balance 5177.429994
# day 98: buy 1 unit at price 75.760002, total balance 5101.669992
# day 99: buy 1 unit at price 75.930000, total balance 5025.739992
# day 100: buy 1 unit at price 75.779999, total balance 4949.959993
# day 101: buy 1 unit at price 74.410004, total balance 4875.549989
# day 102: buy 1 unit at price 75.690002, total balance 4799.859987
# day 103: buy 1 unit at price 75.349998, total balance 4724.509989
# day 105: buy 1 unit at price 77.220001, total balance 4647.289988
# day 106: buy 1 unit at price 77.029999, total balance 4570.259989
# day 107: buy 1 unit at price 78.139999, total balance 4492.119990
# day 108: buy 1 unit at price 76.720001, total balance 4415.399989
# day 109: buy 1 unit at price 77.110001, total balance 4338.289988
# day 110: buy 1 unit at price 76.970001, total balance 4261.319987
# day 111, sell 1 unit at price 78.250000, investment -0.012780 %, total balance 4339.569987,
# day 112: buy 1 unit at price 78.019997, total balance 4261.549990
# day 113: buy 1 unit at price 78.550003, total balance 4182.999987
# day 114: buy 1 unit at price 80.699997, total balance 4102.299990
# day 116: buy 1 unit at price 79.199997, total balance 4023.099993
# day 117: buy 1 unit at price 78.820000, total balance 3944.279993
# day 119: buy 1 unit at price 78.699997, total balance 3865.579996
# day 120, sell 1 unit at price 77.959999, investment -0.624599 %, total balance 3943.539995,
# day 122, sell 1 unit at price 77.379997, investment -0.731238 %, total balance 4020.919992,
# day 123: buy 1 unit at price 79.019997, total balance 3941.899995
# day 124: buy 1 unit at price 78.989998, total balance 3862.909997
# day 125, sell 1 unit at price 79.489998, investment 1.351521 %, total balance 3942.399995,
# day 126: buy 1 unit at price 79.900002, total balance 3862.499993
# day 127, sell 1 unit at price 79.889999, investment 2.226484 %, total balance 3942.389992,
# day 129: buy 1 unit at price 80.980003, total balance 3861.409989
# day 131: buy 1 unit at price 81.589996, total balance 3779.819993
# day 132: buy 1 unit at price 83.320000, total balance 3696.499993
# day 133: buy 1 unit at price 81.709999, total balance 3614.789994
# day 134: buy 1 unit at price 81.959999, total balance 3532.829995
# day 135: buy 1 unit at price 82.739998, total balance 3450.089997
# day 136, sell 1 unit at price 82.330002, investment 5.877057 %, total balance 3532.419999,
# day 137: buy 1 unit at price 82.379997, total balance 3450.040002
# day 138: buy 1 unit at price 82.239998, total balance 3367.800004
# day 139: buy 1 unit at price 82.669998, total balance 3285.130006
# day 141, sell 1 unit at price 82.839996, investment 6.232358 %, total balance 3367.970002,
# day 142, sell 1 unit at price 82.720001, investment 9.244585 %, total balance 3450.690003,
# day 143: buy 1 unit at price 81.559998, total balance 3369.130005
# day 144: buy 1 unit at price 80.760002, total balance 3288.370003
# day 145: buy 1 unit at price 81.500000, total balance 3206.870003
# day 147: buy 1 unit at price 76.860001, total balance 3130.010002
# day 148: buy 1 unit at price 77.820000, total balance 3052.190002
# day 149, sell 1 unit at price 78.489998, investment 6.211090 %, total balance 3130.680000,
# day 150, sell 1 unit at price 78.070000, investment 2.025618 %, total balance 3208.750000,
# day 151: buy 1 unit at price 77.239998, total balance 3131.510002
# day 152: buy 1 unit at price 76.260002, total balance 3055.250000
# day 153: buy 1 unit at price 75.559998, total balance 2979.690002
# day 154, sell 1 unit at price 75.419998, investment -1.140389 %, total balance 3055.110000,
# day 155: buy 1 unit at price 75.220001, total balance 2979.889999
# day 158: buy 1 unit at price 75.559998, total balance 2904.330001
# day 160, sell 1 unit at price 74.900002, investment -3.267465 %, total balance 2979.230003,
# day 161, sell 1 unit at price 75.260002, investment -3.648699 %, total balance 3054.490005,
# day 163, sell 1 unit at price 75.860001, investment -6.287827 %, total balance 3130.350006,
# day 164: buy 1 unit at price 76.610001, total balance 3053.740005
# day 166: buy 1 unit at price 77.690002, total balance 2976.050003
# day 168: buy 1 unit at price 78.430000, total balance 2897.620003
# day 169, sell 1 unit at price 75.639999, investment -7.235715 %, total balance 2973.260002,
# day 170: buy 1 unit at price 75.290001, total balance 2897.970001
# day 171: buy 1 unit at price 75.720001, total balance 2822.250000
# day 172: buy 1 unit at price 75.730003, total balance 2746.519997
# day 173: buy 1 unit at price 75.559998, total balance 2670.959999
# day 174: buy 1 unit at price 76.610001, total balance 2594.349998
# day 175, sell 1 unit at price 75.699997, investment -7.457220 %, total balance 2670.049995,
# day 176: buy 1 unit at price 77.199997, total balance 2592.849998
# day 177: buy 1 unit at price 76.279999, total balance 2516.569999
# day 179: buy 1 unit at price 76.879997, total balance 2439.690002
# day 180: buy 1 unit at price 76.099998, total balance 2363.590004
# day 181, sell 1 unit at price 77.169998, investment -5.440513 %, total balance 2440.760002,
# day 182: buy 1 unit at price 77.610001, total balance 2363.150001
# day 183: buy 1 unit at price 77.269997, total balance 2285.880004
# day 184, sell 1 unit at price 76.820000, investment -6.918695 %, total balance 2362.700004,
# day 185: buy 1 unit at price 76.790001, total balance 2285.910003
# day 186: buy 1 unit at price 76.760002, total balance 2209.150001
# day 188: buy 1 unit at price 76.980003, total balance 2132.169998
# day 189: buy 1 unit at price 77.279999, total balance 2054.889999
# day 190: buy 1 unit at price 76.559998, total balance 1978.330001
# day 191: buy 1 unit at price 76.099998, total balance 1902.230003
# day 192: buy 1 unit at price 75.209999, total balance 1827.020004
# day 193: buy 1 unit at price 74.110001, total balance 1752.910003
# day 194: buy 1 unit at price 73.970001, total balance 1678.940002
# day 195: buy 1 unit at price 71.440002, total balance 1607.500000
# day 196, sell 1 unit at price 70.290001, investment -15.282632 %, total balance 1677.790001,
# day 197, sell 1 unit at price 72.169998, investment -12.531819 %, total balance 1749.959999,
# day 201: buy 1 unit at price 73.589996, total balance 1676.370003
# day 202: buy 1 unit at price 73.690002, total balance 1602.680001
# day 205: buy 1 unit at price 70.150002, total balance 1532.529999
# day 206, sell 1 unit at price 71.480003, investment -12.850517 %, total balance 1604.010002,
# day 207: buy 1 unit at price 70.529999, total balance 1533.480003
# day 208: buy 1 unit at price 69.220001, total balance 1464.260002
# day 209: buy 1 unit at price 66.519997, total balance 1397.740005
# day 210: buy 1 unit at price 69.029999, total balance 1328.710006
# day 211, sell 1 unit at price 68.779999, investment -14.717920 %, total balance 1397.490005,
# day 213: buy 1 unit at price 69.459999, total balance 1328.030006
# day 214: buy 1 unit at price 69.650002, total balance 1258.380004
# day 215: buy 1 unit at price 71.370003, total balance 1187.010001
# day 216: buy 1 unit at price 71.239998, total balance 1115.770003
# day 217: buy 1 unit at price 70.339996, total balance 1045.430007
# day 218: buy 1 unit at price 69.550003, total balance 975.880004
# day 219, sell 1 unit at price 69.610001, investment -14.357773 %, total balance 1045.490005,
# day 220: buy 1 unit at price 67.570000, total balance 977.920005
# day 223: buy 1 unit at price 69.209999, total balance 908.710006
# day 224: buy 1 unit at price 67.610001, total balance 841.100005
# day 225: buy 1 unit at price 68.669998, total balance 772.430007
# day 227: buy 1 unit at price 68.750000, total balance 703.680007
# day 228: buy 1 unit at price 69.900002, total balance 633.780005
# day 229, sell 1 unit at price 70.760002, investment -13.990513 %, total balance 704.540007,
# day 230: buy 1 unit at price 70.300003, total balance 634.240004
# day 232: buy 1 unit at price 71.930000, total balance 562.310004
# day 233: buy 1 unit at price 70.019997, total balance 492.290007
# day 234, sell 1 unit at price 69.400002, investment -17.449742 %, total balance 561.690009,
# day 235: buy 1 unit at price 68.000000, total balance 493.690009
# day 236: buy 1 unit at price 67.089996, total balance 426.600013
# day 238, sell 1 unit at price 68.029999, investment -18.808929 %, total balance 494.630012,
# day 239: buy 1 unit at price 69.080002, total balance 425.550010
# day 240: buy 1 unit at price 67.769997, total balance 357.780013
# day 241: buy 1 unit at price 64.669998, total balance 293.110015
# day 243: buy 1 unit at price 64.230003, total balance 228.880012
# day 244: buy 1 unit at price 62.779999, total balance 166.100013
# day 245: buy 1 unit at price 60.090000, total balance 106.010013
# day 246: buy 1 unit at price 60.020000, total balance 45.990013
# day 264, sell 1 unit at price 66.800003, investment -20.124351 %, total balance 112.790016,
# day 265: buy 1 unit at price 67.059998, total balance 45.730018
# day 269, sell 1 unit at price 68.660004, investment -19.061650 %, total balance 114.390022,
# day 272: buy 1 unit at price 70.139999, total balance 44.250023
# day 275, sell 1 unit at price 74.500000, investment -11.108457 %, total balance 118.750023,
# day 276: buy 1 unit at price 72.989998, total balance 45.760025
# day 278, sell 1 unit at price 72.970001, investment -13.450359 %, total balance 118.730026,
# day 279: buy 1 unit at price 73.449997, total balance 45.280029
# day 287, sell 1 unit at price 72.250000, investment -10.769422 %, total balance 117.530029,
# day 288: buy 1 unit at price 72.040001, total balance 45.490028
# day 307, sell 1 unit at price 70.750000, investment -10.736818 %, total balance 116.240028,
# day 308: buy 1 unit at price 71.089996, total balance 45.150032
# day 313, sell 1 unit at price 73.570000, investment -8.129373 %, total balance 118.720032,
# day 314: buy 1 unit at price 74.180000, total balance 44.540032
# day 329, sell 1 unit at price 72.930000, investment -8.459895 %, total balance 117.470032,
# day 330, sell 1 unit at price 73.370003, investment -8.857139 %, total balance 190.840035,
# day 331: buy 1 unit at price 72.400002, total balance 118.440033
# day 333, sell 1 unit at price 72.180000, investment -8.875141 %, total balance 190.620033,
# day 334: buy 1 unit at price 66.610001, total balance 124.010032
# day 335: buy 1 unit at price 59.250000, total balance 64.760032
# day 337: buy 1 unit at price 58.509998, total balance 6.250034
# day 353, sell 1 unit at price 62.360001, investment -21.133172 %, total balance 68.610035,
# day 354: buy 1 unit at price 61.930000, total balance 6.680035
# day 364, sell 1 unit at price 61.639999, investment -21.885698 %, total balance 68.320034,
# day 366: buy 1 unit at price 63.720001, total balance 4.600033
# day 376, sell 1 unit at price 64.360001, investment -19.950250 %, total balance 68.960034,
# day 377: buy 1 unit at price 64.180000, total balance 4.780034
# day 381, sell 1 unit at price 64.059998, investment -21.446970 %, total balance 68.840032,
# day 382: buy 1 unit at price 65.290001, total balance 3.550031
# day 393, sell 1 unit at price 66.400002, investment -17.842116 %, total balance 69.950033,
# day 394, sell 1 unit at price 66.040001, investment -19.236880 %, total balance 135.990034,
# day 395: buy 1 unit at price 65.330002, total balance 70.660032
# day 396: buy 1 unit at price 65.139999, total balance 5.520033
# day 400, sell 1 unit at price 62.580002, investment -24.328894 %, total balance 68.100035,
# day 401: buy 1 unit at price 62.209999, total balance 5.890036
# day 404, sell 1 unit at price 61.169998, investment -25.737531 %, total balance 67.060034,
# day 405: buy 1 unit at price 61.740002, total balance 5.320032
# day 413, sell 1 unit at price 60.000000, investment -26.623453 %, total balance 65.320032,
# day 414: buy 1 unit at price 59.869999, total balance 5.450033
# day 415, sell 1 unit at price 59.700001, investment -26.811326 %, total balance 65.150034,
# day 416: buy 1 unit at price 60.240002, total balance 4.910032
# day 422, sell 1 unit at price 64.449997, investment -20.235155 %, total balance 69.360029,
# day 423: buy 1 unit at price 64.180000, total balance 5.180029
# day 453, sell 1 unit at price 60.779999, investment -24.879501 %, total balance 65.960028,
# day 454: buy 1 unit at price 59.900002, total balance 6.060026
# day 457, sell 1 unit at price 60.459999, investment -25.925022 %, total balance 66.520025,
# day 458, sell 1 unit at price 60.669998, investment -25.849428 %, total balance 127.190023,
# day 459: buy 1 unit at price 60.450001, total balance 66.740022
# day 460: buy 1 unit at price 59.889999, total balance 6.850023
# day 466, sell 1 unit at price 63.029999, investment -22.965046 %, total balance 69.880022,
# day 467: buy 1 unit at price 62.860001, total balance 7.020021
# day 469, sell 1 unit at price 62.840000, investment -22.763029 %, total balance 69.860021,
# day 470: buy 1 unit at price 62.509998, total balance 7.350023
# day 480, sell 1 unit at price 64.150002, investment -21.930140 %, total balance 71.500025,
# day 481: buy 1 unit at price 64.110001, total balance 7.390024
# day 482, sell 1 unit at price 63.540001, investment -15.896759 %, total balance 70.930025,
# day 483: buy 1 unit at price 62.750000, total balance 8.180025
# day 496, sell 1 unit at price 63.220001, investment -15.740368 %, total balance 71.400026,
# day 497: buy 1 unit at price 62.630001, total balance 8.770025
# day 501, sell 1 unit at price 61.650002, investment -18.828171 %, total balance 70.420027,
# day 502: buy 1 unit at price 62.020000, total balance 8.400027

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Actor-critic Duel agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Actor-critic Duel agent'

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            feed_actor = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            tensor_action, tensor_validation = tf.split(feed_actor,2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            self.logits = feed_validation + tf.subtract(feed_action,
                                                        tf.reduce_mean(feed_action,axis=1,keep_dims=True))

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            self.REWARD = tf.placeholder(tf.float32, (None, 1))
            feed_critic = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            tensor_action, tensor_validation = tf.split(feed_critic,2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            feed_critic = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            feed_critic = tf.nn.relu(feed_critic) + self.Y
            feed_critic = tf.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(tf.square(self.REWARD - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(self.critic.logits, self.critic.Y)
        self.actor_critic_grad = tf.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(self.actor.logits, weights_actor, -self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead):
        self.MEMORIES.append((state, action, reward, new_state, dead))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target})
        for i in range(len(replay)):
            if not replay[0][-1]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: -110.460043.3, cost: 0.002866, total money: 8829.129962
# epoch: 20, total rewards: -211.969919.3, cost: 0.001687, total money: 8480.580085
# epoch: 30, total rewards: -324.769993.3, cost: 0.011638, total money: 5870.959998
# epoch: 40, total rewards: -373.199999.3, cost: 0.009326, total money: 5795.269988
# epoch: 50, total rewards: -616.129994.3, cost: 0.019383, total money: 3147.200027
# epoch: 60, total rewards: -598.930034.3, cost: 0.068640, total money: 1866.109969
# epoch: 70, total rewards: -568.749987.3, cost: 0.083038, total money: 4133.959998
# epoch: 80, total rewards: -460.510010.3, cost: 0.112504, total money: 3635.709969
# epoch: 90, total rewards: -787.610007.3, cost: 2.566644, total money: 391.950005
# epoch: 100, total rewards: -814.509976.3, cost: 127.994476, total money: 37.300036
# epoch: 110, total rewards: -294.319998.3, cost: 604.508667, total money: 3785.460015
# epoch: 120, total rewards: -937.050015.3, cost: 680.514465, total money: 40.099994
# epoch: 130, total rewards: -849.399959.3, cost: 36.476685, total money: 66.780040
# epoch: 140, total rewards: -629.049997.3, cost: 143.349121, total money: 6.610008
# epoch: 150, total rewards: -761.389971.3, cost: 183.138306, total money: 34.710043
# epoch: 160, total rewards: -801.840012.3, cost: 5.847219, total money: 8.579989
# epoch: 170, total rewards: -928.729998.3, cost: 0.046006, total money: 4.709998
# epoch: 180, total rewards: -632.240007.3, cost: 0.010296, total money: 62.120009
# epoch: 190, total rewards: -749.600009.3, cost: 0.038720, total money: 45.199984
# epoch: 200, total rewards: -630.420015.3, cost: 1.808500, total money: 1584.509973

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 70.949997, total balance 9929.050003
# day 3: buy 1 unit at price 73.300003, total balance 9855.750000
# day 6: buy 1 unit at price 73.970001, total balance 9781.779999
# day 7: buy 1 unit at price 74.010002, total balance 9707.769997
# day 10: buy 1 unit at price 75.839996, total balance 9631.930001
# day 11: buy 1 unit at price 76.750000, total balance 9555.180001
# day 13: buy 1 unit at price 77.959999, total balance 9477.220002
# day 14, sell 1 unit at price 78.260002, investment 10.303038 %, total balance 9555.480004,
# day 18: buy 1 unit at price 78.150002, total balance 9477.330002
# day 22: buy 1 unit at price 75.720001, total balance 9401.610001
# day 23: buy 1 unit at price 73.290001, total balance 9328.320000
# day 24, sell 1 unit at price 73.900002, investment 0.818552 %, total balance 9402.220002,
# day 25, sell 1 unit at price 76.519997, investment 3.447338 %, total balance 9478.739999,
# day 26, sell 1 unit at price 75.160004, investment 1.553847 %, total balance 9553.900003,
# day 27: buy 1 unit at price 76.290001, total balance 9477.610002
# day 29: buy 1 unit at price 78.110001, total balance 9399.500001
# day 30: buy 1 unit at price 79.820000, total balance 9319.680001
# day 31, sell 1 unit at price 81.370003, investment 7.291676 %, total balance 9401.050004,
# day 33: buy 1 unit at price 81.540001, total balance 9319.510003
# day 34: buy 1 unit at price 81.800003, total balance 9237.710000
# day 36: buy 1 unit at price 82.529999, total balance 9155.180001
# day 37: buy 1 unit at price 82.970001, total balance 9072.210000
# day 38: buy 1 unit at price 82.510002, total balance 8989.699998
# day 40, sell 1 unit at price 80.650002, investment 5.081436 %, total balance 9070.350000,
# day 41: buy 1 unit at price 81.279999, total balance 8989.070001
# day 43: buy 1 unit at price 83.070000, total balance 8906.000001
# day 45: buy 1 unit at price 83.220001, total balance 8822.780000
# day 51, sell 1 unit at price 84.599998, investment 8.517187 %, total balance 8907.379998,
# day 52: buy 1 unit at price 83.809998, total balance 8823.570000
# day 54: buy 1 unit at price 83.349998, total balance 8740.220002
# day 55: buy 1 unit at price 80.970001, total balance 8659.250001
# day 58: buy 1 unit at price 80.080002, total balance 8579.169999
# day 59: buy 1 unit at price 79.669998, total balance 8499.500001
# day 60, sell 1 unit at price 80.500000, investment 3.007035 %, total balance 8580.000001,
# day 63, sell 1 unit at price 80.720001, investment 6.603275 %, total balance 8660.720002,
# day 64, sell 1 unit at price 80.919998, investment 10.410693 %, total balance 8741.640000,
# day 65: buy 1 unit at price 79.070000, total balance 8662.570000
# day 68, sell 1 unit at price 79.930000, investment 4.771266 %, total balance 8742.500000,
# day 69: buy 1 unit at price 81.550003, total balance 8660.949997
# day 70, sell 1 unit at price 80.820000, investment 3.469465 %, total balance 8741.769997,
# day 75: buy 1 unit at price 81.769997, total balance 8660.000000
# day 77, sell 1 unit at price 80.800003, investment 1.227766 %, total balance 8740.800003,
# day 83: buy 1 unit at price 81.379997, total balance 8659.420006
# day 86: buy 1 unit at price 77.860001, total balance 8581.560005
# day 87: buy 1 unit at price 75.550003, total balance 8506.010002
# day 88: buy 1 unit at price 75.029999, total balance 8430.980003
# day 90: buy 1 unit at price 76.580002, total balance 8354.400001
# day 91, sell 1 unit at price 75.860001, investment -6.965906 %, total balance 8430.260002,
# day 95: buy 1 unit at price 76.040001, total balance 8354.220001
# day 96, sell 1 unit at price 75.750000, investment -7.396091 %, total balance 8429.970001,
# day 98: buy 1 unit at price 75.760002, total balance 8354.209999
# day 99, sell 1 unit at price 75.930000, investment -7.997091 %, total balance 8430.139999,
# day 101, sell 1 unit at price 74.410004, investment -10.316978 %, total balance 8504.550003,
# day 102: buy 1 unit at price 75.690002, total balance 8428.860001
# day 105, sell 1 unit at price 77.220001, investment -6.411345 %, total balance 8506.080002,
# day 111: buy 1 unit at price 78.250000, total balance 8427.830002
# day 116, sell 1 unit at price 79.199997, investment -2.559058 %, total balance 8507.029999,
# day 117: buy 1 unit at price 78.820000, total balance 8428.209999
# day 122: buy 1 unit at price 77.379997, total balance 8350.830002
# day 130: buy 1 unit at price 81.750000, total balance 8269.080002
# day 131: buy 1 unit at price 81.589996, total balance 8187.490006
# day 133: buy 1 unit at price 81.709999, total balance 8105.780007
# day 136: buy 1 unit at price 82.330002, total balance 8023.450005
# day 138: buy 1 unit at price 82.239998, total balance 7941.210007
# day 147, sell 1 unit at price 76.860001, investment -7.475622 %, total balance 8018.070008,
# day 151: buy 1 unit at price 77.239998, total balance 7940.830010
# day 152: buy 1 unit at price 76.260002, total balance 7864.570008
# day 153, sell 1 unit at price 75.559998, investment -9.204522 %, total balance 7940.130006,
# day 156: buy 1 unit at price 74.540001, total balance 7865.590005
# day 159, sell 1 unit at price 74.910004, investment -10.619251 %, total balance 7940.500009,
# day 162: buy 1 unit at price 75.110001, total balance 7865.390008
# day 166: buy 1 unit at price 77.690002, total balance 7787.700006
# day 175: buy 1 unit at price 75.699997, total balance 7712.000009
# day 176, sell 1 unit at price 77.199997, investment -7.378526 %, total balance 7789.200006,
# day 180: buy 1 unit at price 76.099998, total balance 7713.100008
# day 181: buy 1 unit at price 77.169998, total balance 7635.930010
# day 182, sell 1 unit at price 77.610001, investment -4.149685 %, total balance 7713.540011,
# day 186: buy 1 unit at price 76.760002, total balance 7636.780009
# day 190: buy 1 unit at price 76.559998, total balance 7560.220011
# day 192, sell 1 unit at price 75.209999, investment -6.081422 %, total balance 7635.430010,
# day 193: buy 1 unit at price 74.110001, total balance 7561.320009
# day 195: buy 1 unit at price 71.440002, total balance 7489.880007
# day 196: buy 1 unit at price 70.290001, total balance 7419.590006
# day 197: buy 1 unit at price 72.169998, total balance 7347.420008
# day 198, sell 1 unit at price 72.010002, investment -9.614656 %, total balance 7419.430010,
# day 201: buy 1 unit at price 73.589996, total balance 7345.840014
# day 202, sell 1 unit at price 73.690002, investment -6.804095 %, total balance 7419.530016,
# day 203, sell 1 unit at price 73.589996, investment -9.760891 %, total balance 7493.120012,
# day 205, sell 1 unit at price 70.150002, investment -14.210585 %, total balance 7563.270014,
# day 207, sell 1 unit at price 70.529999, investment -13.332512 %, total balance 7633.800013,
# day 208, sell 1 unit at price 69.220001, investment -11.096840 %, total balance 7703.020014,
# day 209: buy 1 unit at price 66.519997, total balance 7636.500017
# day 210, sell 1 unit at price 69.029999, investment -8.630051 %, total balance 7705.530016,
# day 212: buy 1 unit at price 69.500000, total balance 7636.030016
# day 213, sell 1 unit at price 69.459999, investment -7.423697 %, total balance 7705.490015,
# day 217, sell 1 unit at price 70.339996, investment -8.148349 %, total balance 7775.830011,
# day 219: buy 1 unit at price 69.610001, total balance 7706.220010
# day 222: buy 1 unit at price 70.330002, total balance 7635.890008
# day 223: buy 1 unit at price 69.209999, total balance 7566.680009
# day 227: buy 1 unit at price 68.750000, total balance 7497.930009
# day 229, sell 1 unit at price 70.760002, investment -6.943712 %, total balance 7568.690011,
# day 231, sell 1 unit at price 71.230003, investment -5.979407 %, total balance 7639.920014,
# day 232, sell 1 unit at price 71.930000, investment -4.967634 %, total balance 7711.850014,
# day 233: buy 1 unit at price 70.019997, total balance 7641.830017
# day 235: buy 1 unit at price 68.000000, total balance 7573.830017
# day 236: buy 1 unit at price 67.089996, total balance 7506.740021
# day 241: buy 1 unit at price 64.669998, total balance 7442.070023
# day 242, sell 1 unit at price 64.620003, investment -17.418527 %, total balance 7506.690026,
# day 243: buy 1 unit at price 64.230003, total balance 7442.460023
# day 244: buy 1 unit at price 62.779999, total balance 7379.680024
# day 245: buy 1 unit at price 60.090000, total balance 7319.590024
# day 247, sell 1 unit at price 62.360001, investment -20.883023 %, total balance 7381.950025,
# day 252, sell 1 unit at price 61.099998, investment -21.039028 %, total balance 7443.050023,
# day 255: buy 1 unit at price 64.320000, total balance 7378.730023
# day 258, sell 1 unit at price 64.919998, investment -20.587158 %, total balance 7443.650021,
# day 268: buy 1 unit at price 68.949997, total balance 7374.700024
# day 269: buy 1 unit at price 68.660004, total balance 7306.040020
# day 273, sell 1 unit at price 71.290001, investment -12.624091 %, total balance 7377.330021,
# day 274: buy 1 unit at price 71.209999, total balance 7306.120022
# day 276, sell 1 unit at price 72.989998, investment -10.671890 %, total balance 7379.110020,
# day 279: buy 1 unit at price 73.449997, total balance 7305.660023
# day 281: buy 1 unit at price 73.120003, total balance 7232.540020
# day 285: buy 1 unit at price 71.339996, total balance 7161.200024
# day 287: buy 1 unit at price 72.250000, total balance 7088.950024
# day 288, sell 1 unit at price 72.040001, investment -12.498483 %, total balance 7160.990025,
# day 289: buy 1 unit at price 71.309998, total balance 7089.680027
# day 291: buy 1 unit at price 72.129997, total balance 7017.550030
# day 293: buy 1 unit at price 71.389999, total balance 6946.160031
# day 296: buy 1 unit at price 71.150002, total balance 6875.010029
# day 297: buy 1 unit at price 72.349998, total balance 6802.660031
# day 299: buy 1 unit at price 71.209999, total balance 6731.450032
# day 301, sell 1 unit at price 72.129997, investment -12.293289 %, total balance 6803.580029,
# day 308: buy 1 unit at price 71.089996, total balance 6732.490033
# day 310, sell 1 unit at price 71.580002, investment -7.327804 %, total balance 6804.070035,
# day 312: buy 1 unit at price 73.849998, total balance 6730.220037
# day 315, sell 1 unit at price 73.790001, investment -3.238921 %, total balance 6804.010038,
# day 316: buy 1 unit at price 74.199997, total balance 6729.810041
# day 319, sell 1 unit at price 74.599998, investment 0.080490 %, total balance 6804.410039,
# day 320: buy 1 unit at price 74.190002, total balance 6730.220037
# day 321, sell 1 unit at price 74.290001, investment -1.091732 %, total balance 6804.510038,
# day 322, sell 1 unit at price 74.320000, investment -4.337755 %, total balance 6878.830038,
# day 324: buy 1 unit at price 72.150002, total balance 6806.680036
# day 326: buy 1 unit at price 71.480003, total balance 6735.200033
# day 327: buy 1 unit at price 72.849998, total balance 6662.350035
# day 329: buy 1 unit at price 72.930000, total balance 6589.420035
# day 331: buy 1 unit at price 72.400002, total balance 6517.020033
# day 332: buy 1 unit at price 72.959999, total balance 6444.060034
# day 334, sell 1 unit at price 66.610001, investment -12.007921 %, total balance 6510.670035,
# day 335: buy 1 unit at price 59.250000, total balance 6451.420035
# day 337: buy 1 unit at price 58.509998, total balance 6392.910037
# day 339: buy 1 unit at price 59.099998, total balance 6333.810039
# day 341, sell 1 unit at price 56.880001, investment -25.256239 %, total balance 6390.690040,
# day 342, sell 1 unit at price 57.750000, investment -25.165218 %, total balance 6448.440040,
# day 343, sell 1 unit at price 58.599998, investment -23.658160 %, total balance 6507.040038,
# day 344, sell 1 unit at price 58.639999, investment -23.406478 %, total balance 6565.680037,
# day 349: buy 1 unit at price 61.080002, total balance 6504.600035
# day 352: buy 1 unit at price 61.880001, total balance 6442.720034
# day 359, sell 1 unit at price 62.779999, investment -15.288088 %, total balance 6505.500033,
# day 361: buy 1 unit at price 63.369999, total balance 6442.130034
# day 365: buy 1 unit at price 62.560001, total balance 6379.570033
# day 367: buy 1 unit at price 62.610001, total balance 6316.960032
# day 369: buy 1 unit at price 64.459999, total balance 6252.500033
# day 372: buy 1 unit at price 63.060001, total balance 6189.440032
# day 383: buy 1 unit at price 65.860001, total balance 6123.580031
# day 388, sell 1 unit at price 65.139999, investment -8.818593 %, total balance 6188.720030,
# day 389, sell 1 unit at price 65.550003, investment -6.743488 %, total balance 6254.270033,
# day 390, sell 1 unit at price 65.870003, investment -8.729382 %, total balance 6320.140036,
# day 392, sell 1 unit at price 65.779999, investment -10.612852 %, total balance 6385.920035,
# day 397, sell 1 unit at price 66.410004, investment -0.165353 %, total balance 6452.330039,
# day 398: buy 1 unit at price 63.490002, total balance 6388.840037
# day 403: buy 1 unit at price 62.459999, total balance 6326.380038
# day 407: buy 1 unit at price 60.580002, total balance 6265.800036
# day 409, sell 1 unit at price 61.860001, investment -10.992804 %, total balance 6327.660037,
# day 413, sell 1 unit at price 60.000000, investment -13.805489 %, total balance 6387.660037,
# day 414, sell 1 unit at price 59.869999, investment -14.872747 %, total balance 6447.530036,
# day 418, sell 1 unit at price 61.389999, investment -11.298945 %, total balance 6508.920035,
# day 423: buy 1 unit at price 64.180000, total balance 6444.740035
# day 424: buy 1 unit at price 64.739998, total balance 6380.000037
# day 425, sell 1 unit at price 65.360001, investment -4.930908 %, total balance 6445.360038,
# day 427: buy 1 unit at price 64.330002, total balance 6381.030036
# day 429: buy 1 unit at price 64.000000, total balance 6317.030036
# day 430, sell 1 unit at price 63.509998, investment -9.297343 %, total balance 6380.540034,
# day 431: buy 1 unit at price 63.470001, total balance 6317.070033
# day 434: buy 1 unit at price 59.919998, total balance 6257.150035
# day 439: buy 1 unit at price 60.619999, total balance 6196.530036
# day 441, sell 1 unit at price 60.180000, investment -11.500000 %, total balance 6256.710036,
# day 443, sell 1 unit at price 60.279999, investment -10.150540 %, total balance 6316.990035,
# day 444, sell 1 unit at price 58.900002, investment -8.922215 %, total balance 6375.890037,
# day 448: buy 1 unit at price 60.380001, total balance 6315.510036
# day 450: buy 1 unit at price 61.389999, total balance 6254.120037
# day 459, sell 1 unit at price 60.450001, investment -5.885103 %, total balance 6314.570038,
# day 463: buy 1 unit at price 62.070000, total balance 6252.500038
# day 464: buy 1 unit at price 61.919998, total balance 6190.580040
# day 467, sell 1 unit at price 62.860001, investment 0.127432 %, total balance 6253.440041,
# day 469, sell 1 unit at price 62.840000, investment 4.576469 %, total balance 6316.280041,
# day 471: buy 1 unit at price 63.110001, total balance 6253.170040
# day 472, sell 1 unit at price 63.380001, investment -1.461441 %, total balance 6316.550041,
# day 477: buy 1 unit at price 63.189999, total balance 6253.360042
# day 478: buy 1 unit at price 63.360001, total balance 6190.000041
# day 480: buy 1 unit at price 64.150002, total balance 6125.850039
# day 481, sell 1 unit at price 64.110001, investment -7.019574 %, total balance 6189.960040,
# day 482, sell 1 unit at price 63.540001, investment -7.457039 %, total balance 6253.500041,
# day 483: buy 1 unit at price 62.750000, total balance 6190.750041
# day 484: buy 1 unit at price 62.400002, total balance 6128.350039
# day 487: buy 1 unit at price 61.880001, total balance 6066.470038
# day 488: buy 1 unit at price 61.099998, total balance 6005.370040
# day 489: buy 1 unit at price 60.680000, total balance 5944.690040
# day 491: buy 1 unit at price 61.639999, total balance 5883.050041
# day 492: buy 1 unit at price 61.660000, total balance 5821.390041
# day 494: buy 1 unit at price 62.320000, total balance 5759.070041
# day 496: buy 1 unit at price 63.220001, total balance 5695.850040
# day 500: buy 1 unit at price 62.160000, total balance 5633.690040
# day 501: buy 1 unit at price 61.650002, total balance 5572.040038
# day 502: buy 1 unit at price 62.020000, total balance 5510.020038

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Actor-critic Recurrent agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Actor-critic Recurrent agent'

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, None, input_size))
            self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * size_layer))
            cell = tf.nn.rnn_cell.LSTMCell(size_layer, state_is_tuple = False)
            self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X, cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            self.logits = tf.layers.dense(self.rnn[:,-1], output_size)

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * size_layer))
            self.REWARD = tf.placeholder(tf.float32, (None, 1))
            feed_critic = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            cell = tf.nn.rnn_cell.LSTMCell(size_layer, state_is_tuple = False)
            self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X, cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            feed_critic = tf.layers.dense(self.rnn[:,-1], output_size, activation = tf.nn.relu) + self.Y
            feed_critic = tf.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(tf.square(self.REWARD - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.skip = skip
        tf.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(self.critic.logits, self.critic.Y)
        self.actor_critic_grad = tf.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(self.actor.logits, weights_actor, -self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states,
                                                       self.actor.hidden_layer: init_values})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states,
                                                                     self.actor_target.hidden_layer: init_values})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q,
                                                          self.critic.hidden_layer: init_values})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads,
                                                self.actor.hidden_layer: init_values})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target,
                                                 self.critic_target.hidden_layer: init_values})
        for i in range(len(replay)):
            if not replay[0][-2]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards,
                                          self.critic.hidden_layer: init_values})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            
            if np.random.rand() < self.EPSILON:
                action = np.random.randint(self.OUTPUT_SIZE)
            else:
                action, last_state = self.sess.run([self.actor.logits,
                                                  self.actor.last_state],
                                                  feed_dict={self.actor.X:[self.INITIAL_FEATURES],
                                                             self.actor.hidden_layer:init_value})
                action, init_value = np.argmax(action[0]), last_state
                    
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                    
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.actor.logits,
                                                  self.actor.last_state],
                                                  feed_dict={self.actor.X:[self.INITIAL_FEATURES],
                                                             self.actor.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                self.INITIAL_FEATURES = new_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f4b50403eb8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f4b53f15cf8>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f4b53f54b00>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x7f4b50476278>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1750: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# epoch: 10, total rewards: -31.729992.3, cost: 0.000573, total money: 8780.450015
# epoch: 20, total rewards: -230.650010.3, cost: 0.003329, total money: 9644.829989
# epoch: 30, total rewards: -26.809967.3, cost: 0.001570, total money: 8479.160034
# epoch: 40, total rewards: -181.369992.3, cost: 0.001329, total money: 8209.040011
# epoch: 50, total rewards: -134.370021.3, cost: 0.002058, total money: 9433.169976
# epoch: 60, total rewards: 2.609981.3, cost: 0.000674, total money: 9563.459982
# epoch: 70, total rewards: -21.919986.3, cost: 0.000692, total money: 8982.590018
# epoch: 80, total rewards: -0.020014.3, cost: 0.889067, total money: 9999.979986
# epoch: 90, total rewards: -1238.820057.3, cost: 0.070994, total money: 5224.509936
# epoch: 100, total rewards: 35.259985.3, cost: 0.020609, total money: 10035.259985
# epoch: 110, total rewards: 4.409976.3, cost: 0.001269, total money: 10004.409976
# epoch: 120, total rewards: -125.149984.3, cost: 0.000245, total money: 9564.270015
# epoch: 130, total rewards: -0.559990.3, cost: 0.001391, total money: 9937.420010
# epoch: 140, total rewards: 8.440015.3, cost: 0.001960, total money: 10008.440015
# epoch: 150, total rewards: 9.019994.3, cost: 0.000028, total money: 10009.019994

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Actor-critic Duel Recurrent agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Actor-critic Duel Recurrent agent'

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, None, input_size))
            self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * size_layer))
            cell = tf.nn.rnn_cell.LSTMCell(size_layer, state_is_tuple = False)
            self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X, cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            tensor_action, tensor_validation = tf.split(self.rnn[:,-1],2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            self.logits = feed_validation + tf.subtract(feed_action,
                                                        tf.reduce_mean(feed_action,axis=1,keep_dims=True))

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * size_layer))
            self.REWARD = tf.placeholder(tf.float32, (None, 1))
            feed_critic = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            cell = tf.nn.rnn_cell.LSTMCell(size_layer, state_is_tuple = False)
            self.rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X, cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            tensor_action, tensor_validation = tf.split(self.rnn[:,-1],2,1)
            feed_action = tf.layers.dense(tensor_action, output_size)
            feed_validation = tf.layers.dense(tensor_validation, 1)
            feed_critic = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            feed_critic = tf.nn.relu(feed_critic) + self.Y
            feed_critic = tf.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(tf.square(self.REWARD - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.skip = skip
        tf.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(self.critic.logits, self.critic.Y)
        self.actor_critic_grad = tf.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(self.actor.logits, weights_actor, -self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, dead, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states,
                                                       self.actor.hidden_layer: init_values})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states,
                                                                     self.actor_target.hidden_layer: init_values})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q,
                                                          self.critic.hidden_layer: init_values})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads,
                                                self.actor.hidden_layer: init_values})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target,
                                                 self.critic_target.hidden_layer: init_values})
        for i in range(len(replay)):
            if not replay[0][-2]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards,
                                          self.critic.hidden_layer: init_values})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            
            if np.random.rand() < self.EPSILON:
                action = np.random.randint(self.OUTPUT_SIZE)
            else:
                action, last_state = self.sess.run([self.actor.logits,
                                                  self.actor.last_state],
                                                  feed_dict={self.actor.X:[self.INITIAL_FEATURES],
                                                             self.actor.hidden_layer:init_value})
                action, init_value = np.argmax(action[0]), last_state
                    
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                    
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.actor.logits,
                                                  self.actor.last_state],
                                                  feed_dict={self.actor.X:[self.INITIAL_FEATURES],
                                                             self.actor.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                self.INITIAL_FEATURES = new_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Curiosity Q-learning agent

# %%
from collections import deque
import random


df= df_full.copy()
name = 'Curiosity Q-learning agent'

class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.X = tf.placeholder(tf.float32, (None, self.state_size))
        self.Y = tf.placeholder(tf.float32, (None, self.state_size))
        self.ACTION = tf.placeholder(tf.float32, (None))
        self.REWARD = tf.placeholder(tf.float32, (None))
        self.batch_size = tf.shape(self.ACTION)[0]
        
        with tf.variable_scope('curiosity_model'):
            action = tf.reshape(self.ACTION, (-1,1))
            state_action = tf.concat([self.X, action], axis=1)
            save_state = tf.identity(self.Y)
            
            feed = tf.layers.dense(state_action, 32, activation=tf.nn.relu)
            self.curiosity_logits = tf.layers.dense(feed, self.state_size)
            self.curiosity_cost = tf.reduce_sum(tf.square(save_state - self.curiosity_logits), axis=1)
            
            self.curiosity_optimizer = tf.train.RMSPropOptimizer(self.LEARNING_RATE)\
            .minimize(tf.reduce_mean(self.curiosity_cost))
        
        total_reward = tf.add(self.curiosity_cost, self.REWARD)
        
        with tf.variable_scope("q_model"):
            with tf.variable_scope("eval_net"):
                x_action = tf.layers.dense(self.X, 128, tf.nn.relu)
                self.logits = tf.layers.dense(x_action, self.OUTPUT_SIZE)
            
            with tf.variable_scope("target_net"):
                y_action = tf.layers.dense(self.Y, 128, tf.nn.relu)
                y_q = tf.layers.dense(y_action, self.OUTPUT_SIZE)
            
            q_target = total_reward + self.GAMMA * tf.reduce_max(y_q, axis=1)
            action = tf.cast(self.ACTION, tf.int32)
            action_indices = tf.stack([tf.range(self.batch_size, dtype=tf.int32), action], axis=1)
            q = tf.gather_nd(params=self.logits, indices=action_indices)
            self.cost = tf.losses.mean_squared_error(labels=q_target, predictions=q)
            self.optimizer = tf.train.RMSPropOptimizer(self.LEARNING_RATE).minimize(
            self.cost, var_list=tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "q_model/eval_net"))
            
        t_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='q_model/target_net')
        e_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='q_model/eval_net')
        self.target_replace_op = [tf.assign(t, e) for t, e in zip(t_params, e_params)]
        
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action
    
    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        actions = np.array([a[1] for a in replay])
        rewards = np.array([a[2] for a in replay])
        new_states = np.array([a[3] for a in replay])
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.target_replace_op)
            
        cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict = {
            self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
        })
        
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.curiosity_optimizer, feed_dict = {
                self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
            })
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Recurrent Curiosity Q-learning agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Recurrent Curiosity Q-learning agent'

class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 128
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.INITIAL_FEATURES = np.zeros((4, self.state_size))
        self.X = tf.placeholder(tf.float32, (None, None, self.state_size))
        self.Y = tf.placeholder(tf.float32, (None, None, self.state_size))
        self.hidden_layer = tf.placeholder(tf.float32, (None, 2 * self.LAYER_SIZE))
        self.ACTION = tf.placeholder(tf.float32, (None))
        self.REWARD = tf.placeholder(tf.float32, (None))
        self.batch_size = tf.shape(self.ACTION)[0]
        self.seq_len = tf.shape(self.X)[1]
        
        with tf.variable_scope('curiosity_model'):
            action = tf.reshape(self.ACTION, (-1,1,1))
            repeat_action = tf.tile(action, [1,self.seq_len,1])
            state_action = tf.concat([self.X, repeat_action], axis=-1)
            save_state = tf.identity(self.Y)
            cell = tf.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
            self.rnn,last_state = tf.nn.dynamic_rnn(inputs=state_action,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
            self.curiosity_logits = tf.layers.dense(self.rnn[:,-1], self.state_size)
            self.curiosity_cost = tf.reduce_sum(tf.square(save_state[:,-1] - self.curiosity_logits), axis=1)
            
            self.curiosity_optimizer = tf.train.RMSPropOptimizer(self.LEARNING_RATE)\
            .minimize(tf.reduce_mean(self.curiosity_cost))
        
        total_reward = tf.add(self.curiosity_cost, self.REWARD)
        
        with tf.variable_scope("q_model"):
            with tf.variable_scope("eval_net"):
                cell = tf.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
                rnn,self.last_state = tf.nn.dynamic_rnn(inputs=self.X,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
                self.logits = tf.layers.dense(rnn[:,-1], self.OUTPUT_SIZE)
            
            with tf.variable_scope("target_net"):
                cell = tf.nn.rnn_cell.LSTMCell(self.LAYER_SIZE, state_is_tuple = False)
                rnn,last_state = tf.nn.dynamic_rnn(inputs=self.Y,cell=cell,
                                                    dtype=tf.float32,
                                                    initial_state=self.hidden_layer)
                y_q = tf.layers.dense(rnn[:,-1], self.OUTPUT_SIZE)
            
            q_target = total_reward + self.GAMMA * tf.reduce_max(y_q, axis=1)
            action = tf.cast(self.ACTION, tf.int32)
            action_indices = tf.stack([tf.range(self.batch_size, dtype=tf.int32), action], axis=1)
            q = tf.gather_nd(params=self.logits, indices=action_indices)
            self.cost = tf.losses.mean_squared_error(labels=q_target, predictions=q)
            self.optimizer = tf.train.RMSPropOptimizer(self.LEARNING_RATE).minimize(
            self.cost, var_list=tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "q_model/eval_net"))
            
        t_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='q_model/target_net')
        e_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='q_model/eval_net')
        self.target_replace_op = [tf.assign(t, e) for t, e in zip(t_params, e_params)]
        
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, done, rnn_state):
        self.MEMORIES.append((state, action, reward, new_state, done, rnn_state))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        actions = np.array([a[1] for a in replay])
        rewards = np.array([a[2] for a in replay])
        new_states = np.array([a[3] for a in replay])
        init_values = np.array([a[-1] for a in replay])
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.target_replace_op)
            
        cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict = {
            self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards,
            self.hidden_layer: init_values
        })
        
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.curiosity_optimizer, feed_dict = {
                self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards,
                self.hidden_layer: init_values
            })
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        init_value = np.zeros((1, 2 * self.LAYER_SIZE))
        for k in range(self.INITIAL_FEATURES.shape[0]):
            self.INITIAL_FEATURES[k,:] = state
        for t in range(0, len(self.trend) - 1, self.skip):
            
            if np.random.rand() < self.EPSILON:
                action = np.random.randint(self.OUTPUT_SIZE)
            else:
                action, last_state = self.sess.run([self.logits,
                                                  self.last_state],
                                                  feed_dict={self.X:[self.INITIAL_FEATURES],
                                                             self.hidden_layer:init_value})
                action, init_value = np.argmax(action[0]), last_state
                    
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
            self.INITIAL_FEATURES = new_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            init_value = np.zeros((1, 2 * self.LAYER_SIZE))
            for k in range(self.INITIAL_FEATURES.shape[0]):
                self.INITIAL_FEATURES[k,:] = state
            for t in range(0, len(self.trend) - 1, self.skip):
                if np.random.rand() < self.EPSILON:
                    action = np.random.randint(self.OUTPUT_SIZE)
                else:
                    action, last_state = self.sess.run([self.logits,
                                                  self.last_state],
                                                  feed_dict={self.X:[self.INITIAL_FEATURES],
                                                             self.hidden_layer:init_value})
                    action, init_value = np.argmax(action[0]), last_state
                    
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                new_state = np.append([self.get_state(t + 1)], self.INITIAL_FEATURES[:3, :], axis = 0)
                self._memorize(self.INITIAL_FEATURES, action, invest, new_state, 
                               starting_money < initial_money, init_value[0])
                self.INITIAL_FEATURES = new_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Duel Curiosity Q-learning agent

# %%
from collections import deque
import random

df= df_full.copy()
name = 'Duel Curiosity Q-learning agent'

class Agent:

    LEARNING_RATE = 0.003
    BATCH_SIZE = 32
    LAYER_SIZE = 500
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    COPY = 1000
    T_COPY = 0
    MEMORY_SIZE = 300
    
    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.X = tf.placeholder(tf.float32, (None, self.state_size))
        self.Y = tf.placeholder(tf.float32, (None, self.state_size))
        self.ACTION = tf.placeholder(tf.float32, (None))
        self.REWARD = tf.placeholder(tf.float32, (None))
        self.batch_size = tf.shape(self.ACTION)[0]
        
        with tf.variable_scope('curiosity_model'):
            action = tf.reshape(self.ACTION, (-1,1))
            state_action = tf.concat([self.X, action], axis=1)
            save_state = tf.identity(self.Y)
            
            feed = tf.layers.dense(state_action, 32, activation=tf.nn.relu)
            self.curiosity_logits = tf.layers.dense(feed, self.state_size)
            self.curiosity_cost = tf.reduce_sum(tf.square(save_state - self.curiosity_logits), axis=1)
            
            self.curiosity_optimizer = tf.train.RMSPropOptimizer(self.LEARNING_RATE)\
            .minimize(tf.reduce_mean(self.curiosity_cost))
        
        total_reward = tf.add(self.curiosity_cost, self.REWARD)
        
        with tf.variable_scope("q_model"):
            with tf.variable_scope("eval_net"):
                x_action = tf.layers.dense(self.X, 128, tf.nn.relu)
                tensor_action, tensor_validation = tf.split(x_action,2,1)
                feed_action = tf.layers.dense(tensor_action, self.OUTPUT_SIZE)
                feed_validation = tf.layers.dense(tensor_validation, 1)
                self.logits = feed_validation + \
                tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            
            with tf.variable_scope("target_net"):
                y_action = tf.layers.dense(self.Y, 128, tf.nn.relu)
                tensor_action, tensor_validation = tf.split(y_action,2,1)
                feed_action = tf.layers.dense(tensor_action, self.OUTPUT_SIZE)
                feed_validation = tf.layers.dense(tensor_validation, 1)
                y_q = feed_validation + \
                tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
            
            q_target = total_reward + self.GAMMA * tf.reduce_max(y_q, axis=1)
            action = tf.cast(self.ACTION, tf.int32)
            action_indices = tf.stack([tf.range(self.batch_size, dtype=tf.int32), action], axis=1)
            q = tf.gather_nd(params=self.logits, indices=action_indices)
            self.cost = tf.losses.mean_squared_error(labels=q_target, predictions=q)
            self.optimizer = tf.train.RMSPropOptimizer(self.LEARNING_RATE).minimize(
            self.cost, var_list=tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "q_model/eval_net"))
            
        t_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='q_model/target_net')
        e_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='q_model/eval_net')
        self.target_replace_op = [tf.assign(t, e) for t, e in zip(t_params, e_params)]
        
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _memorize(self, state, action, reward, new_state, done):
        self.MEMORIES.append((state, action, reward, new_state, done))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def predict(self, inputs):
        return self.sess.run(self.logits, feed_dict={self.X:inputs})
    
    def get_predicted_action(self, sequence):
        prediction = self.predict(np.array(sequence))[0]
        return np.argmax(prediction)
    
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            action = self.get_predicted_action([state])
        return action
    
    def _construct_memories(self, replay):
        states = np.array([a[0] for a in replay])
        actions = np.array([a[1] for a in replay])
        rewards = np.array([a[2] for a in replay])
        new_states = np.array([a[3] for a in replay])
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.target_replace_op)
            
        cost, _ = self.sess.run([self.cost, self.optimizer], feed_dict = {
            self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
        })
        
        if (self.T_COPY + 1) % self.COPY == 0:
            self.sess.run(self.curiosity_optimizer, feed_dict = {
                self.X: states, self.Y: new_states, self.ACTION: actions, self.REWARD: rewards
            })
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                state = next_state
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Neuro-evolution agent

# %%
df= df_full.copy()
name = 'Neuro-evolution agent'

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1

# %%
class neuralnetwork:
    def __init__(self, id_, hidden_size = 128):
        self.W1 = np.random.randn(window_size, hidden_size) / np.sqrt(window_size)
        self.W2 = np.random.randn(hidden_size, 3) / np.sqrt(hidden_size)
        self.fitness = 0
        self.id = id_

def relu(X):
    return np.maximum(X, 0)
    
def softmax(X):
    e_x = np.exp(X - np.max(X, axis=-1, keepdims=True))
    return e_x / np.sum(e_x, axis=-1, keepdims=True)

def feed_forward(X, nets):
    a1 = np.dot(X, nets.W1)
    z1 = relu(a1)
    a2 = np.dot(z1, nets.W2)
    return softmax(a2)

# %%
class NeuroEvolution:
    def __init__(self, population_size, mutation_rate, model_generator,
                state_size, window_size, trend, skip, initial_money):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.model_generator = model_generator
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        
    def _initialize_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append(self.model_generator(i))
    
    def mutate(self, individual, scale=1.0):
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W1.shape)
        individual.W1 += np.random.normal(loc=0, scale=scale, size=individual.W1.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W2.shape)
        individual.W2 += np.random.normal(loc=0, scale=scale, size=individual.W2.shape) * mutation_mask
        return individual
    
    def inherit_weights(self, parent, child):
        child.W1 = parent.W1.copy()
        child.W2 = parent.W2.copy()
        return child
    
    def crossover(self, parent1, parent2):
        child1 = self.model_generator((parent1.id+1)*10)
        child1 = self.inherit_weights(parent1, child1)
        child2 = self.model_generator((parent2.id+1)*10)
        child2 = self.inherit_weights(parent2, child2)
        # first W
        n_neurons = child1.W1.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W1[:, cutoff:] = parent2.W1[:, cutoff:].copy()
        child2.W1[:, cutoff:] = parent1.W1[:, cutoff:].copy()
        # second W
        n_neurons = child1.W2.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W2[:, cutoff:] = parent2.W2[:, cutoff:].copy()
        child2.W2[:, cutoff:] = parent1.W2[:, cutoff:].copy()
        return child1, child2
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def act(self, p, state):
        logits = feed_forward(state, p)
        return np.argmax(logits, 1)[0]
    
    def buy(self, individual):
        initial_money = self.initial_money
        starting_money = initial_money
        state = self.get_state(0)
        inventory = []
        states_sell = []
        states_buy = []
        
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(individual, state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((self.trend[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, self.trend[t], invest, initial_money)
                )
            state = next_state
        
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def calculate_fitness(self):
        for i in range(self.population_size):
            initial_money = self.initial_money
            starting_money = initial_money
            state = self.get_state(0)
            inventory = []
            
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(self.population[i], state)
                next_state = self.get_state(t + 1)
            
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    starting_money += self.trend[t]

                state = next_state
            invest = ((starting_money - initial_money) / initial_money) * 100
            self.population[i].fitness = invest
    
    def evolve(self, generations=20, checkpoint= 5):
        self._initialize_population()
        n_winners = int(self.population_size * 0.4)
        n_parents = self.population_size - n_winners
        for epoch in range(generations):
            self.calculate_fitness()
            fitnesses = [i.fitness for i in self.population]
            sort_fitness = np.argsort(fitnesses)[::-1]
            self.population = [self.population[i] for i in sort_fitness]
            fittest_individual = self.population[0]
            if (epoch+1) % checkpoint == 0:
                print('epoch %d, fittest individual %d with accuracy %f'%(epoch+1, sort_fitness[0], 
                                                                          fittest_individual.fitness))
            next_population = [self.population[i] for i in range(n_winners)]
            total_fitness = np.sum([np.abs(i.fitness) for i in self.population])
            parent_probabilities = [np.abs(i.fitness / total_fitness) for i in self.population]
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)
            for i in np.arange(0, len(parents), 2):
                child1, child2 = self.crossover(parents[i], parents[i+1])
                next_population += [self.mutate(child1), self.mutate(child2)]
            self.population = next_population
        return fittest_individual

# %%
population_size = 100
generations = 100
mutation_rate = 0.1
neural_evolve = NeuroEvolution(population_size, mutation_rate, neuralnetwork,
                              window_size, window_size, close, skip, initial_money)

# %%
fittest_nets = neural_evolve.evolve(50)

# %%
states_buy, states_sell, total_gains, invest = neural_evolve.buy(fittest_nets)

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## Neuro-evolution with Novelty search agent

# %%
df= df_full.copy()
name = 'Neuro-evolution with Novelty search agent'

close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1

novelty_search_threshold = 6
novelty_log_maxlen = 1000
backlog_maxsize = 500
novelty_log_add_amount = 3

# %%
class neuralnetwork:
    def __init__(self, id_, hidden_size = 128):
        self.W1 = np.random.randn(window_size, hidden_size) / np.sqrt(window_size)
        self.W2 = np.random.randn(hidden_size, 3) / np.sqrt(hidden_size)
        self.fitness = 0
        self.last_features = None
        self.id = id_

def relu(X):
    return np.maximum(X, 0)
    
def softmax(X):
    e_x = np.exp(X - np.max(X, axis=-1, keepdims=True))
    return e_x / np.sum(e_x, axis=-1, keepdims=True)

def feed_forward(X, nets):
    a1 = np.dot(X, nets.W1)
    z1 = relu(a1)
    a2 = np.dot(z1, nets.W2)
    return softmax(a2)

# %%
class NeuroEvolution:
    def __init__(self, population_size, mutation_rate, model_generator,
                state_size, window_size, trend, skip, initial_money):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.model_generator = model_generator
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.generation_backlog = []
        self.novel_backlog = []
        self.novel_pop = []
        
    def _initialize_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append(self.model_generator(i))
    
    def _memorize(self, q, i, limit):
        q.append(i)
        if len(q) > limit:
            q.pop()
    
    def mutate(self, individual, scale=1.0):
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W1.shape)
        individual.W1 += np.random.normal(loc=0, scale=scale, size=individual.W1.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W2.shape)
        individual.W2 += np.random.normal(loc=0, scale=scale, size=individual.W2.shape) * mutation_mask
        return individual
    
    def inherit_weights(self, parent, child):
        child.W1 = parent.W1.copy()
        child.W2 = parent.W2.copy()
        return child
    
    def crossover(self, parent1, parent2):
        child1 = self.model_generator((parent1.id+1)*10)
        child1 = self.inherit_weights(parent1, child1)
        child2 = self.model_generator((parent2.id+1)*10)
        child2 = self.inherit_weights(parent2, child2)
        # first W
        n_neurons = child1.W1.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W1[:, cutoff:] = parent2.W1[:, cutoff:].copy()
        child2.W1[:, cutoff:] = parent1.W1[:, cutoff:].copy()
        # second W
        n_neurons = child1.W2.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W2[:, cutoff:] = parent2.W2[:, cutoff:].copy()
        child2.W2[:, cutoff:] = parent1.W2[:, cutoff:].copy()
        return child1, child2
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])
    
    def act(self, p, state):
        logits = feed_forward(state, p)
        return np.argmax(logits, 1)[0]
    
    def buy(self, individual):
        initial_money = self.initial_money
        starting_money = initial_money
        state = self.get_state(0)
        inventory = []
        states_sell = []
        states_buy = []
        
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(individual, state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((self.trend[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, self.trend[t], invest, initial_money)
                )
            state = next_state
        
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def calculate_fitness(self):
        for i in range(self.population_size):
            initial_money = self.initial_money
            starting_money = initial_money
            state = self.get_state(0)
            inventory = []
            
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(self.population[i], state)
                next_state = self.get_state(t + 1)
            
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    starting_money += self.trend[t]

                state = next_state
            invest = ((starting_money - initial_money) / initial_money) * 100
            self.population[i].fitness = invest
            self.population[i].last_features = self.population[i].W2.flatten()
    
    def evaluate(self, individual, backlog, pop, k = 4):
        score = 0
        if len(backlog):
            x = np.array(backlog)
            nn = NearestNeighbors(n_neighbors = k, metric = 'euclidean').fit(np.array(backlog))
            d, _ = nn.kneighbors([individual])
            score += np.mean(d)
        
        if len(pop):
            nn = NearestNeighbors(n_neighbors = k, metric = 'euclidean').fit(np.array(pop))
            d, _ = nn.kneighbors([individual])
            score += np.mean(d)
        
        return score
    
    def evolve(self, generations=20, checkpoint= 5):
        self._initialize_population()
        n_winners = int(self.population_size * 0.4)
        n_parents = self.population_size - n_winners
        for epoch in range(generations):
            self.calculate_fitness()
            scores = [self.evaluate(p.last_features, self.novel_backlog, self.novel_pop) for p in self.population]
            sort_fitness = np.argsort(scores)[::-1]
            self.population = [self.population[i] for i in sort_fitness]
            fittest_individual = self.population[0]
            if (epoch+1) % checkpoint == 0:
                print('epoch %d, fittest individual %d with accuracy %f'%(epoch+1, sort_fitness[0], 
                                                                          fittest_individual.fitness))
            next_population = [self.population[i] for i in range(n_winners)]
            total_fitness = np.sum([np.abs(i.fitness) for i in self.population])
            parent_probabilities = [np.abs(i.fitness / total_fitness) for i in self.population]
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)
            
            for p in next_population:
                if p.last_features is not None:
                    self._memorize(self.novel_pop, p.last_features, backlog_maxsize)
                    if np.random.randint(0,10) < novelty_search_threshold:
                        self._memorize(self.novel_backlog, p.last_features, novelty_log_maxlen)
                        
            for i in np.arange(0, len(parents), 2):
                child1, child2 = self.crossover(parents[i], parents[i+1])
                next_population += [self.mutate(child1), self.mutate(child2)]
            self.population = next_population
            
            if np.random.randint(0,10) < novelty_search_threshold:
                pop_sorted = sorted(self.population, key=lambda p: p.fitness, reverse=True)
                self.generation_backlog.append(pop_sorted[0])
                print('novel add fittest, score: %f, backlog size: %d'%(pop_sorted[0].fitness, 
                                                                        len(self.generation_backlog)))
                generation_backlog_temp = self.generation_backlog
                if len(self.generation_backlog) > backlog_maxsize:
                    generation_backlog_temp = random.sample(generation_backlog, backlog_maxsize)
                for p in generation_backlog_temp:
                    if p.last_features is not None:
                        self._memorize(self.novel_backlog, p.last_features, novelty_log_maxlen)
                        
        return fittest_individual

# %%
population_size = 100
generations = 100
mutation_rate = 0.1
neural_evolve = NeuroEvolution(population_size, mutation_rate, neuralnetwork,
                              window_size, window_size, close, skip, initial_money)

# %%
fittest_nets = neural_evolve.evolve(100)

# %%
states_buy, states_sell, total_gains, invest = neural_evolve.buy(fittest_nets)

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %% [markdown]
# ## ABCD strategy agent

# %%
df= df_full.copy()
name = 'ABCD strategy agent'

def abcd(trend, skip_loop = 4, ma = 7):
    ma = pd.Series(trend).rolling(ma).mean().values
    x = []
    for a in range(ma.shape[0]):
        for b in range(a, ma.shape[0], skip_loop):
            for c in range(b, ma.shape[0], skip_loop):
                for d in range(c, ma.shape[0], skip_loop):
                    if ma[b] > ma[a] and \
                    (ma[c] < ma[b] and ma[c] > ma[a]) \
                    and ma[d] > ma[b]:
                        x.append([a,b,c,d])
    x_np = np.array(x)
    ac = x_np[:,0].tolist() + x_np[:,2].tolist()
    bd = x_np[:,1].tolist() + x_np[:,3].tolist()
    ac_set = set(ac)
    bd_set = set(bd)
    signal = np.zeros(len(trend))
    buy = list(ac_set - bd_set)
    sell = list(list(bd_set - ac_set))
    signal[buy] = 1.0
    signal[sell] = -1.0
    return signal

# %%
# %%time
signal = abcd(df['Close'])

# %%
def buy_stock(
    real_movement,
    signal,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 10000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    states_sell = []
    states_buy = []
    states_money = []
    current_inventory = 0
    
    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory
    
    for i in range(real_movement.shape[0]):
        state = signal[i]
        if state == 1:
            initial_money, current_inventory = buy(
                i, initial_money, current_inventory
            )
            states_buy.append(i)
        elif state == -1:
            if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
            else:
                if current_inventory > max_sell:
                    sell_units = max_sell
                else:
                    sell_units = current_inventory
                current_inventory -= sell_units
                total_sell = sell_units * real_movement[i]
                initial_money += total_sell
                try:
                    invest = (
                        (real_movement[i] - real_movement[states_buy[-1]])
                        / real_movement[states_buy[-1]]
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (i, sell_units, total_sell, invest, initial_money)
                )
            states_sell.append(i)
        states_money.append(initial_money)
            
    invest = ((initial_money - starting_money) / starting_money) * 100
    total_gains = initial_money - starting_money
    return states_buy, states_sell, total_gains, invest, states_money

# %%
states_buy, states_sell, total_gains, invest, states_money = buy_stock(df.Close, signal)

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.savefig(name+'.png')
plt.show()

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(states_money, color='r', lw=2.)
plt.plot(states_money, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(states_money, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.legend()
plt.show()

# %% [markdown]
# ## Deep Evolution Strategy

# %%
plt.figure(figsize = (10, 5))
bins = np.linspace(-10, 10, 100)

solution = np.random.randn(100)
w = np.random.randn(100)

plt.hist(solution, bins, alpha = 0.5, label = 'solution', color = 'r')
plt.hist(w, bins, alpha = 0.5, label = 'random', color = 'y')
plt.legend()
plt.show()

# %%
def f(w):
    return -np.sum(np.square(solution - w))


npop = 50
sigma = 0.1
alpha = 0.001

for i in range(5000):

    if (i + 1) % 1000 == 0:
        print(
            'iter %d. w: %s, solution: %s, reward: %f'
            % (i + 1, str(w[-1]), str(solution[-1]), f(w))
        )
    N = np.random.randn(npop, 100)
    R = np.zeros(npop)
    for j in range(npop):
        w_try = w + sigma * N[j]
        R[j] = f(w_try)

    A = (R - np.mean(R)) / np.std(R)
    w = w + alpha / (npop * sigma) * np.dot(N.T, A)

# %%
'''
I want to compare my first two individuals with my real w
'''
plt.figure(figsize=(10,5))

sigma = 0.1
N = np.random.randn(npop, 100)
individuals = []
for j in range(2):
    individuals.append(w + sigma * N[j])
    
    
plt.hist(w, bins, alpha=0.5, label='w',color='r')
plt.hist(individuals[0], bins, alpha=0.5, label='individual 1')
plt.hist(individuals[1], bins, alpha=0.5, label='individual 2')
plt.legend()
plt.show()

# %%
df= df_full.copy()
name = 'Deep Evolution Strategy'

# %%
def get_state(data, t, n):
    d = t - n + 1
    block = data[d : t + 1] if d >= 0 else -d * [data[0]] + data[: t + 1]
    res = []
    for i in range(n - 1):
        res.append(block[i + 1] - block[i])
    return np.array([res])

# %%
close = df.Close.values.tolist()
get_state(close, 0, 10)

# %%
get_state(close, 1, 10)

# %%
get_state(close, 2, 10)

# %%
class Deep_Evolution_Strategy:
    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / np.std(rewards)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')

# %%
class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(layer_size, 1),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        buy = np.dot(feed, self.weights[2])
        return decision, buy

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
window_size = 30
model = Model(window_size, 500, 3)

# %%
initial_money = 10000
starting_money = initial_money
len_close = len(close) - 1
weight = model
skip = 1

state = get_state(close, 0, window_size + 1)
inventory = []
quantity = 0

max_buy = 5
max_sell = 5


def act(model, sequence):
    decision, buy = model.predict(np.array(sequence))
    return np.argmax(decision[0]), int(buy[0])


for t in range(0, len_close, skip):
    action, buy = act(weight, state)
    next_state = get_state(close, t + 1, window_size + 1)
    if action == 1 and initial_money >= close[t]:
        if buy < 0:
            buy = 1
        if buy > max_buy:
            buy_units = max_buy
        else:
            buy_units = buy
        total_buy = buy_units * close[t]
        initial_money -= total_buy
        inventory.append(total_buy)
        quantity += buy_units
    elif action == 2 and len(inventory) > 0:
        if quantity > max_sell:
            sell_units = max_sell
        else:
            sell_units = quantity
        quantity -= sell_units
        total_sell = sell_units * close[t]
        initial_money += total_sell

    state = next_state
((initial_money - starting_money) / starting_money) * 100

# %%
import time


class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(
        self, model, money, max_buy, max_sell, close, window_size, skip
    ):
        self.window_size = window_size
        self.skip = skip
        self.close = close
        self.model = model
        self.initial_money = money
        self.max_buy = max_buy
        self.max_sell = max_sell
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision, buy = self.model.predict(np.array(sequence))
        return np.argmax(decision[0]), int(buy[0])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        len_close = len(self.close) - 1

        self.model.weights = weights
        state = get_state(self.close, 0, self.window_size + 1)
        inventory = []
        quantity = 0
        for t in range(0, len_close, self.skip):
            action, buy = self.act(state)
            next_state = get_state(self.close, t + 1, self.window_size + 1)
            if action == 1 and initial_money >= self.close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * self.close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
            elif action == 2 and len(inventory) > 0:
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                quantity -= sell_units
                total_sell = sell_units * self.close[t]
                initial_money += total_sell

            state = next_state
        return ((initial_money - starting_money) / starting_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        len_close = len(self.close) - 1
        state = get_state(self.close, 0, self.window_size + 1)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        quantity = 0
        for t in range(0, len_close, self.skip):
            action, buy = self.act(state)
            next_state = get_state(self.close, t + 1, self.window_size + 1)
            if action == 1 and initial_money >= self.close[t]:
                if buy < 0:
                    buy = 1
                if buy > self.max_buy:
                    buy_units = self.max_buy
                else:
                    buy_units = buy
                total_buy = buy_units * self.close[t]
                initial_money -= total_buy
                inventory.append(total_buy)
                quantity += buy_units
                states_buy.append(t)
                print(
                    'day %d: buy %d units at price %f, total balance %f'
                    % (t, buy_units, total_buy, initial_money)
                )
            elif action == 2 and len(inventory) > 0:
                bought_price = inventory.pop(0)
                if quantity > self.max_sell:
                    sell_units = self.max_sell
                else:
                    sell_units = quantity
                if sell_units < 1:
                    continue
                quantity -= sell_units
                total_sell = sell_units * self.close[t]
                initial_money += total_sell
                states_sell.append(t)
                try:
                    invest = ((total_sell - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (t, sell_units, total_sell, invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        print(
            '\ntotal gained %f, total investment %f %%'
            % (initial_money - starting_money, invest)
        )
        plt.figure(figsize = (20, 10))
        plt.plot(close, label = 'true close', c = 'g')
        plt.plot(
            close, 'X', label = 'predict buy', markevery = states_buy, c = 'b'
        )
        plt.plot(
            close, 'o', label = 'predict sell', markevery = states_sell, c = 'r'
        )
        plt.legend()
        plt.savefig(name+'.png')
        plt.show()

# %%
model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(
    model = model,
    money = 10000,
    max_buy = 5,
    max_sell = 5,
    close = close,
    window_size = window_size,
    skip = 1,
)

# %%
agent.fit(iterations = 500, checkpoint = 10)

# %%
agent.buy()
